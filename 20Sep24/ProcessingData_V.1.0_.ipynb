# %% [markdown]
# # Índice de Entradas
#
# 1. [Timestamp Eliminator](#1)
# 2. [Curl File Generator](#2)
# 3. [Moduli Curl File Generator](#3)
# 4. [General Velocity File Generator](#4)
# 5. [Velocity Generator by Triad](#5)
# 6. [Vorticity File Generator](#6)
# 7. [Helicity Generator by Triads](#7)
# 8. [First Integral of Helicity Generator](#8)
# 9. [First Integral of Absolute Values of Helicity Generator](#9)
# 10. [General Enstrophy File Generator](#10)
# 11. [First Integral of Enstrophy](#11)
# 12. [First Integral Moduli Baseline vs Experimental Color](#12)
# 13. [Second Integral of Absolute Helicity Baseline vs Experimental Color](#13)

# %% [markdown]
# Este primer código se encarga de determinar la ruta en la que se encuentran los archivos que se van a trabajar

# %%
root_folder = r"F:\Datos\20sep24"

# Horarios ajustados de mediciones de línea base y de intervenciones experimentales

# Horarios de mediciones de línea base
lab_b_matutino_base_times = {
    '01': "10:39:59.065",
    '02': "11:19:56.844",
    '03': "12:00:00.896",
    '04': "12:39:59.139",
    '05': "13:19:59.461"
}

# Horarios de intervenciones experimentales
lab_b_matutino_intervention_times = {
    '01': "10:59:59.414",
    '02': "11:39:59.104",
    '03': "12:19:59.778",
    '04': "13:00:01.295"
}

# Horarios de mediciones de línea base para Lab_A en turno matutino
lab_a_matutino_base_times = {
    '01': "10:39:59.065",
    '02': "11:19:56.844",
    '03': "12:00:00.896",
    '04': "12:39:59.139",
    '05': "13:19:59.461"
}

# Horarios de intervenciones experimentales para Lab_A en turno matutino
lab_a_matutino_intervention_times = {
    '01': "10:59:59.414",
    '02': "11:39:59.104",
    '03': "12:19:59.778",
    '04': "13:00:01.295"
}

n_change = {"Lab_Betta":"Lab_Betta", "Lab_Gamma":"Lab_Gamma"}

triad_names = {
    "FRT": "Frontal-Derecho-Superior",  
    "PLB": "Trasero-Izquierdo-Inferior",  
    "FLT": "Frontal-Izquierdo-Superior",  
    "PRB": "Trasero-Derecho-Inferior",  
    "FRB": "Frontal-Derecho-Inferior",  
    "PLT": "Trasero-Izquierdo-Superior",  
    "FLB": "Frontal-Izquierdo-Inferior",  
    "PRT": "Trasero-Derecho-Superior",  
    "RTB": "Derecho-Superior-Inferior",  
    "FLP": "Frontal-Izquierdo-Trasero",  
    "LTB": "Izquierdo-Superior-Inferior",  
    "FRP": "Frontal-Derecho-Trasero"
}

# %% [markdown]
# ## 1
#
# $$
#
#     \Huge \text{Second Timestamp Eliminator}
#
# $$

# %%
import os
import re

# Función para actualizar el formato de las líneas
def update_file_format(filepath):
    updated_lines = []
    print(f"Actualizando formato del archivo: {filepath}")
    with open(filepath, 'r', encoding='utf-8') as file:
        for line in file:
            print(f"Procesando línea: {line.strip()}")  # Mostrar cada línea procesada
            # Verificar si la línea contiene dos estampas de tiempo
            if re.match(r'^\d{2}:\d{2}:\d{2}\.\d{3} -> \d{2}:\d{2}:\d{2}\.\d{3} -> ', line):
                # Extraer y conservar sólo desde la segunda estampa de tiempo hasta el final de la línea
                new_line = re.sub(r'^\d{2}:\d{2}:\d{2}\.\d{3} -> ', '', line.strip())
                print(f"Formato actualizado: {new_line}")  # Mostrar la línea actualizada
                updated_lines.append(new_line)
            else:
                updated_lines.append(line.strip())
    
    # Sobrescribir el archivo con el nuevo formato
    with open(filepath, 'w', encoding='utf-8') as file:
        for line in updated_lines:
            file.write(line + '\n')
    print(f"Formato actualizado en: {filepath}")

# Función para eliminar filas con valores menores a 3.0
def filter_file(filepath):
    filtered_lines = []
    print(f"Filtrando archivo: {filepath}")
    with open(filepath, 'r', encoding='utf-8') as infile:
        for line in infile:
            # Buscar el vector entre paréntesis
            match = re.search(r'\((.*?)\)', line)
            if match:
                # Convertir los valores del vector a float
                values = list(map(float, match.group(1).split(',')))
                # Si todos los valores son mayores o iguales a 3.0, conservar la línea
                if all(value >= 3.0 for value in values):
                    filtered_lines.append(line.strip())
                else:
                    print(f"Línea eliminada: {line.strip()}")  # Mostrar la línea eliminada
            else:
                filtered_lines.append(line.strip())

    # Sobrescribir el archivo con las líneas filtradas
    with open(filepath, 'w', encoding='utf-8') as outfile:
        for line in filtered_lines:
            outfile.write(line + '\n')
    print(f"Archivo filtrado guardado: {filepath}")

# Función para escanear un directorio y procesar archivos con sufijos específicos
def scan_directory(root_folder, file_suffixes):
    for root, dirs, files in os.walk(root_folder):
        dirs[:] = [d for d in dirs if d not in ["Data Analysis", "Programas"]]  # Excluir directorios
        for filename in files:
            if any(filename.endswith(suffix) for suffix in file_suffixes):
                file_path = os.path.join(root, filename)
                update_file_format(file_path)  # Actualizar formato del archivo
                filter_file(file_path)  # Filtrar el archivo

file_suffixes = ["medroja.txt", "medmorada.txt", "medazul.txt", "medverde.txt", "medamarilla.txt", "mednegra.txt", "mednaranja.txt"]

# Realiza la búsqueda y procesa los archivos
scan_directory(root_folder, file_suffixes)
# Out:
# Actualizando formato del archivo: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Amarilla\01medamarilla.txt
# Procesando línea: 00:00:00.010 -> (3.3479959964, 3.3137829303, 3.3773214817, 3.3870968818, 3.3382208347, 3.2258064746)
# Procesando línea: 00:00:00.108 -> (3.3479959964, 3.3186705112, 3.3773214817, 3.3919844627, 3.3431084156, 3.2258064746)
# Procesando línea: 00:00:00.217 -> (3.3382208347, 3.3088953495, 3.3724339008, 3.3822093009, 3.3382208347, 3.2258064746)
# Procesando línea: 00:00:00.323 -> (3.3528835773, 3.3235580921, 3.3870968818, 3.3968720436, 3.3479959964, 3.2306940555)
# Procesando línea: 00:00:00.429 -> (3.3284456729, 3.2991201877, 3.3822093009, 3.3822093009, 3.3333332538, 3.2111437320)
# Procesando línea: 00:00:00.535 -> (3.3479959964, 3.3382208347, 3.3822093009, 3.3919844627, 3.3431084156, 3.2306940555)
# Procesando línea: 00:00:00.641 -> (3.3479959964, 3.3333332538, 3.3773214817, 3.3870968818, 3.3382208347, 3.2258064746)
# Procesando línea: 00:00:00.747 -> (3.3382208347, 3.3235580921, 3.3724339008, 3.3822093009, 3.3284456729, 3.2160313129)
# Procesando línea: 00:00:00.854 -> (3.3528835773, 3.3577711582, 3.3822093009, 3.3968720436, 3.3528835773, 3.2355816364)
# Procesando línea: 00:00:00.959 -> (3.3382208347, 3.3040077686, 3.3724339008, 3.3870968818, 3.3431084156, 3.2160313129)
# Procesando línea: 00:00:01.065 -> (3.3382208347, 3.3040077686, 3.3724339008, 3.3822093009, 3.3333332538, 3.2209188938)
# Procesando línea: 00:00:01.171 -> (3.3479959964, 3.3186705112, 3.3822093009, 3.3968720436, 3.3479959964, 3.2355816364)
# Procesando línea: 00:00:01.277 -> (3.3333332538, 3.3186705112, 3.3773214817, 3.3822093009, 3.3235580921, 3.2209188938)
# Procesando línea: 00:00:01.384 -> (3.3479959964, 3.3235580921, 3.3773214817, 3.3968720436, 3.3382208347, 3.2258064746)
# Procesando línea: 00:00:01.489 -> (3.3479959964, 3.3137829303, 3.3822093009, 3.3919844627, 3.3382208347, 3.2258064746)
# Procesando línea: 00:00:01.596 -> (3.3382208347, 3.3040077686, 3.3675463199, 3.3822093009, 3.3333332538, 3.2160313129)
# Procesando línea: 00:00:01.701 -> (3.3528835773, 3.3284456729, 3.3773214817, 3.4017596244, 3.3333332538, 3.2306940555)
# Procesando línea: 00:00:01.808 -> (3.3382208347, 3.3186705112, 3.3773214817, 3.3870968818, 3.3333332538, 3.2209188938)
# Procesando línea: 00:00:01.913 -> (3.3431084156, 3.3137829303, 3.3773214817, 3.3822093009, 3.3382208347, 3.2258064746)
# Procesando línea: 00:00:02.020 -> (3.3528835773, 3.3284456729, 3.3822093009, 3.3968720436, 3.3479959964, 3.2258064746)
# Procesando línea: 00:00:02.126 -> (3.3333332538, 3.3040077686, 3.3577711582, 3.3870968818, 3.3382208347, 3.2062561511)
# Procesando línea: 00:00:02.232 -> (3.3431084156, 3.3284456729, 3.3822093009, 3.3919844627, 3.3479959964, 3.2306940555)
# Procesando línea: 00:00:02.338 -> (3.3479959964, 3.3235580921, 3.3822093009, 3.3968720436, 3.3431084156, 3.2258064746)
# Procesando línea: 00:00:02.444 -> (3.3382208347, 3.3137829303, 3.3675463199, 3.3822093009, 3.3333332538, 3.2209188938)
# Procesando línea: 00:00:02.550 -> (3.3528835773, 3.3235580921, 3.3870968818, 3.3968720436, 3.3577711582, 3.2404692173)
# Procesando línea: 00:00:02.657 -> (3.3431084156, 3.3284456729, 3.3773214817, 3.3822093009, 3.3333332538, 3.2209188938)
# Procesando línea: 00:00:02.762 -> (3.3382208347, 3.3284456729, 3.3724339008, 3.3822093009, 3.3333332538, 3.2209188938)
# Procesando línea: 00:00:02.869 -> (3.3528835773, 3.3431084156, 3.3870968818, 3.3919844627, 3.3479959964, 3.2355816364)
# Procesando línea: 00:00:02.974 -> (3.3382208347, 3.3235580921, 3.3724339008, 3.3773214817, 3.3333332538, 3.2160313129)
# Procesando línea: 00:00:03.081 -> (3.3382208347, 3.3284456729, 3.3773214817, 3.3919844627, 3.3382208347, 3.2306940555)
# Procesando línea: 00:00:03.187 -> (3.3479959964, 3.3186705112, 3.3822093009, 3.3870968818, 3.3431084156, 3.2306940555)
# Procesando línea: 00:00:03.293 -> (3.3382208347, 3.2942326068, 3.3675463199, 3.3773214817, 3.3333332538, 3.2160313129)
# Procesando línea: 00:00:03.399 -> (3.3528835773, 3.3333332538, 3.3822093009, 3.3968720436, 3.3479959964, 3.2404692173)
# Procesando línea: 00:00:03.505 -> (3.3479959964, 3.3284456729, 3.3773214817, 3.3870968818, 3.3333332538, 3.2209188938)
# Procesando línea: 00:00:03.611 -> (3.3382208347, 3.3284456729, 3.3724339008, 3.3870968818, 3.3333332538, 3.2209188938)
# Procesando línea: 00:00:03.718 -> (3.3577711582, 3.3333332538, 3.3870968818, 3.3870968818, 3.3479959964, 3.2355816364)
# Procesando línea: 00:00:03.823 -> (3.3382208347, 3.3088953495, 3.3724339008, 3.3822093009, 3.3333332538, 3.2160313129)
# Procesando línea: 00:00:03.930 -> (3.3382208347, 3.3137829303, 3.3773214817, 3.3919844627, 3.3333332538, 3.2258064746)
# Procesando línea: 00:00:04.035 -> (3.3528835773, 3.3186705112, 3.3822093009, 3.3968720436, 3.3479959964, 3.2258064746)
# Procesando línea: 00:00:04.142 -> (3.3284456729, 3.2795698642, 3.3528835773, 3.3822093009, 3.3382208347, 3.2209188938)
# Procesando línea: 00:00:04.248 -> (3.3528835773, 3.3235580921, 3.3870968818, 3.3968720436, 3.3479959964, 3.2258064746)
# Procesando línea: 00:00:04.354 -> (3.3479959964, 3.3235580921, 3.3773214817, 3.3919844627, 3.3333332538, 3.2258064746)
# Procesando línea: 00:00:04.460 -> (3.3382208347, 3.3186705112, 3.3724339008, 3.3822093009, 3.3333332538, 3.2209188938)
# Procesando línea: 00:00:04.566 -> (3.3431084156, 3.3088953495, 3.3724339008, 3.3919844627, 3.3382208347, 3.2355816364)
# Procesando línea: 00:00:04.672 -> (3.3382208347, 3.3137829303, 3.3675463199, 3.3870968818, 3.3382208347, 3.2160313129)
# Procesando línea: 00:00:04.779 -> (3.3431084156, 3.3235580921, 3.3773214817, 3.3870968818, 3.3382208347, 3.2306940555)
# Procesando línea: 00:00:04.884 -> (3.3528835773, 3.3235580921, 3.3822093009, 3.3968720436, 3.3479959964, 3.2306940555)
# Procesando línea: 00:00:04.990 -> (3.3382208347, 3.2795698642, 3.3626587390, 3.3870968818, 3.3235580921, 3.2209188938)
# Procesando línea: 00:00:05.096 -> (3.3479959964, 3.3284456729, 3.3773214817, 3.3919844627, 3.3431084156, 3.2306940555)
# Procesando línea: 00:00:05.202 -> (3.3479959964, 3.3235580921, 3.3773214817, 3.3870968818, 3.3382208347, 3.2209188938)
# Procesando línea: 00:00:05.308 -> (3.3382208347, 3.3137829303, 3.3675463199, 3.3822093009, 3.3333332538, 3.2160313129)
# Procesando línea: 00:00:05.414 -> (3.3479959964, 3.2991201877, 3.3919844627, 3.3968720436, 3.3431084156, 3.2355816364)
# Procesando línea: 00:00:05.521 -> (3.3431084156, 3.3235580921, 3.3724339008, 3.3870968818, 3.3333332538, 3.2209188938)
# Procesando línea: 00:00:05.626 -> (3.3382208347, 3.3186705112, 3.3724339008, 3.3870968818, 3.3382208347, 3.2258064746)
# Procesando línea: 00:00:05.733 -> (3.3479959964, 3.3382208347, 3.3870968818, 3.3919844627, 3.3382208347, 3.2306940555)
# Procesando línea: 00:00:05.838 -> (3.3431084156, 3.3333332538, 3.3773214817, 3.3773214817, 3.3186705112, 3.2258064746)
# Procesando línea: 00:00:05.945 -> (3.3528835773, 3.3333332538, 3.3822093009, 3.3968720436, 3.3382208347, 3.2306940555)
# Procesando línea: 00:00:06.051 -> (3.3479959964, 3.3284456729, 3.3822093009, 3.3919844627, 3.3382208347, 3.2258064746)
# Procesando línea: 00:00:06.157 -> (3.3431084156, 3.3235580921, 3.3675463199, 3.3822093009, 3.3333332538, 3.2160313129)
# Procesando línea: 00:00:06.263 -> (3.3577711582, 3.3479959964, 3.3968720436, 3.3968720436, 3.3333332538, 3.2306940555)
# Procesando línea: 00:00:06.369 -> (3.3382208347, 3.3235580921, 3.3724339008, 3.3822093009, 3.3333332538, 3.2160313129)
# Procesando línea: 00:00:06.475 -> (3.3431084156, 3.3284456729, 3.3773214817, 3.3870968818, 3.3333332538, 3.2258064746)
# Procesando línea: 00:00:06.582 -> (3.3479959964, 3.3333332538, 3.3870968818, 3.3968720436, 3.3479959964, 3.2306940555)
# Procesando línea: 00:00:06.687 -> (3.3382208347, 3.3333332538, 3.3724339008, 3.3822093009, 3.3284456729, 3.2160313129)
# Procesando línea: 00:00:06.794 -> (3.3528835773, 3.3479959964, 3.3870968818, 3.3968720436, 3.3431084156, 3.2306940555)
# Procesando línea: 00:00:06.899 -> (3.3479959964, 3.3284456729, 3.3822093009, 3.3919844627, 3.3431084156, 3.2258064746)
# Procesando línea: 00:00:07.006 -> (3.3382208347, 3.3235580921, 3.3724339008, 3.3822093009, 3.3333332538, 3.2160313129)
# Procesando línea: 00:00:07.112 -> (3.3577711582, 3.3528835773, 3.3870968818, 3.3919844627, 3.3528835773, 3.2306940555)
# Procesando línea: 00:00:07.218 -> (3.3382208347, 3.3235580921, 3.3724339008, 3.3822093009, 3.3284456729, 3.2209188938)
# Procesando línea: 00:00:07.324 -> (3.3431084156, 3.3284456729, 3.3773214817, 3.3822093009, 3.3333332538, 3.2258064746)
# Procesando línea: 00:00:07.430 -> (3.3528835773, 3.3382208347, 3.3870968818, 3.3919844627, 3.3382208347, 3.2306940555)
# Procesando línea: 00:00:07.536 -> (3.3431084156, 3.3235580921, 3.3773214817, 3.3870968818, 3.3382208347, 3.2160313129)
# Procesando línea: 00:00:07.643 -> (3.3479959964, 3.3382208347, 3.3773214817, 3.3870968818, 3.3479959964, 3.2306940555)
# Procesando línea: 00:00:07.748 -> (3.3528835773, 3.3333332538, 3.3822093009, 3.3919844627, 3.3382208347, 3.2306940555)
# Procesando línea: 00:00:07.855 -> (3.3431084156, 3.3235580921, 3.3675463199, 3.3822093009, 3.3333332538, 3.2160313129)
# Procesando línea: 00:00:07.960 -> (3.3528835773, 3.3333332538, 3.3919844627, 3.3968720436, 3.3528835773, 3.2209188938)
# Procesando línea: 00:00:08.067 -> (3.3431084156, 3.3284456729, 3.3773214817, 3.3870968818, 3.3333332538, 3.2258064746)
# Procesando línea: 00:00:08.173 -> (3.3382208347, 3.3284456729, 3.3724339008, 3.3822093009, 3.3382208347, 3.2209188938)
# Procesando línea: 00:00:08.279 -> (3.3528835773, 3.3382208347, 3.3822093009, 3.3919844627, 3.3431084156, 3.2404692173)
# Procesando línea: 00:00:08.385 -> (3.3382208347, 3.3333332538, 3.3577711582, 3.3773214817, 3.3137829303, 3.1964809894)
# Procesando línea: 00:00:08.491 -> (3.3528835773, 3.3382208347, 3.3773214817, 3.3919844627, 3.3431084156, 3.2209188938)
# Procesando línea: 00:00:08.597 -> (3.3479959964, 3.3382208347, 3.3822093009, 3.3919844627, 3.3431084156, 3.2258064746)
# Procesando línea: 00:00:08.702 -> (3.3333332538, 3.3333332538, 3.3724339008, 3.3773214817, 3.3333332538, 3.2209188938)
# Procesando línea: 00:00:08.809 -> (3.3528835773, 3.3333332538, 3.3773214817, 3.4017596244, 3.3479959964, 3.2355816364)
# Procesando línea: 00:00:08.915 -> (3.3431084156, 3.3382208347, 3.3773214817, 3.3870968818, 3.3284456729, 3.2258064746)
# Procesando línea: 00:00:09.021 -> (3.3382208347, 3.3333332538, 3.3773214817, 3.3870968818, 3.3333332538, 3.2258064746)
# Procesando línea: 00:00:09.127 -> (3.3431084156, 3.3284456729, 3.3822093009, 3.3968720436, 3.3431084156, 3.2306940555)
# Procesando línea: 00:00:09.233 -> (3.3431084156, 3.3235580921, 3.3724339008, 3.3822093009, 3.3235580921, 3.2209188938)
# Procesando línea: 00:00:09.339 -> (3.3431084156, 3.3382208347, 3.3773214817, 3.3919844627, 3.3382208347, 3.2306940555)
# Procesando línea: 00:00:09.446 -> (3.3577711582, 3.3431084156, 3.3822093009, 3.3968720436, 3.3431084156, 3.2258064746)
# Procesando línea: 00:00:09.551 -> (3.3431084156, 3.3235580921, 3.3577711582, 3.3822093009, 3.3284456729, 3.2209188938)
# Procesando línea: 00:00:09.658 -> (3.3479959964, 3.3479959964, 3.3870968818, 3.3968720436, 3.3479959964, 3.2404692173)
# Procesando línea: 00:00:09.763 -> (3.3528835773, 3.3333332538, 3.3773214817, 3.3870968818, 3.3382208347, 3.2209188938)
# Procesando línea: 00:00:09.870 -> (3.3431084156, 3.3284456729, 3.3724339008, 3.3870968818, 3.3333332538, 3.2209188938)
# Procesando línea: 00:00:09.976 -> (3.3577711582, 3.3431084156, 3.3773214817, 3.4017596244, 3.3431084156, 3.2306940555)
# Procesando línea: 00:00:10.082 -> (3.3431084156, 3.3333332538, 3.3724339008, 3.3822093009, 3.3284456729, 3.2111437320)
# Procesando línea: 00:00:10.188 -> (3.3431084156, 3.3284456729, 3.3822093009, 3.3870968818, 3.3431084156, 3.2306940555)
# Procesando línea: 00:00:10.294 -> (3.3528835773, 3.3333332538, 3.3822093009, 3.3919844627, 3.3431084156, 3.2355816364)
# Procesando línea: 00:00:10.400 -> (3.3382208347, 3.2942326068, 3.3528835773, 3.3822093009, 3.3382208347, 3.2209188938)
# Procesando línea: 00:00:10.507 -> (3.3479959964, 3.3235580921, 3.3870968818, 3.3919844627, 3.3431084156, 3.2355816364)
# Procesando línea: 00:00:10.612 -> (3.3479959964, 3.3137829303, 3.3822093009, 3.3870968818, 3.3382208347, 3.2306940555)
# Procesando línea: 00:00:10.719 -> (3.3382208347, 3.3235580921, 3.3724339008, 3.3773214817, 3.3333332538, 3.2209188938)
# Procesando línea: 00:00:10.824 -> (3.3577711582, 3.3431084156, 3.3870968818, 3.4017596244, 3.3333332538, 3.2404692173)
# Procesando línea: 00:00:10.931 -> (3.3382208347, 3.3235580921, 3.3724339008, 3.3870968818, 3.3333332538, 3.2258064746)
# Procesando línea: 00:00:11.037 -> (3.3382208347, 3.3382208347, 3.3773214817, 3.3870968818, 3.3382208347, 3.2209188938)
# Procesando línea: 00:00:11.143 -> (3.3528835773, 3.3333332538, 3.3870968818, 3.3968720436, 3.3431084156, 3.2306940555)
# Procesando línea: 00:00:11.249 -> (3.3382208347, 3.3382208347, 3.3773214817, 3.3822093009, 3.3186705112, 3.2258064746)
# Procesando línea: 00:00:11.355 -> (3.3528835773, 3.3382208347, 3.3822093009, 3.3968720436, 3.3431084156, 3.2306940555)
# Procesando línea: 00:00:11.461 -> (3.3479959964, 3.3333332538, 3.3822093009, 3.3870968818, 3.3382208347, 3.2306940555)
# Procesando línea: 00:00:11.567 -> (3.3382208347, 3.3284456729, 3.3675463199, 3.3822093009, 3.3284456729, 3.2209188938)
# Procesando línea: 00:00:11.673 -> (3.3479959964, 3.3235580921, 3.3773214817, 3.4017596244, 3.3528835773, 3.2258064746)
# Procesando línea: 00:00:11.780 -> (3.3382208347, 3.3235580921, 3.3724339008, 3.3870968818, 3.3284456729, 3.2209188938)
# Procesando línea: 00:00:11.885 -> (3.3431084156, 3.3333332538, 3.3773214817, 3.3822093009, 3.3333332538, 3.2209188938)
# Procesando línea: 00:00:11.992 -> (3.3528835773, 3.3382208347, 3.3870968818, 3.3919844627, 3.3479959964, 3.2355816364)
# Procesando línea: 00:00:12.097 -> (3.3333332538, 3.3088953495, 3.3773214817, 3.3870968818, 3.3186705112, 3.2062561511)
# Procesando línea: 00:00:12.204 -> (3.3479959964, 3.3479959964, 3.3773214817, 3.3968720436, 3.3382208347, 3.2306940555)
# Procesando línea: 00:00:12.310 -> (3.3528835773, 3.3431084156, 3.3773214817, 3.3919844627, 3.3382208347, 3.2306940555)
# Procesando línea: 00:00:12.416 -> (3.3382208347, 3.3333332538, 3.3675463199, 3.3822093009, 3.3333332538, 3.2209188938)
# Procesando línea: 00:00:12.522 -> (3.3528835773, 3.3528835773, 3.3968720436, 3.4066472053, 3.3382208347, 3.2306940555)
# Procesando línea: 00:00:12.627 -> (3.3479959964, 3.3284456729, 3.3822093009, 3.3822093009, 3.3333332538, 3.2160313129)
# Procesando línea: 00:00:12.734 -> (3.3431084156, 3.3333332538, 3.3773214817, 3.3870968818, 3.3333332538, 3.2209188938)
# Procesando línea: 00:00:12.840 -> (3.3528835773, 3.3431084156, 3.3870968818, 3.4017596244, 3.3431084156, 3.2306940555)
# Procesando línea: 00:00:12.946 -> (3.3382208347, 3.3186705112, 3.3773214817, 3.3822093009, 3.3333332538, 3.2062561511)
# Procesando línea: 00:00:13.052 -> (3.3479959964, 3.3382208347, 3.3773214817, 3.3919844627, 3.3431084156, 3.2306940555)
# Procesando línea: 00:00:13.158 -> (3.3528835773, 3.3382208347, 3.3822093009, 3.3919844627, 3.3431084156, 3.2306940555)
# Procesando línea: 00:00:13.264 -> (3.3431084156, 3.3235580921, 3.3724339008, 3.3822093009, 3.3333332538, 3.2209188938)
# Procesando línea: 00:00:13.371 -> (3.3528835773, 3.3431084156, 3.3968720436, 3.4017596244, 3.3479959964, 3.2453567981)
# Procesando línea: 00:00:13.476 -> (3.3479959964, 3.3284456729, 3.3773214817, 3.3870968818, 3.3333332538, 3.2258064746)
# Procesando línea: 00:00:13.583 -> (3.3431084156, 3.3284456729, 3.3724339008, 3.3870968818, 3.3333332538, 3.2306940555)
# Procesando línea: 00:00:13.688 -> (3.3577711582, 3.3186705112, 3.3870968818, 3.3968720436, 3.3431084156, 3.2355816364)
# Procesando línea: 00:00:13.795 -> (3.3431084156, 3.3284456729, 3.3675463199, 3.3870968818, 3.3431084156, 3.2111437320)
# Procesando línea: 00:00:13.901 -> (3.3479959964, 3.3284456729, 3.3773214817, 3.3919844627, 3.3382208347, 3.2306940555)
# Procesando línea: 00:00:14.007 -> (3.3577711582, 3.3333332538, 3.3822093009, 3.3919844627, 3.3382208347, 3.2306940555)
# Procesando línea: 00:00:14.113 -> (3.3382208347, 3.3333332538, 3.3577711582, 3.3822093009, 3.3284456729, 3.2160313129)
# Procesando línea: 00:00:14.219 -> (3.3577711582, 3.3333332538, 3.3870968818, 3.4017596244, 3.3479959964, 3.2306940555)
# Procesando línea: 00:00:14.325 -> (3.3479959964, 3.3284456729, 3.3773214817, 3.3870968818, 3.3382208347, 3.2209188938)
# Procesando línea: 00:00:14.432 -> (3.3431084156, 3.3235580921, 3.3773214817, 3.3822093009, 3.3333332538, 3.2209188938)
# Procesando línea: 00:00:14.537 -> (3.3528835773, 3.3382208347, 3.3773214817, 3.4017596244, 3.3479959964, 3.2355816364)
# Procesando línea: 00:00:14.644 -> (3.3431084156, 3.3284456729, 3.3675463199, 3.3870968818, 3.3284456729, 3.2258064746)
# Procesando línea: 00:00:14.749 -> (3.3479959964, 3.3333332538, 3.3773214817, 3.3919844627, 3.3333332538, 3.2258064746)
# Procesando línea: 00:00:14.856 -> (3.3528835773, 3.3479959964, 3.3822093009, 3.3968720436, 3.3431084156, 3.2306940555)
# Procesando línea: 00:00:14.961 -> (3.3431084156, 3.3333332538, 3.3724339008, 3.3822093009, 3.3284456729, 3.2111437320)
# Procesando línea: 00:00:15.068 -> (3.3528835773, 3.3382208347, 3.3870968818, 3.3968720436, 3.3479959964, 3.2404692173)
# Procesando línea: 00:00:15.174 -> (3.3479959964, 3.3333332538, 3.3773214817, 3.3870968818, 3.3382208347, 3.2209188938)
# Procesando línea: 00:00:15.280 -> (3.3431084156, 3.3284456729, 3.3724339008, 3.3870968818, 3.3333332538, 3.2258064746)
# Procesando línea: 00:00:15.386 -> (3.3626587390, 3.3528835773, 3.3870968818, 3.3919844627, 3.3479959964, 3.2355816364)
# Procesando línea: 00:00:15.492 -> (3.3431084156, 3.3284456729, 3.3724339008, 3.3870968818, 3.3333332538, 3.2160313129)
# Procesando línea: 00:00:15.598 -> (3.3431084156, 3.3333332538, 3.3773214817, 3.3870968818, 3.3333332538, 3.2306940555)
# Procesando línea: 00:00:15.705 -> (3.3528835773, 3.3382208347, 3.3822093009, 3.3968720436, 3.3479959964, 3.2306940555)
# Procesando línea: 00:00:15.810 -> (3.3431084156, 3.2991201877, 3.3773214817, 3.3870968818, 3.3284456729, 3.2258064746)
# Procesando línea: 00:00:15.917 -> (3.3479959964, 3.3382208347, 3.3870968818, 3.3968720436, 3.3431084156, 3.2404692173)
# Procesando línea: 00:00:16.022 -> (3.3479959964, 3.3431084156, 3.3822093009, 3.3919844627, 3.3382208347, 3.2306940555)
# Procesando línea: 00:00:16.129 -> (3.3382208347, 3.3333332538, 3.3675463199, 3.3822093009, 3.3284456729, 3.2160313129)
# Procesando línea: 00:00:16.235 -> (3.3626587390, 3.3284456729, 3.3773214817, 3.3968720436, 3.3382208347, 3.2258064746)
# Procesando línea: 00:00:16.340 -> (3.3479959964, 3.3382208347, 3.3724339008, 3.3870968818, 3.3333332538, 3.2258064746)
# Procesando línea: 00:00:16.447 -> (3.3479959964, 3.3382208347, 3.3724339008, 3.3822093009, 3.3333332538, 3.2209188938)
# Procesando línea: 00:00:16.552 -> (3.3577711582, 3.3528835773, 3.3870968818, 3.3968720436, 3.3528835773, 3.2404692173)
# Procesando línea: 00:00:16.659 -> (3.3431084156, 3.3479959964, 3.3724339008, 3.3870968818, 3.3333332538, 3.2355816364)
# Procesando línea: 00:00:16.765 -> (3.3528835773, 3.3528835773, 3.3773214817, 3.3870968818, 3.3382208347, 3.2306940555)
# Procesando línea: 00:00:16.871 -> (3.3479959964, 3.3431084156, 3.3773214817, 3.3968720436, 3.3431084156, 3.2306940555)
# Procesando línea: 00:00:16.977 -> (3.3431084156, 3.3333332538, 3.3724339008, 3.3870968818, 3.3284456729, 3.2209188938)
# Procesando línea: 00:00:17.083 -> (3.3528835773, 3.3626587390, 3.3919844627, 3.3919844627, 3.3333332538, 3.2209188938)
# Procesando línea: 00:00:17.189 -> (3.3479959964, 3.3382208347, 3.3773214817, 3.3870968818, 3.3382208347, 3.2306940555)
# Procesando línea: 00:00:17.296 -> (3.3382208347, 3.3382208347, 3.3724339008, 3.3870968818, 3.3333332538, 3.2306940555)
# Procesando línea: 00:00:17.401 -> (3.3528835773, 3.3479959964, 3.3870968818, 3.3968720436, 3.3431084156, 3.2355816364)
# Procesando línea: 00:00:17.508 -> (3.3431084156, 3.3333332538, 3.3724339008, 3.3822093009, 3.3333332538, 3.2062561511)
# Procesando línea: 00:00:17.613 -> (3.3479959964, 3.3382208347, 3.3822093009, 3.3919844627, 3.3431084156, 3.2355816364)
# Procesando línea: 00:00:17.720 -> (3.3528835773, 3.3382208347, 3.3822093009, 3.3968720436, 3.3431084156, 3.2306940555)
# Procesando línea: 00:00:17.826 -> (3.3431084156, 3.3382208347, 3.3773214817, 3.3773214817, 3.3284456729, 3.2209188938)
# Procesando línea: 00:00:17.932 -> (3.3577711582, 3.3382208347, 3.3870968818, 3.3968720436, 3.3479959964, 3.2453567981)
# Procesando línea: 00:00:18.038 -> (3.3479959964, 3.3333332538, 3.3724339008, 3.3919844627, 3.3382208347, 3.2209188938)
# Procesando línea: 00:00:18.144 -> (3.3382208347, 3.3333332538, 3.3724339008, 3.3870968818, 3.3284456729, 3.2209188938)
# Procesando línea: 00:00:18.250 -> (3.3577711582, 3.3577711582, 3.3919844627, 3.3968720436, 3.3382208347, 3.2355816364)
# Procesando línea: 00:00:18.357 -> (3.3431084156, 3.3284456729, 3.3724339008, 3.3822093009, 3.3333332538, 3.2258064746)
# Procesando línea: 00:00:18.462 -> (3.3479959964, 3.3382208347, 3.3773214817, 3.3870968818, 3.3333332538, 3.2258064746)
# Procesando línea: 00:00:18.569 -> (3.3528835773, 3.3431084156, 3.3822093009, 3.3919844627, 3.3431084156, 3.2306940555)
# Procesando línea: 00:00:18.674 -> (3.3431084156, 3.3431084156, 3.3577711582, 3.3870968818, 3.3382208347, 3.2209188938)
# Procesando línea: 00:00:18.781 -> (3.3577711582, 3.3479959964, 3.3870968818, 3.3968720436, 3.3431084156, 3.2306940555)
# Procesando línea: 00:00:18.886 -> (3.3528835773, 3.3333332538, 3.3773214817, 3.3919844627, 3.3333332538, 3.2306940555)
# Procesando línea: 00:00:18.993 -> (3.3431084156, 3.3333332538, 3.3724339008, 3.3870968818, 3.3333332538, 3.2258064746)
# Procesando línea: 00:00:19.099 -> (3.3577711582, 3.3431084156, 3.3675463199, 3.3968720436, 3.3479959964, 3.2258064746)
# Procesando línea: 00:00:19.205 -> (3.3479959964, 3.3333332538, 3.3675463199, 3.3822093009, 3.3333332538, 3.2258064746)
# Procesando línea: 00:00:19.311 -> (3.3479959964, 3.3284456729, 3.3773214817, 3.3870968818, 3.3382208347, 3.2306940555)
# Procesando línea: 00:00:19.417 -> (3.3528835773, 3.3431084156, 3.3822093009, 3.3968720436, 3.3431084156, 3.2306940555)
# Procesando línea: 00:00:19.523 -> (3.3431084156, 3.3333332538, 3.3626587390, 3.3870968818, 3.3284456729, 3.2306940555)
# Procesando línea: 00:00:19.630 -> (3.3528835773, 3.3431084156, 3.3822093009, 3.3968720436, 3.3431084156, 3.2404692173)
# Procesando línea: 00:00:19.735 -> (3.3528835773, 3.3382208347, 3.3773214817, 3.3919844627, 3.3333332538, 3.2258064746)
# Procesando línea: 00:00:19.842 -> (3.3431084156, 3.3284456729, 3.3724339008, 3.3822093009, 3.3333332538, 3.2209188938)
# Procesando línea: 00:00:19.947 -> (3.3577711582, 3.3577711582, 3.3968720436, 3.3968720436, 3.3333332538, 3.2404692173)
# Procesando línea: 00:00:20.054 -> (3.3479959964, 3.3431084156, 3.3724339008, 3.3870968818, 3.3333332538, 3.2209188938)
# Procesando línea: 00:00:20.160 -> (3.3479959964, 3.3382208347, 3.3724339008, 3.3870968818, 3.3333332538, 3.2209188938)
# Procesando línea: 00:00:20.265 -> (3.3528835773, 3.3577711582, 3.3870968818, 3.3968720436, 3.3479959964, 3.2404692173)
# Procesando línea: 00:00:20.372 -> (3.3382208347, 3.3284456729, 3.3675463199, 3.3822093009, 3.3333332538, 3.2160313129)
# Procesando línea: 00:00:20.477 -> (3.3479959964, 3.3382208347, 3.3773214817, 3.3919844627, 3.3431084156, 3.2306940555)
# Procesando línea: 00:00:20.584 -> (3.3528835773, 3.3528835773, 3.3822093009, 3.3919844627, 3.3382208347, 3.2306940555)
# Procesando línea: 00:00:20.690 -> (3.3431084156, 3.3382208347, 3.3724339008, 3.3822093009, 3.3333332538, 3.2209188938)
# Procesando línea: 00:00:20.796 -> (3.3577711582, 3.3528835773, 3.3919844627, 3.4017596244, 3.3528835773, 3.2404692173)
# Procesando línea: 00:00:20.902 -> (3.3528835773, 3.3431084156, 3.3773214817, 3.3870968818, 3.3333332538, 3.2306940555)
# Procesando línea: 00:00:21.008 -> (3.3431084156, 3.3431084156, 3.3675463199, 3.3822093009, 3.3333332538, 3.2258064746)
# Procesando línea: 00:00:21.114 -> (3.3528835773, 3.3528835773, 3.4017596244, 3.3968720436, 3.3431084156, 3.2355816364)
# Procesando línea: 00:00:21.221 -> (3.3431084156, 3.3431084156, 3.3724339008, 3.3822093009, 3.3284456729, 3.2258064746)
# Procesando línea: 00:00:21.326 -> (3.3528835773, 3.3479959964, 3.3773214817, 3.3870968818, 3.3382208347, 3.2306940555)
# Procesando línea: 00:00:21.433 -> (3.3577711582, 3.3528835773, 3.3773214817, 3.3919844627, 3.3382208347, 3.2306940555)
# Procesando línea: 00:00:21.538 -> (3.3333332538, 3.3479959964, 3.3773214817, 3.3870968818, 3.3382208347, 3.2258064746)
# Procesando línea: 00:00:21.645 -> (3.3577711582, 3.3479959964, 3.3773214817, 3.3919844627, 3.3431084156, 3.2306940555)
# Procesando línea: 00:00:21.751 -> (3.3528835773, 3.3431084156, 3.3773214817, 3.3870968818, 3.3382208347, 3.2258064746)
# Procesando línea: 00:00:21.857 -> (3.3431084156, 3.3382208347, 3.3675463199, 3.3822093009, 3.3333332538, 3.2258064746)
# Procesando línea: 00:00:21.963 -> (3.3577711582, 3.3382208347, 3.3822093009, 3.3968720436, 3.3528835773, 3.2258064746)
# Procesando línea: 00:00:22.069 -> (3.3479959964, 3.3382208347, 3.3724339008, 3.3822093009, 3.3284456729, 3.2258064746)
# Procesando línea: 00:00:22.175 -> (3.3431084156, 3.3431084156, 3.3773214817, 3.3870968818, 3.3333332538, 3.2306940555)
# Procesando línea: 00:00:22.281 -> (3.3577711582, 3.3479959964, 3.3870968818, 3.3968720436, 3.3431084156, 3.2306940555)
# Procesando línea: 00:00:22.387 -> (3.3431084156, 3.3431084156, 3.3724339008, 3.3822093009, 3.3284456729, 3.2306940555)
# Procesando línea: 00:00:22.494 -> (3.3528835773, 3.3528835773, 3.3822093009, 3.3919844627, 3.3431084156, 3.2404692173)
# Procesando línea: 00:00:22.599 -> (3.3528835773, 3.3382208347, 3.3822093009, 3.3870968818, 3.3382208347, 3.2306940555)
# Procesando línea: 00:00:22.706 -> (3.3431084156, 3.3333332538, 3.3724339008, 3.3822093009, 3.3333332538, 3.2209188938)
# Procesando línea: 00:00:22.811 -> (3.3626587390, 3.3479959964, 3.3773214817, 3.3870968818, 3.3431084156, 3.2209188938)
# Procesando línea: 00:00:22.918 -> (3.3479959964, 3.3382208347, 3.3724339008, 3.3870968818, 3.3333332538, 3.2258064746)
# Procesando línea: 00:00:23.024 -> (3.3479959964, 3.3382208347, 3.3675463199, 3.3822093009, 3.3333332538, 3.2258064746)
# Procesando línea: 00:00:23.130 -> (3.3577711582, 3.3431084156, 3.3822093009, 3.3968720436, 3.3431084156, 3.2355816364)
# Procesando línea: 00:00:23.236 -> (3.3528835773, 3.3137829303, 3.3675463199, 3.3870968818, 3.3284456729, 3.2209188938)
# Procesando línea: 00:00:23.342 -> (3.3479959964, 3.3479959964, 3.3773214817, 3.3919844627, 3.3333332538, 3.2209188938)
# Procesando línea: 00:00:23.448 -> (3.3577711582, 3.3431084156, 3.3822093009, 3.3919844627, 3.3431084156, 3.2306940555)
# Procesando línea: 00:00:23.555 -> (3.3333332538, 3.3382208347, 3.3675463199, 3.3822093009, 3.3284456729, 3.2209188938)
# Procesando línea: 00:00:23.660 -> (3.3528835773, 3.3431084156, 3.3870968818, 3.4017596244, 3.3479959964, 3.2404692173)
# Procesando línea: 00:00:23.767 -> (3.3479959964, 3.3431084156, 3.3724339008, 3.3870968818, 3.3333332538, 3.2258064746)
# Procesando línea: 00:00:23.872 -> (3.3431084156, 3.3431084156, 3.3724339008, 3.3822093009, 3.3284456729, 3.2258064746)
# Procesando línea: 00:00:23.979 -> (3.3577711582, 3.3675463199, 3.3919844627, 3.4017596244, 3.3431084156, 3.2355816364)
# Procesando línea: 00:00:24.085 -> (3.3431084156, 3.3479959964, 3.3724339008, 3.3870968818, 3.3333332538, 3.2306940555)
# Procesando línea: 00:00:24.190 -> (3.3431084156, 3.3528835773, 3.3773214817, 3.3870968818, 3.3382208347, 3.2306940555)
# Procesando línea: 00:00:24.297 -> (3.3577711582, 3.3577711582, 3.3822093009, 3.3919844627, 3.3382208347, 3.2306940555)
# Procesando línea: 00:00:24.402 -> (3.3431084156, 3.3284456729, 3.3724339008, 3.3822093009, 3.3333332538, 3.2160313129)
# Procesando línea: 00:00:24.509 -> (3.3577711582, 3.3577711582, 3.3870968818, 3.3919844627, 3.3431084156, 3.2355816364)
# Procesando línea: 00:00:24.615 -> (3.3479959964, 3.3479959964, 3.3822093009, 3.3919844627, 3.3284456729, 3.2258064746)
# Procesando línea: 00:00:24.721 -> (3.3431084156, 3.3431084156, 3.3675463199, 3.3822093009, 3.3284456729, 3.2258064746)
# Procesando línea: 00:00:24.827 -> (3.3577711582, 3.3773214817, 3.3724339008, 3.3919844627, 3.3382208347, 3.2453567981)
# Procesando línea: 00:00:24.933 -> (3.3479959964, 3.3479959964, 3.3724339008, 3.3870968818, 3.3333332538, 3.2209188938)
# Procesando línea: 00:00:25.039 -> (3.3431084156, 3.3479959964, 3.3822093009, 3.3822093009, 3.3382208347, 3.2258064746)
# Procesando línea: 00:00:25.145 -> (3.3577711582, 3.3479959964, 3.3822093009, 3.3968720436, 3.3431084156, 3.2355816364)
# Procesando línea: 00:00:25.251 -> (3.3382208347, 3.3479959964, 3.3626587390, 3.3870968818, 3.3333332538, 3.2258064746)
# Procesando línea: 00:00:25.358 -> (3.3528835773, 3.3577711582, 3.3870968818, 3.3968720436, 3.3431084156, 3.2306940555)
# Procesando línea: 00:00:25.463 -> (3.3528835773, 3.3431084156, 3.3822093009, 3.3919844627, 3.3382208347, 3.2355816364)
# Procesando línea: 00:00:25.570 -> (3.3431084156, 3.3382208347, 3.3724339008, 3.3822093009, 3.3333332538, 3.2209188938)
# Procesando línea: 00:00:25.675 -> (3.3626587390, 3.3675463199, 3.3919844627, 3.3968720436, 3.3333332538, 3.2404692173)
# Procesando línea: 00:00:25.782 -> (3.3479959964, 3.3479959964, 3.3724339008, 3.3870968818, 3.3333332538, 3.2306940555)
# Procesando línea: 00:00:25.888 -> (3.3479959964, 3.3479959964, 3.3724339008, 3.3822093009, 3.3284456729, 3.2258064746)
# Procesando línea: 00:00:25.994 -> (3.3577711582, 3.3577711582, 3.3870968818, 3.3919844627, 3.3382208347, 3.2306940555)
# Procesando línea: 00:00:26.100 -> (3.3431084156, 3.3333332538, 3.3577711582, 3.3919844627, 3.3235580921, 3.2258064746)
# Procesando línea: 00:00:26.206 -> (3.3479959964, 3.3479959964, 3.3773214817, 3.3919844627, 3.3333332538, 3.2306940555)
# Procesando línea: 00:00:26.312 -> (3.3528835773, 3.3577711582, 3.3822093009, 3.3968720436, 3.3382208347, 3.2355816364)
# Procesando línea: 00:00:26.419 -> (3.3333332538, 3.3382208347, 3.3724339008, 3.3822093009, 3.3284456729, 3.2258064746)
# Procesando línea: 00:00:26.524 -> (3.3577711582, 3.3577711582, 3.3870968818, 3.3968720436, 3.3528835773, 3.2355816364)
# Procesando línea: 00:00:26.631 -> (3.3528835773, 3.3528835773, 3.3773214817, 3.3870968818, 3.3382208347, 3.2258064746)
# Procesando línea: 00:00:26.736 -> (3.3431084156, 3.3431084156, 3.3724339008, 3.3870968818, 3.3284456729, 3.2306940555)
# Procesando línea: 00:00:26.843 -> (3.3528835773, 3.3675463199, 3.3822093009, 3.3919844627, 3.3528835773, 3.2306940555)
# Procesando línea: 00:00:26.949 -> (3.3479959964, 3.3431084156, 3.3773214817, 3.3870968818, 3.3284456729, 3.2209188938)
# Procesando línea: 00:00:27.055 -> (3.3479959964, 3.3479959964, 3.3773214817, 3.3870968818, 3.3333332538, 3.2306940555)
# Procesando línea: 00:00:27.161 -> (3.3577711582, 3.3528835773, 3.3870968818, 3.3968720436, 3.3431084156, 3.2306940555)
# Procesando línea: 00:00:27.267 -> (3.3479959964, 3.3528835773, 3.3626587390, 3.3822093009, 3.3186705112, 3.2111437320)
# Procesando línea: 00:00:27.373 -> (3.3528835773, 3.3431084156, 3.3822093009, 3.3919844627, 3.3431084156, 3.2355816364)
# Procesando línea: 00:00:27.480 -> (3.3528835773, 3.3431084156, 3.3822093009, 3.3919844627, 3.3382208347, 3.2258064746)
# Procesando línea: 00:00:27.585 -> (3.3479959964, 3.3382208347, 3.3675463199, 3.3822093009, 3.3284456729, 3.2258064746)
# Procesando línea: 00:00:27.692 -> (3.3626587390, 3.3382208347, 3.3870968818, 3.3968720436, 3.3333332538, 3.2306940555)
# Procesando línea: 00:00:27.797 -> (3.3528835773, 3.3431084156, 3.3724339008, 3.3870968818, 3.3284456729, 3.2258064746)
# Procesando línea: 00:00:27.904 -> (3.3528835773, 3.3431084156, 3.3773214817, 3.3870968818, 3.3333332538, 3.2258064746)
# Procesando línea: 00:00:28.010 -> (3.3577711582, 3.3479959964, 3.3870968818, 3.3968720436, 3.3431084156, 3.2404692173)
# Procesando línea: 00:00:28.115 -> (3.3431084156, 3.3577711582, 3.3773214817, 3.3773214817, 3.3333332538, 3.2111437320)
# Procesando línea: 00:00:28.222 -> (3.3528835773, 3.3479959964, 3.3822093009, 3.3919844627, 3.3382208347, 3.2306940555)
# Procesando línea: 00:00:28.327 -> (3.3577711582, 3.3528835773, 3.3822093009, 3.3968720436, 3.3382208347, 3.2355816364)
# Procesando línea: 00:00:28.434 -> (3.3431084156, 3.3382208347, 3.3626587390, 3.3822093009, 3.3284456729, 3.2258064746)
# Procesando línea: 00:00:28.539 -> (3.3577711582, 3.3577711582, 3.3724339008, 3.3968720436, 3.3333332538, 3.2404692173)
# Procesando línea: 00:00:28.646 -> (3.3479959964, 3.3431084156, 3.3773214817, 3.3870968818, 3.3333332538, 3.2258064746)
# Procesando línea: 00:00:28.752 -> (3.3479959964, 3.3431084156, 3.3724339008, 3.3870968818, 3.3284456729, 3.2306940555)
# Procesando línea: 00:00:28.858 -> (3.3528835773, 3.3528835773, 3.3870968818, 3.3968720436, 3.3479959964, 3.2355816364)
# Procesando línea: 00:00:28.964 -> (3.3479959964, 3.3382208347, 3.3724339008, 3.3822093009, 3.3186705112, 3.2160313129)
# Procesando línea: 00:00:29.070 -> (3.3528835773, 3.3479959964, 3.3822093009, 3.3919844627, 3.3333332538, 3.2306940555)
# Procesando línea: 00:00:29.176 -> (3.3528835773, 3.3577711582, 3.3870968818, 3.3919844627, 3.3431084156, 3.2355816364)
# Procesando línea: 00:00:29.283 -> (3.3479959964, 3.3479959964, 3.3724339008, 3.3822093009, 3.3333332538, 3.2258064746)
# Procesando línea: 00:00:29.388 -> (3.3577711582, 3.3528835773, 3.3919844627, 3.4017596244, 3.3431084156, 3.2355816364)
# Procesando línea: 00:00:29.495 -> (3.3528835773, 3.3577711582, 3.3822093009, 3.3870968818, 3.3333332538, 3.2258064746)
# Procesando línea: 00:00:29.600 -> (3.3479959964, 3.3431084156, 3.3724339008, 3.3870968818, 3.3284456729, 3.2258064746)
# Procesando línea: 00:00:29.707 -> (3.3626587390, 3.3724339008, 3.3822093009, 3.3968720436, 3.3431084156, 3.2453567981)
# Procesando línea: 00:00:29.813 -> (3.3479959964, 3.3431084156, 3.3724339008, 3.3870968818, 3.3284456729, 3.2209188938)
# Procesando línea: 00:00:29.919 -> (3.3479959964, 3.3479959964, 3.3773214817, 3.3870968818, 3.3333332538, 3.2306940555)
# Procesando línea: 00:00:30.025 -> (3.3577711582, 3.3528835773, 3.3822093009, 3.4017596244, 3.3479959964, 3.2355816364)
# Procesando línea: 00:00:30.131 -> (3.3479959964, 3.3431084156, 3.3822093009, 3.3773214817, 3.3235580921, 3.2258064746)
# Procesando línea: 00:00:30.237 -> (3.3577711582, 3.3528835773, 3.3822093009, 3.3968720436, 3.3382208347, 3.2404692173)
# Procesando línea: 00:00:30.344 -> (3.3528835773, 3.3479959964, 3.3773214817, 3.3919844627, 3.3382208347, 3.2306940555)
# Procesando línea: 00:00:30.449 -> (3.3431084156, 3.3528835773, 3.3724339008, 3.3870968818, 3.3235580921, 3.2258064746)
# Procesando línea: 00:00:30.556 -> (3.3577711582, 3.3626587390, 3.3870968818, 3.4066472053, 3.3333332538, 3.2453567981)
# Procesando línea: 00:00:30.661 -> (3.3479959964, 3.3528835773, 3.3773214817, 3.3870968818, 3.3333332538, 3.2306940555)
# Procesando línea: 00:00:30.768 -> (3.3479959964, 3.3528835773, 3.3724339008, 3.3870968818, 3.3284456729, 3.2258064746)
# Procesando línea: 00:00:30.874 -> (3.3577711582, 3.3577711582, 3.3822093009, 3.3968720436, 3.3479959964, 3.2306940555)
# Procesando línea: 00:00:30.980 -> (3.3431084156, 3.3626587390, 3.3773214817, 3.3870968818, 3.3186705112, 3.2258064746)
# Procesando línea: 00:00:31.086 -> (3.3528835773, 3.3626587390, 3.3822093009, 3.3919844627, 3.3431084156, 3.2404692173)
# Procesando línea: 00:00:31.192 -> (3.3577711582, 3.3528835773, 3.3822093009, 3.3968720436, 3.3382208347, 3.2306940555)
# Procesando línea: 00:00:31.298 -> (3.3528835773, 3.3431084156, 3.3675463199, 3.3822093009, 3.3333332538, 3.2209188938)
# Procesando línea: 00:00:31.405 -> (3.3577711582, 3.3577711582, 3.3822093009, 3.4017596244, 3.3431084156, 3.2306940555)
# Procesando línea: 00:00:31.510 -> (3.3528835773, 3.3479959964, 3.3773214817, 3.3870968818, 3.3333332538, 3.2306940555)
# Procesando línea: 00:00:31.617 -> (3.3479959964, 3.3431084156, 3.3724339008, 3.3870968818, 3.3333332538, 3.2258064746)
# Procesando línea: 00:00:31.722 -> (3.3577711582, 3.3479959964, 3.3919844627, 3.3968720436, 3.3479959964, 3.2355816364)
# Procesando línea: 00:00:31.828 -> (3.3479959964, 3.3431084156, 3.3675463199, 3.3773214817, 3.3284456729, 3.2258064746)
# Procesando línea: 00:00:31.935 -> (3.3528835773, 3.3431084156, 3.3724339008, 3.3870968818, 3.3382208347, 3.2306940555)
# Procesando línea: 00:00:32.040 -> (3.3626587390, 3.3528835773, 3.3822093009, 3.3968720436, 3.3431084156, 3.2355816364)
# Procesando línea: 00:00:32.147 -> (3.3479959964, 3.3528835773, 3.3626587390, 3.3822093009, 3.3284456729, 3.2209188938)
# Procesando línea: 00:00:32.252 -> (3.3577711582, 3.3479959964, 3.3870968818, 3.3968720436, 3.3431084156, 3.2404692173)
# Procesando línea: 00:00:32.359 -> (3.3577711582, 3.3479959964, 3.3773214817, 3.3870968818, 3.3382208347, 3.2306940555)
# Procesando línea: 00:00:32.464 -> (3.3479959964, 3.3431084156, 3.3724339008, 3.3773214817, 3.3284456729, 3.2258064746)
# Procesando línea: 00:00:32.571 -> (3.3577711582, 3.3675463199, 3.3870968818, 3.3919844627, 3.3479959964, 3.2453567981)
# Procesando línea: 00:00:32.677 -> (3.3528835773, 3.3431084156, 3.3724339008, 3.3822093009, 3.3284456729, 3.2306940555)
# Procesando línea: 00:00:32.783 -> (3.3479959964, 3.3382208347, 3.3724339008, 3.3870968818, 3.3333332538, 3.2306940555)
# Procesando línea: 00:00:32.889 -> (3.3626587390, 3.3528835773, 3.3822093009, 3.3968720436, 3.3382208347, 3.2355816364)
# Procesando línea: 00:00:32.995 -> (3.3479959964, 3.3479959964, 3.3724339008, 3.3822093009, 3.3382208347, 3.2306940555)
# Procesando línea: 00:00:33.101 -> (3.3577711582, 3.3431084156, 3.3773214817, 3.3968720436, 3.3382208347, 3.2355816364)
# Procesando línea: 00:00:33.208 -> (3.3528835773, 3.3479959964, 3.3773214817, 3.3870968818, 3.3333332538, 3.2355816364)
# Procesando línea: 00:00:33.313 -> (3.3479959964, 3.3431084156, 3.3675463199, 3.3822093009, 3.3284456729, 3.2258064746)
# Procesando línea: 00:00:33.420 -> (3.3577711582, 3.3626587390, 3.3773214817, 3.3968720436, 3.3528835773, 3.2209188938)
# Procesando línea: 00:00:33.525 -> (3.3528835773, 3.3479959964, 3.3773214817, 3.3822093009, 3.3284456729, 3.2258064746)
# Procesando línea: 00:00:33.632 -> (3.3479959964, 3.3479959964, 3.3724339008, 3.3822093009, 3.3333332538, 3.2306940555)
# Procesando línea: 00:00:33.738 -> (3.3626587390, 3.3626587390, 3.3822093009, 3.3968720436, 3.3431084156, 3.2355816364)
# Procesando línea: 00:00:33.844 -> (3.3431084156, 3.3382208347, 3.3528835773, 3.3773214817, 3.3186705112, 3.2258064746)
# Procesando línea: 00:00:33.950 -> (3.3528835773, 3.3577711582, 3.3822093009, 3.3919844627, 3.3479959964, 3.2404692173)
# Procesando línea: 00:00:34.056 -> (3.3528835773, 3.3577711582, 3.3773214817, 3.3968720436, 3.3431084156, 3.2355816364)
# Procesando línea: 00:00:34.162 -> (3.3479959964, 3.3479959964, 3.3675463199, 3.3822093009, 3.3284456729, 3.2258064746)
# Procesando línea: 00:00:34.269 -> (3.3577711582, 3.3626587390, 3.3822093009, 3.3919844627, 3.3333332538, 3.2258064746)
# Procesando línea: 00:00:34.374 -> (3.3528835773, 3.3528835773, 3.3773214817, 3.3870968818, 3.3382208347, 3.2306940555)
# Procesando línea: 00:00:34.481 -> (3.3479959964, 3.3479959964, 3.3773214817, 3.3822093009, 3.3333332538, 3.2258064746)
# Procesando línea: 00:00:34.586 -> (3.3626587390, 3.3431084156, 3.3919844627, 3.3968720436, 3.3382208347, 3.2404692173)
# Procesando línea: 00:00:34.693 -> (3.3479959964, 3.3528835773, 3.3675463199, 3.3822093009, 3.3284456729, 3.2209188938)
# Procesando línea: 00:00:34.799 -> (3.3528835773, 3.3577711582, 3.3724339008, 3.3870968818, 3.3431084156, 3.2306940555)
# Procesando línea: 00:00:34.905 -> (3.3577711582, 3.3626587390, 3.3822093009, 3.3968720436, 3.3382208347, 3.2355816364)
# Procesando línea: 00:00:35.011 -> (3.3479959964, 3.3528835773, 3.3773214817, 3.3773214817, 3.3333332538, 3.2160313129)
# Procesando línea: 00:00:35.117 -> (3.3577711582, 3.3626587390, 3.3822093009, 3.3968720436, 3.3479959964, 3.2453567981)
# Procesando línea: 00:00:35.223 -> (3.3577711582, 3.3479959964, 3.3773214817, 3.3870968818, 3.3333332538, 3.2306940555)
# Procesando línea: 00:00:35.330 -> (3.3431084156, 3.3431084156, 3.3724339008, 3.3870968818, 3.3284456729, 3.2258064746)
# Procesando línea: 00:00:35.435 -> (3.3577711582, 3.3431084156, 3.3919844627, 3.3870968818, 3.3284456729, 3.2404692173)
# Procesando línea: 00:00:35.542 -> (3.3479959964, 3.3479959964, 3.3675463199, 3.3773214817, 3.3284456729, 3.2306940555)
# Procesando línea: 00:00:35.647 -> (3.3528835773, 3.3528835773, 3.3773214817, 3.3870968818, 3.3382208347, 3.2355816364)
# Procesando línea: 00:00:35.753 -> (3.3626587390, 3.3577711582, 3.3822093009, 3.3919844627, 3.3382208347, 3.2453567981)
# Procesando línea: 00:00:35.859 -> (3.3382208347, 3.3577711582, 3.3724339008, 3.3870968818, 3.3186705112, 3.2258064746)
# Procesando línea: 00:00:35.965 -> (3.3577711582, 3.3577711582, 3.3822093009, 3.3919844627, 3.3479959964, 3.2453567981)
# Procesando línea: 00:00:36.072 -> (3.3528835773, 3.3577711582, 3.3773214817, 3.3870968818, 3.3284456729, 3.2306940555)
# Procesando línea: 00:00:36.177 -> (3.3479959964, 3.3431084156, 3.3724339008, 3.3773214817, 3.3284456729, 3.2306940555)
# Procesando línea: 00:00:36.284 -> (3.3675463199, 3.3724339008, 3.3773214817, 3.4017596244, 3.3479959964, 3.2453567981)
# Procesando línea: 00:00:36.389 -> (3.3528835773, 3.3479959964, 3.3675463199, 3.3870968818, 3.3333332538, 3.2306940555)
# Procesando línea: 00:00:36.496 -> (3.3528835773, 3.3479959964, 3.3724339008, 3.3870968818, 3.3333332538, 3.2306940555)
# Procesando línea: 00:00:36.602 -> (3.3626587390, 3.3626587390, 3.3870968818, 3.3968720436, 3.3431084156, 3.2404692173)
# Procesando línea: 00:00:36.708 -> (3.3431084156, 3.3235580921, 3.3528835773, 3.3822093009, 3.3333332538, 3.2355816364)
# Procesando línea: 00:00:36.814 -> (3.3577711582, 3.3626587390, 3.3822093009, 3.3919844627, 3.3431084156, 3.2355816364)
# Procesando línea: 00:00:36.920 -> (3.3577711582, 3.3577711582, 3.3822093009, 3.3870968818, 3.3431084156, 3.2355816364)
# Procesando línea: 00:00:37.026 -> (3.3479959964, 3.3431084156, 3.3675463199, 3.3822093009, 3.3284456729, 3.2209188938)
# Procesando línea: 00:00:37.133 -> (3.3626587390, 3.3724339008, 3.3919844627, 3.3919844627, 3.3333332538, 3.2355816364)
# Procesando línea: 00:00:37.238 -> (3.3479959964, 3.3528835773, 3.3773214817, 3.3919844627, 3.3382208347, 3.2355816364)
# Procesando línea: 00:00:37.345 -> (3.3479959964, 3.3479959964, 3.3724339008, 3.3870968818, 3.3333332538, 3.2306940555)
# Procesando línea: 00:00:37.450 -> (3.3577711582, 3.3382208347, 3.3870968818, 3.3919844627, 3.3382208347, 3.2355816364)
# Procesando línea: 00:00:37.557 -> (3.3479959964, 3.3479959964, 3.3675463199, 3.3822093009, 3.3235580921, 3.2258064746)
# Procesando línea: 00:00:37.663 -> (3.3528835773, 3.3577711582, 3.3773214817, 3.3870968818, 3.3382208347, 3.2355816364)
# Procesando línea: 00:00:37.769 -> (3.3577711582, 3.3577711582, 3.3773214817, 3.3919844627, 3.3431084156, 3.2404692173)
# Procesando línea: 00:00:37.875 -> (3.3528835773, 3.3479959964, 3.3675463199, 3.3870968818, 3.3235580921, 3.2209188938)
# Procesando línea: 00:00:37.981 -> (3.3626587390, 3.3626587390, 3.3822093009, 3.3919844627, 3.3528835773, 3.2355816364)
# Procesando línea: 00:00:38.087 -> (3.3528835773, 3.3577711582, 3.3822093009, 3.3919844627, 3.3333332538, 3.2306940555)
# Procesando línea: 00:00:38.194 -> (3.3479959964, 3.3479959964, 3.3724339008, 3.3870968818, 3.3284456729, 3.2258064746)
# Procesando línea: 00:00:38.299 -> (3.3577711582, 3.3626587390, 3.3919844627, 3.4017596244, 3.3333332538, 3.2453567981)
# Procesando línea: 00:00:38.406 -> (3.3528835773, 3.3528835773, 3.3773214817, 3.3822093009, 3.3333332538, 3.2306940555)
# Procesando línea: 00:00:38.511 -> (3.3479959964, 3.3528835773, 3.3773214817, 3.3870968818, 3.3333332538, 3.2355816364)
# Procesando línea: 00:00:38.618 -> (3.3626587390, 3.3577711582, 3.3822093009, 3.3968720436, 3.3431084156, 3.2355816364)
# Procesando línea: 00:00:38.724 -> (3.3479959964, 3.3479959964, 3.3577711582, 3.3919844627, 3.3137829303, 3.2306940555)
# Procesando línea: 00:00:38.830 -> (3.3577711582, 3.3626587390, 3.3870968818, 3.3968720436, 3.3431084156, 3.2355816364)
# Procesando línea: 00:00:38.936 -> (3.3577711582, 3.3577711582, 3.3822093009, 3.3870968818, 3.3382208347, 3.2306940555)
# Procesando línea: 00:00:39.042 -> (3.3431084156, 3.3528835773, 3.3675463199, 3.3773214817, 3.3284456729, 3.2258064746)
# Procesando línea: 00:00:39.148 -> (3.3577711582, 3.3675463199, 3.3919844627, 3.3968720436, 3.3528835773, 3.2258064746)
# Procesando línea: 00:00:39.254 -> (3.3479959964, 3.3528835773, 3.3724339008, 3.3870968818, 3.3333332538, 3.2258064746)
# Procesando línea: 00:00:39.360 -> (3.3479959964, 3.3528835773, 3.3773214817, 3.3822093009, 3.3333332538, 3.2355816364)
# Procesando línea: 00:00:39.467 -> (3.3626587390, 3.3675463199, 3.3870968818, 3.3919844627, 3.3382208347, 3.2355816364)
# Procesando línea: 00:00:39.572 -> (3.3528835773, 3.3626587390, 3.3773214817, 3.3822093009, 3.3333332538, 3.2306940555)
# Procesando línea: 00:00:39.678 -> (3.3528835773, 3.3626587390, 3.3822093009, 3.3870968818, 3.3382208347, 3.2355816364)
# Procesando línea: 00:00:39.784 -> (3.3528835773, 3.3626587390, 3.3822093009, 3.3919844627, 3.3382208347, 3.2404692173)
# Procesando línea: 00:00:39.890 -> (3.3479959964, 3.3528835773, 3.3675463199, 3.3822093009, 3.3284456729, 3.2209188938)
# Procesando línea: 00:00:39.997 -> (3.3626587390, 3.3675463199, 3.3870968818, 3.4017596244, 3.3431084156, 3.2453567981)
# Procesando línea: 00:00:40.102 -> (3.3528835773, 3.3528835773, 3.3822093009, 3.3822093009, 3.3333332538, 3.2355816364)
# Procesando línea: 00:00:40.209 -> (3.3479959964, 3.3528835773, 3.3724339008, 3.3870968818, 3.3333332538, 3.2306940555)
# Procesando línea: 00:00:40.314 -> (3.3577711582, 3.3724339008, 3.3724339008, 3.3870968818, 3.3382208347, 3.2404692173)
# Procesando línea: 00:00:40.421 -> (3.3479959964, 3.3528835773, 3.3724339008, 3.3773214817, 3.3284456729, 3.2258064746)
# Procesando línea: 00:00:40.527 -> (3.3479959964, 3.3528835773, 3.3724339008, 3.3822093009, 3.3333332538, 3.2258064746)
# Procesando línea: 00:00:40.633 -> (3.3577711582, 3.3626587390, 3.3822093009, 3.3919844627, 3.3333332538, 3.2306940555)
# Procesando línea: 00:00:40.739 -> (3.3479959964, 3.3577711582, 3.3528835773, 3.3773214817, 3.3186705112, 3.2062561511)
# Procesando línea: 00:00:40.845 -> (3.3626587390, 3.3626587390, 3.3822093009, 3.3968720436, 3.3333332538, 3.2404692173)
# Procesando línea: 00:00:40.951 -> (3.3528835773, 3.3528835773, 3.3773214817, 3.3919844627, 3.3333332538, 3.2306940555)
# Procesando línea: 00:00:41.058 -> (3.3479959964, 3.3479959964, 3.3724339008, 3.3773214817, 3.3333332538, 3.2209188938)
# Procesando línea: 00:00:41.163 -> (3.3577711582, 3.3822093009, 3.3675463199, 3.3870968818, 3.3479959964, 3.2551319599)
# Procesando línea: 00:00:41.270 -> (3.3528835773, 3.3528835773, 3.3773214817, 3.3822093009, 3.3284456729, 3.2306940555)
# Procesando línea: 00:00:41.375 -> (3.3479959964, 3.3577711582, 3.3773214817, 3.3870968818, 3.3333332538, 3.2258064746)
# Procesando línea: 00:00:41.482 -> (3.3626587390, 3.3675463199, 3.3822093009, 3.3968720436, 3.3479959964, 3.2404692173)
# Procesando línea: 00:00:41.588 -> (3.3479959964, 3.3577711582, 3.3773214817, 3.3870968818, 3.3235580921, 3.2111437320)
# Procesando línea: 00:00:41.694 -> (3.3577711582, 3.3675463199, 3.3822093009, 3.3919844627, 3.3382208347, 3.2355816364)
# Procesando línea: 00:00:41.800 -> (3.3577711582, 3.3577711582, 3.3870968818, 3.3919844627, 3.3333332538, 3.2306940555)
# Procesando línea: 00:00:41.906 -> (3.3479959964, 3.3528835773, 3.3724339008, 3.3822093009, 3.3284456729, 3.2355816364)
# Procesando línea: 00:00:42.012 -> (3.3577711582, 3.3773214817, 3.3773214817, 3.3968720436, 3.3431084156, 3.2404692173)
# Procesando línea: 00:00:42.119 -> (3.3528835773, 3.3528835773, 3.3822093009, 3.3870968818, 3.3333332538, 3.2209188938)
# Procesando línea: 00:00:42.224 -> (3.3431084156, 3.3577711582, 3.3724339008, 3.3822093009, 3.3333332538, 3.2355816364)
# Procesando línea: 00:00:42.331 -> (3.3626587390, 3.3626587390, 3.3870968818, 3.3968720436, 3.3382208347, 3.2355816364)
# Procesando línea: 00:00:42.436 -> (3.3479959964, 3.3431084156, 3.3724339008, 3.3822093009, 3.3333332538, 3.2160313129)
# Procesando línea: 00:00:42.543 -> (3.3528835773, 3.3528835773, 3.3675463199, 3.3822093009, 3.3431084156, 3.2306940555)
# ...
# Procesando línea: 00:04:46.632 -> (3.2600195407, 3.2991201877, 3.3675463199, 3.3773214817, 3.2746822834, 3.2600195407)
# Procesando línea: 00:04:46.739 -> (3.2649071216, 3.3040077686, 3.3675463199, 3.3773214817, 3.2746822834, 3.2600195407)
# Procesando línea: 00:04:46.844 -> (3.2649071216, 3.3284456729, 3.3822093009, 3.3919844627, 3.2795698642, 3.2600195407)
# Procesando línea: 00:04:46.951 -> (3.2600195407, 3.2991201877, 3.3626587390, 3.3773214817, 3.2697947025, 3.2600195407)
# Procesando línea: 00:04:47.056 -> (3.2649071216, 3.3040077686, 3.3675463199, 3.3822093009, 3.2746822834, 3.2649071216)
# Procesando línea: 00:04:47.163 -> (3.2600195407, 3.2991201877, 3.3675463199, 3.3773214817, 3.2795698642, 3.2600195407)
# Procesando línea: 00:04:47.269 -> (3.2502443790, 3.2844574451, 3.3577711582, 3.3773214817, 3.2551319599, 3.2551319599)
# Procesando línea: 00:04:47.375 -> (3.2697947025, 3.3137829303, 3.3675463199, 3.3822093009, 3.2795698642, 3.2697947025)
# Procesando línea: 00:04:47.481 -> (3.2649071216, 3.3040077686, 3.3675463199, 3.3822093009, 3.2746822834, 3.2600195407)
# Procesando línea: 00:04:47.587 -> (3.2551319599, 3.3040077686, 3.3626587390, 3.3773214817, 3.2746822834, 3.2600195407)
# Procesando línea: 00:04:47.693 -> (3.2697947025, 3.3088953495, 3.3528835773, 3.3773214817, 3.2942326068, 3.2502443790)
# Procesando línea: 00:04:47.800 -> (3.2600195407, 3.3137829303, 3.3675463199, 3.3773214817, 3.2746822834, 3.2600195407)
# Procesando línea: 00:04:47.905 -> (3.2600195407, 3.3040077686, 3.3577711582, 3.3822093009, 3.2746822834, 3.2600195407)
# Procesando línea: 00:04:48.012 -> (3.2649071216, 3.3040077686, 3.3675463199, 3.3773214817, 3.2746822834, 3.2600195407)
# Procesando línea: 00:04:48.117 -> (3.2649071216, 3.3137829303, 3.3479959964, 3.3773214817, 3.2649071216, 3.2600195407)
# Procesando línea: 00:04:48.224 -> (3.2649071216, 3.2991201877, 3.3675463199, 3.3822093009, 3.2746822834, 3.2600195407)
# Procesando línea: 00:04:48.330 -> (3.2649071216, 3.3040077686, 3.3675463199, 3.3822093009, 3.2697947025, 3.2600195407)
# Procesando línea: 00:04:48.436 -> (3.2600195407, 3.3040077686, 3.3626587390, 3.3724339008, 3.2697947025, 3.2551319599)
# Procesando línea: 00:04:48.542 -> (3.2600195407, 3.3186705112, 3.3773214817, 3.3822093009, 3.2893450260, 3.2697947025)
# Procesando línea: 00:04:48.648 -> (3.2551319599, 3.3088953495, 3.3675463199, 3.3773214817, 3.2746822834, 3.2551319599)
# Procesando línea: 00:04:48.754 -> (3.2600195407, 3.3088953495, 3.3626587390, 3.3773214817, 3.2746822834, 3.2600195407)
# Procesando línea: 00:04:48.861 -> (3.2649071216, 3.3137829303, 3.3724339008, 3.3822093009, 3.2746822834, 3.2551319599)
# Procesando línea: 00:04:48.966 -> (3.2600195407, 3.2893450260, 3.3626587390, 3.3773214817, 3.2697947025, 3.2551319599)
# Procesando línea: 00:04:49.073 -> (3.2649071216, 3.3137829303, 3.3675463199, 3.3822093009, 3.2746822834, 3.2649071216)
# Procesando línea: 00:04:49.178 -> (3.2649071216, 3.3088953495, 3.3675463199, 3.3822093009, 3.2746822834, 3.2600195407)
# Procesando línea: 00:04:49.285 -> (3.2600195407, 3.3040077686, 3.3626587390, 3.3773214817, 3.2746822834, 3.2600195407)
# Procesando línea: 00:04:49.391 -> (3.2649071216, 3.3235580921, 3.3577711582, 3.3919844627, 3.2893450260, 3.2649071216)
# Procesando línea: 00:04:49.497 -> (3.2600195407, 3.3137829303, 3.3626587390, 3.3773214817, 3.2697947025, 3.2600195407)
# Procesando línea: 00:04:49.603 -> (3.2649071216, 3.3088953495, 3.3675463199, 3.3724339008, 3.2746822834, 3.2600195407)
# Procesando línea: 00:04:49.709 -> (3.2649071216, 3.3137829303, 3.3773214817, 3.3822093009, 3.2795698642, 3.2600195407)
# Procesando línea: 00:04:49.815 -> (3.2697947025, 3.3137829303, 3.3675463199, 3.3773214817, 3.2795698642, 3.2600195407)
# Procesando línea: 00:04:49.922 -> (3.2649071216, 3.3137829303, 3.3626587390, 3.3773214817, 3.2746822834, 3.2600195407)
# Procesando línea: 00:04:50.027 -> (3.2600195407, 3.3040077686, 3.3626587390, 3.3773214817, 3.2746822834, 3.2600195407)
# Procesando línea: 00:04:50.134 -> (3.2600195407, 3.3137829303, 3.3675463199, 3.3773214817, 3.2697947025, 3.2600195407)
# Procesando línea: 00:04:50.239 -> (3.2697947025, 3.2991201877, 3.3577711582, 3.3724339008, 3.2649071216, 3.2649071216)
# Procesando línea: 00:04:50.345 -> (3.2600195407, 3.3088953495, 3.3675463199, 3.3724339008, 3.2795698642, 3.2600195407)
# Procesando línea: 00:04:50.451 -> (3.2600195407, 3.3088953495, 3.3626587390, 3.3773214817, 3.2746822834, 3.2600195407)
# Procesando línea: 00:04:50.557 -> (3.2649071216, 3.3137829303, 3.3724339008, 3.3822093009, 3.2795698642, 3.2649071216)
# Procesando línea: 00:04:50.664 -> (3.2600195407, 3.3088953495, 3.3626587390, 3.3773214817, 3.2600195407, 3.2502443790)
# Procesando línea: 00:04:50.769 -> (3.2600195407, 3.3088953495, 3.3724339008, 3.3724339008, 3.2795698642, 3.2649071216)
# Procesando línea: 00:04:50.876 -> (3.2600195407, 3.3137829303, 3.3675463199, 3.3822093009, 3.2795698642, 3.2551319599)
# Procesando línea: 00:04:50.981 -> (3.2600195407, 3.2991201877, 3.3577711582, 3.3773214817, 3.2746822834, 3.2551319599)
# Procesando línea: 00:04:51.088 -> (3.2649071216, 3.3088953495, 3.3724339008, 3.3773214817, 3.2991201877, 3.2502443790)
# Procesando línea: 00:04:51.194 -> (3.2600195407, 3.3088953495, 3.3675463199, 3.3822093009, 3.2795698642, 3.2600195407)
# Procesando línea: 00:04:51.300 -> (3.2600195407, 3.3088953495, 3.3675463199, 3.3724339008, 3.2746822834, 3.2600195407)
# Procesando línea: 00:04:51.406 -> (3.2746822834, 3.2991201877, 3.3675463199, 3.3773214817, 3.2795698642, 3.2600195407)
# Procesando línea: 00:04:51.512 -> (3.2649071216, 3.3137829303, 3.3675463199, 3.3773214817, 3.2697947025, 3.2649071216)
# Procesando línea: 00:04:51.618 -> (3.2600195407, 3.3040077686, 3.3626587390, 3.3773214817, 3.2795698642, 3.2649071216)
# Procesando línea: 00:04:51.725 -> (3.2649071216, 3.3137829303, 3.3724339008, 3.3773214817, 3.2795698642, 3.2600195407)
# Procesando línea: 00:04:51.830 -> (3.2600195407, 3.3137829303, 3.3626587390, 3.3675463199, 3.2795698642, 3.2649071216)
# Procesando línea: 00:04:51.937 -> (3.2600195407, 3.3186705112, 3.3626587390, 3.3822093009, 3.2795698642, 3.2649071216)
# Procesando línea: 00:04:52.042 -> (3.2649071216, 3.3137829303, 3.3675463199, 3.3773214817, 3.2795698642, 3.2551319599)
# Procesando línea: 00:04:52.149 -> (3.2600195407, 3.3088953495, 3.3626587390, 3.3773214817, 3.2795698642, 3.2551319599)
# Procesando línea: 00:04:52.255 -> (3.2697947025, 3.3333332538, 3.3626587390, 3.3773214817, 3.2893450260, 3.2600195407)
# Procesando línea: 00:04:52.361 -> (3.2600195407, 3.3040077686, 3.3675463199, 3.3773214817, 3.2795698642, 3.2600195407)
# Procesando línea: 00:04:52.467 -> (3.2649071216, 3.3137829303, 3.3675463199, 3.3773214817, 3.2795698642, 3.2600195407)
# Procesando línea: 00:04:52.573 -> (3.2600195407, 3.3137829303, 3.3675463199, 3.3773214817, 3.2746822834, 3.2649071216)
# Procesando línea: 00:04:52.679 -> (3.2649071216, 3.3088953495, 3.3528835773, 3.3724339008, 3.2844574451, 3.2600195407)
# Procesando línea: 00:04:52.786 -> (3.2697947025, 3.3137829303, 3.3675463199, 3.3822093009, 3.2795698642, 3.2649071216)
# Procesando línea: 00:04:52.891 -> (3.2600195407, 3.3088953495, 3.3724339008, 3.3773214817, 3.2746822834, 3.2649071216)
# Procesando línea: 00:04:52.998 -> (3.2649071216, 3.3088953495, 3.3626587390, 3.3724339008, 3.2795698642, 3.2600195407)
# Procesando línea: 00:04:53.103 -> (3.2697947025, 3.3186705112, 3.3626587390, 3.3870968818, 3.2893450260, 3.2502443790)
# Procesando línea: 00:04:53.210 -> (3.2649071216, 3.3088953495, 3.3626587390, 3.3724339008, 3.2746822834, 3.2600195407)
# Procesando línea: 00:04:53.315 -> (3.2649071216, 3.3088953495, 3.3675463199, 3.3773214817, 3.2746822834, 3.2600195407)
# Procesando línea: 00:04:53.422 -> (3.2649071216, 3.3088953495, 3.3724339008, 3.3822093009, 3.2795698642, 3.2649071216)
# Procesando línea: 00:04:53.528 -> (3.2649071216, 3.3137829303, 3.3626587390, 3.3773214817, 3.2600195407, 3.2502443790)
# Procesando línea: 00:04:53.634 -> (3.2649071216, 3.3137829303, 3.3675463199, 3.3822093009, 3.2746822834, 3.2649071216)
# Procesando línea: 00:04:53.740 -> (3.2649071216, 3.3088953495, 3.3626587390, 3.3822093009, 3.2697947025, 3.2600195407)
# Procesando línea: 00:04:53.846 -> (3.2649071216, 3.3137829303, 3.3626587390, 3.3773214817, 3.2746822834, 3.2600195407)
# Procesando línea: 00:04:53.952 -> (3.2600195407, 3.3235580921, 3.3773214817, 3.3773214817, 3.2795698642, 3.2697947025)
# Procesando línea: 00:04:54.059 -> (3.2600195407, 3.3137829303, 3.3626587390, 3.3773214817, 3.2795698642, 3.2551319599)
# Procesando línea: 00:04:54.164 -> (3.2600195407, 3.3137829303, 3.3675463199, 3.3773214817, 3.2746822834, 3.2600195407)
# Procesando línea: 00:04:54.270 -> (3.2649071216, 3.3186705112, 3.3724339008, 3.3773214817, 3.2795698642, 3.2551319599)
# Procesando línea: 00:04:54.376 -> (3.2600195407, 3.3088953495, 3.3724339008, 3.3724339008, 3.2649071216, 3.2502443790)
# Procesando línea: 00:04:54.482 -> (3.2600195407, 3.3137829303, 3.3724339008, 3.3822093009, 3.2795698642, 3.2600195407)
# Procesando línea: 00:04:54.589 -> (3.2649071216, 3.3137829303, 3.3675463199, 3.3822093009, 3.2746822834, 3.2551319599)
# Procesando línea: 00:04:54.694 -> (3.2600195407, 3.3040077686, 3.3675463199, 3.3822093009, 3.2795698642, 3.2551319599)
# Procesando línea: 00:04:54.801 -> (3.2649071216, 3.3040077686, 3.3773214817, 3.3822093009, 3.2649071216, 3.2649071216)
# Procesando línea: 00:04:54.906 -> (3.2600195407, 3.3137829303, 3.3675463199, 3.3822093009, 3.2746822834, 3.2551319599)
# Procesando línea: 00:04:55.013 -> (3.2600195407, 3.3088953495, 3.3675463199, 3.3773214817, 3.2746822834, 3.2600195407)
# Procesando línea: 00:04:55.119 -> (3.2600195407, 3.2942326068, 3.3528835773, 3.3773214817, 3.2746822834, 3.2600195407)
# Procesando línea: 00:04:55.225 -> (3.2551319599, 3.3186705112, 3.3626587390, 3.3773214817, 3.2649071216, 3.2600195407)
# Procesando línea: 00:04:55.331 -> (3.2600195407, 3.3137829303, 3.3675463199, 3.3773214817, 3.2795698642, 3.2551319599)
# Procesando línea: 00:04:55.437 -> (3.2649071216, 3.3137829303, 3.3675463199, 3.3773214817, 3.2795698642, 3.2600195407)
# Procesando línea: 00:04:55.543 -> (3.2600195407, 3.2893450260, 3.3528835773, 3.3822093009, 3.2844574451, 3.2551319599)
# Procesando línea: 00:04:55.650 -> (3.2649071216, 3.3235580921, 3.3675463199, 3.3773214817, 3.2893450260, 3.2600195407)
# Procesando línea: 00:04:55.755 -> (3.2649071216, 3.3088953495, 3.3675463199, 3.3822093009, 3.2795698642, 3.2600195407)
# Procesando línea: 00:04:55.862 -> (3.2551319599, 3.3088953495, 3.3626587390, 3.3773214817, 3.2746822834, 3.2600195407)
# Procesando línea: 00:04:55.967 -> (3.2600195407, 3.3235580921, 3.3626587390, 3.3870968818, 3.2600195407, 3.2649071216)
# Procesando línea: 00:04:56.074 -> (3.2649071216, 3.3137829303, 3.3675463199, 3.3724339008, 3.2746822834, 3.2600195407)
# Procesando línea: 00:04:56.180 -> (3.2649071216, 3.3088953495, 3.3675463199, 3.3773214817, 3.2746822834, 3.2600195407)
# Procesando línea: 00:04:56.286 -> (3.2697947025, 3.3137829303, 3.3675463199, 3.3822093009, 3.2795698642, 3.2649071216)
# Procesando línea: 00:04:56.392 -> (3.2502443790, 3.2844574451, 3.3626587390, 3.3724339008, 3.2795698642, 3.2600195407)
# Procesando línea: 00:04:56.498 -> (3.2649071216, 3.3284456729, 3.3724339008, 3.3822093009, 3.2795698642, 3.2649071216)
# Procesando línea: 00:04:56.604 -> (3.2600195407, 3.3088953495, 3.3626587390, 3.3773214817, 3.2746822834, 3.2600195407)
# Procesando línea: 00:04:56.710 -> (3.2649071216, 3.3088953495, 3.3675463199, 3.3773214817, 3.2795698642, 3.2600195407)
# Procesando línea: 00:04:56.816 -> (3.2551319599, 3.2844574451, 3.3577711582, 3.3870968818, 3.2893450260, 3.2697947025)
# Procesando línea: 00:04:56.923 -> (3.2649071216, 3.3040077686, 3.3626587390, 3.3822093009, 3.2795698642, 3.2600195407)
# Procesando línea: 00:04:57.028 -> (3.2600195407, 3.3137829303, 3.3675463199, 3.3773214817, 3.2697947025, 3.2600195407)
# Procesando línea: 00:04:57.135 -> (3.2649071216, 3.3137829303, 3.3724339008, 3.3773214817, 3.2746822834, 3.2649071216)
# Procesando línea: 00:04:57.240 -> (3.2649071216, 3.3088953495, 3.3724339008, 3.3822093009, 3.2844574451, 3.2600195407)
# Procesando línea: 00:04:57.347 -> (3.2649071216, 3.3235580921, 3.3626587390, 3.3822093009, 3.2795698642, 3.2600195407)
# Procesando línea: 00:04:57.453 -> (3.2600195407, 3.3137829303, 3.3675463199, 3.3773214817, 3.2795698642, 3.2600195407)
# Procesando línea: 00:04:57.559 -> (3.2600195407, 3.3137829303, 3.3675463199, 3.3724339008, 3.2746822834, 3.2551319599)
# Procesando línea: 00:04:57.665 -> (3.2502443790, 3.2942326068, 3.3773214817, 3.3870968818, 3.2844574451, 3.2600195407)
# Procesando línea: 00:04:57.771 -> (3.2600195407, 3.3040077686, 3.3626587390, 3.3773214817, 3.2697947025, 3.2600195407)
# Procesando línea: 00:04:57.877 -> (3.2649071216, 3.3137829303, 3.3675463199, 3.3773214817, 3.2746822834, 3.2600195407)
# Procesando línea: 00:04:57.984 -> (3.2649071216, 3.3186705112, 3.3675463199, 3.3822093009, 3.2795698642, 3.2649071216)
# Procesando línea: 00:04:58.089 -> (3.2600195407, 3.2991201877, 3.3479959964, 3.3773214817, 3.2600195407, 3.2697947025)
# Procesando línea: 00:04:58.195 -> (3.2649071216, 3.3088953495, 3.3675463199, 3.3773214817, 3.2844574451, 3.2649071216)
# Procesando línea: 00:04:58.301 -> (3.2649071216, 3.3088953495, 3.3675463199, 3.3822093009, 3.2795698642, 3.2600195407)
# Procesando línea: 00:04:58.407 -> (3.2551319599, 3.3235580921, 3.3675463199, 3.3773214817, 3.2746822834, 3.2600195407)
# Procesando línea: 00:04:58.514 -> (3.2600195407, 3.3137829303, 3.3675463199, 3.3773214817, 3.2893450260, 3.2502443790)
# Procesando línea: 00:04:58.619 -> (3.2649071216, 3.3088953495, 3.3675463199, 3.3773214817, 3.2746822834, 3.2600195407)
# Procesando línea: 00:04:58.726 -> (3.2600195407, 3.3137829303, 3.3626587390, 3.3822093009, 3.2795698642, 3.2551319599)
# Procesando línea: 00:04:58.831 -> (3.2649071216, 3.3431084156, 3.3724339008, 3.3773214817, 3.2795698642, 3.2649071216)
# Procesando línea: 00:04:58.938 -> (3.2551319599, 3.3040077686, 3.3675463199, 3.3822093009, 3.2795698642, 3.2649071216)
# Procesando línea: 00:04:59.044 -> (3.2600195407, 3.3137829303, 3.3724339008, 3.3773214817, 3.2844574451, 3.2600195407)
# Procesando línea: 00:04:59.150 -> (3.2600195407, 3.3137829303, 3.3675463199, 3.3822093009, 3.2746822834, 3.2551319599)
# Procesando línea: 00:04:59.256 -> (3.2649071216, 3.2844574451, 3.3773214817, 3.3822093009, 3.2844574451, 3.2649071216)
# Procesando línea: 00:04:59.362 -> (3.2649071216, 3.3235580921, 3.3675463199, 3.3822093009, 3.2795698642, 3.2697947025)
# Procesando línea: 00:04:59.468 -> (3.2649071216, 3.3137829303, 3.3675463199, 3.3773214817, 3.2746822834, 3.2600195407)
# Procesando línea: 00:04:59.575 -> (3.2649071216, 3.3088953495, 3.3675463199, 3.3773214817, 3.2746822834, 3.2600195407)
# Procesando línea: 00:04:59.680 -> (3.2600195407, 3.2942326068, 3.3724339008, 3.3724339008, 3.2844574451, 3.2600195407)
# Procesando línea: 00:04:59.787 -> (3.2600195407, 3.3137829303, 3.3724339008, 3.3724339008, 3.2746822834, 3.2600195407)
# Procesando línea: 00:04:59.892 -> (3.2649071216, 3.3137829303, 3.3675463199, 3.3773214817, 3.2746822834, 3.2551319599)
# Procesando línea: 00:04:59.999 -> (3.2649071216, 3.3137829303, 3.3675463199, 3.3822093009, 3.2795698642, 3.2649071216)
# Procesando línea: 00:05:00.105 -> (3.2502443790, 3.2893450260, 3.3577711582, 3.3773214817, 3.2795698642, 3.2551319599)
# Procesando línea: 00:05:00.211 -> (3.2697947025, 3.3186705112, 3.3675463199, 3.3773214817, 3.2746822834, 3.2649071216)
# Procesando línea: 00:05:00.317 -> (3.2649071216, 3.3137829303, 3.3724339008, 3.3773214817, 3.2795698642, 3.2600195407)
# Procesando línea: 00:05:00.423 -> (3.2551319599, 3.3088953495, 3.3675463199, 3.3822093009, 3.2795698642, 3.2600195407)
# Formato actualizado en: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Roja\04medroja.txt
# Filtrando archivo: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Roja\04medroja.txt
# Archivo filtrado guardado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Roja\04medroja.txt

# %% [markdown]
# ## 2
#
# $$
#
#     \Huge \text{Curl File Generator}
#
# $$

# %%
#Rotacional .txt
import numpy as np
import os
from datetime import datetime, timedelta
import re

def read_sensor_data(filepath):
    data = []
    timestamps = []
    try:
        with open(filepath, 'r') as file:
            for line in file:
                parts = line.strip().split(' -> ')
                if len(parts) > 1:
                    timestamps.append(parts[0])
                    numbers = parts[1].strip('()').split(', ')
                    data.append([float(num) for num in numbers])
        return timestamps, np.array(data)
    except Exception as e:
        print(f"Error reading file {filepath}: {e}")
        return [], np.array([])

def calculate_curl(data):
    try:
        Dx = Dy = Dz = 1.0
        curl_x = (data[:, 1] - data[:, 0]) / Dx # (Trasero - Frontal) / Dx
        curl_y = (data[:, 3] - data[:, 2]) / Dy # (Derecha - Izquierda) / Dy
        curl_z = (data[:, 5] - data[:, 4]) / Dz # (Inferior - Superior) / Dz
        return np.array([curl_x, curl_y, curl_z]).T
    except Exception as e:
        print(f"Error calculating curl: {e}")
        return np.array([])

def adjust_timestamps(base_time, timestamps):
    try:
        base_datetime = datetime.strptime(base_time, '%H:%M:%S.%f')
        adjusted_timestamps = []
        for ts in timestamps:
            time_delta = datetime.strptime(ts, '%H:%M:%S.%f') - datetime.strptime('00:00:00.000', '%H:%M:%S.%f')
            new_datetime = base_datetime + time_delta
            adjusted_timestamps.append(new_datetime.strftime('%H:%M:%S.%f')[:-3])
        return adjusted_timestamps
    except Exception as e:
        print(f"Error adjusting timestamps: {e}")
        return []

def find_experiment_folder(root_folder, lab, shift):
    date_regex = re.compile(r'\d{2}[A-Za-z]{3}\d{2}')
    for folder in os.listdir(root_folder):
        if date_regex.search(folder) and lab in folder:
            for subfolder in os.listdir(os.path.join(root_folder, folder)):
                if date_regex.search(subfolder) and shift in subfolder:
                    return os.path.join(root_folder, folder, subfolder)
    return None

def process_files(input_folder, output_folder, base_times, file_suffixes=None):
    generated_files = []
    for root, dirs, files in os.walk(input_folder):
        dirs[:] = [d for d in dirs if "Data Analysis" not in os.path.join(root, d)]
        for filename in files:
            if "00" in filename:
                continue
            if file_suffixes:
                if not any(filename.endswith(suffix) for suffix in file_suffixes):
                    continue
            else:
                if not filename.endswith('mednegra.txt'):
                    continue
                
            file_path = os.path.join(root, filename)
            try:
                timestamps, data = read_sensor_data(file_path)
                if data.size == 0:
                    continue
                curls = calculate_curl(data)
                if curls.size == 0:
                    continue
            except Exception as e:
                print(f"Error processing file {file_path}: {e}")
                continue
            
            file_number = filename.split('mednegra.txt')[0][-2:] if not file_suffixes else filename[:2]
            adjusted_timestamps = adjust_timestamps(base_times.get(file_number, "00:00:00.000"), timestamps)

            output_filename = f"curl_{filename}"
            output_file_path = os.path.join(output_folder, output_filename)
            try:
                with open(output_file_path, "w") as f:
                    for i, curl in enumerate(curls):
                        f.write(f"{adjusted_timestamps[i]} -> ({curl[0]:.10f}, {curl[1]:.10f}, {curl[2]:.10f})\n")
                generated_files.append(output_filename)
            except Exception as e:
                print(f"Error writing file {output_file_path}: {e}")

    return generated_files

def process_lab(root_folder, lab_name, base_times, intervention_times):
    for shift in ['V', 'M']:
        shift_name = "Vespertino" if shift == 'V' else "Matutino"
        experiment_folder = find_experiment_folder(root_folder, lab_name, shift)
        if not experiment_folder:
            print(f"No experiment folder found for {lab_name}, {shift_name} shift.")
            continue
        
        print(f"Processing directory: {experiment_folder}")

        # Procesar la línea base
        output_folder = os.path.join(experiment_folder, "Data Analysis", "Processing Data", "Curl_Baseline")
        os.makedirs(output_folder, exist_ok=True)
        generated_files = process_files(experiment_folder, output_folder, base_times)
        
        print(f"Generated files for {lab_name}, {shift_name} shift Baseline:")
        for file in generated_files:
            print(f"  - {file}")

        # Procesar las intervenciones
        output_folder = os.path.join(experiment_folder, "Data Analysis", "Processing Data", "Curl_Experimental_Color")
        os.makedirs(output_folder, exist_ok=True)
        file_suffixes = ["medroja.txt", "medmorada.txt", "medazul.txt", "medverde.txt", "medamarilla.txt"]
        generated_files = process_files(experiment_folder, output_folder, intervention_times, file_suffixes)
        
        print(f"Generated files for {lab_name}, {shift_name} shift Experimental:")
        for file in generated_files:
            print(f"  - {file}")



# Procesar todos los laboratorios y turnos
labs = {
    "Lab_Betta": {
        "base_times": lab_a_matutino_base_times,
        "intervention_times": lab_a_matutino_intervention_times,
    }  ,
    "Lab_Gamma": {
        "base_times": lab_b_matutino_base_times,
        "intervention_times": lab_b_matutino_intervention_times,
    }
}



for lab_name, times in labs.items():
    process_lab(root_folder, lab_name, times["base_times"], times["intervention_times"])
# Out:
# No experiment folder found for Lab_Betta, Vespertino shift.
# No experiment folder found for Lab_Betta, Matutino shift.
# No experiment folder found for Lab_Gamma, Vespertino shift.
# Processing directory: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma
# Generated files for Lab_Gamma, Matutino shift Baseline:
#   - curl_01mednegra.txt
#   - curl_02mednegra.txt
#   - curl_03mednegra.txt
#   - curl_04mednegra.txt
#   - curl_05mednegra.txt
# Generated files for Lab_Gamma, Matutino shift Experimental:
#   - curl_01medamarilla.txt
#   - curl_02medroja.txt
#   - curl_03medroja.txt
#   - curl_04medroja.txt

# %% [markdown]
# ## 3
#
# $$
#
#     \Huge \text{Moduli Curl File Generator}
#
# $$

# %%
#Magnitud rotacional.txt
import numpy as np
import os
from datetime import datetime, timedelta
import re

def read_sensor_data(filepath):
    data = []
    timestamps = []
    with open(filepath, 'r') as file:
        for line in file:
            parts = line.strip().split(' -> ')
            if len(parts) > 1:
                timestamps.append(parts[0])
                numbers = parts[1].strip('()').split(', ')
                data.append([float(num) for num in numbers])
    return timestamps, np.array(data)

def calculate_magnitude(data):
    return np.linalg.norm(data, axis=1)

def adjust_timestamps(base_time, timestamps):
    base_datetime = datetime.strptime(base_time, '%H:%M:%S.%f')
    adjusted_timestamps = []
    for ts in timestamps:
        time_delta = datetime.strptime(ts, '%H:%M:%S.%f') - datetime.strptime('00:00:00.000', '%H:%M:%S.%f')
        new_datetime = base_datetime + time_delta
        adjusted_timestamps.append(new_datetime.strftime('%H:%M:%S.%f')[:-3])
    return adjusted_timestamps

def process_files(input_folder, output_folder, base_times, file_suffixes=None):
    generated_files = []  # Lista para almacenar los nombres de los archivos generados
    for root, dirs, files in os.walk(input_folder):
        dirs[:] = [d for d in dirs if "Data Analysis" not in os.path.join(root, d)]  # Excluir directorios que contienen 'Data Analysis'
        for filename in files:
            if "00" in filename:  # Omitir archivos con "00" en el nombre
                continue
            if file_suffixes:
                if not any(filename.endswith(suffix) for suffix in file_suffixes):
                    continue
            else:
                if not filename.endswith('mednegra.txt'):
                    continue
                
            file_path = os.path.join(root, filename)
            try:
                timestamps, data = read_sensor_data(file_path)
                magnitudes = calculate_magnitude(data)
            except Exception as e:
                print(f"Error processing file {file_path}: {e}")
                continue
            
            file_number = filename.split('mednegra.txt')[0][-2:] if not file_suffixes else filename[:2]
            adjusted_timestamps = adjust_timestamps(base_times.get(file_number, "00:00:00.000"), timestamps)

            magnitude_filename = f"magnitude_{filename}"
            magnitude_file_path = os.path.join(output_folder, magnitude_filename)
            try:
                with open(magnitude_file_path, "w") as f:
                    for i, magnitude in enumerate(magnitudes):
                        f.write(f"{adjusted_timestamps[i]} -> {magnitude:.10f}\n")
                generated_files.append(magnitude_filename)  # Agregar el nombre del archivo generado a la lista
            except Exception as e:
                print(f"Error writing file {magnitude_file_path}: {e}")

    return generated_files  # Devolver la lista de archivos generados

def find_experiment_folder(root_folder, lab, shift):
    date_regex = re.compile(r'\d{2}[A-Za-z]{3}\d{2}')
    for folder in os.listdir(root_folder):
        if date_regex.search(folder) and lab in folder:
            for subfolder in os.listdir(os.path.join(root_folder, folder)):
                if date_regex.search(subfolder) and shift in subfolder:
                    return os.path.join(root_folder, folder, subfolder), date_regex.search(folder).group(0)
    return None, None

def process_lab(root_folder, lab_name, base_times, intervention_times):
    for shift in ['V', 'M']:
        shift_name = "Vespertino" if shift == 'V' else "Matutino"
        experiment_folder, date_str = find_experiment_folder(root_folder, lab_name, shift)
        if not experiment_folder:
            print(f"No se encontró ningún directorio para {lab_name}, {shift}.")
            continue

        input_folder = experiment_folder
        if not os.path.exists(input_folder):
            continue
        
        # Procesar la línea base
        output_folder = os.path.join(input_folder, "Data Analysis", "Processing Data", "Moduli_Curl_Baseline")
        os.makedirs(output_folder, exist_ok=True)
        generated_files = process_files(input_folder, output_folder, base_times)
        
        print(f"Generated files for {lab_name}, {shift_name} shift Baseline:")
        for file in generated_files:
            print(f"  - {file}")

        # Procesar las intervenciones
        output_folder = os.path.join(input_folder, "Data Analysis", "Processing Data", "Moduli_Curl_Experimental_Color")
        os.makedirs(output_folder, exist_ok=True)
        file_suffixes = ["medroja.txt", "medmorada.txt", "medazul.txt", "medverde.txt", "medamarilla.txt", "mednaranja.txt"]
        generated_files = process_files(input_folder, output_folder, intervention_times, file_suffixes)
        
        print(f"Generated files for {lab_name}, {shift_name} shift Experimental:")
        for file in generated_files:
            print(f"  - {file}")


# Procesar todos los laboratorios y turnos
labs = {
    "Lab_Betta": {
        "base_times": lab_a_matutino_base_times,
        "intervention_times": lab_a_matutino_intervention_times,
    }  
,
    "Lab_Gamma": {
        "base_times": lab_b_matutino_base_times,
        "intervention_times": lab_b_matutino_intervention_times,
    }
}

for lab_name, times in labs.items():
    process_lab(root_folder, lab_name, times["base_times"], times["intervention_times"])
# Out:
# No se encontró ningún directorio para Lab_Betta, V.
# No se encontró ningún directorio para Lab_Betta, M.
# No se encontró ningún directorio para Lab_Gamma, V.
# Generated files for Lab_Gamma, Matutino shift Baseline:
#   - magnitude_01mednegra.txt
#   - magnitude_02mednegra.txt
#   - magnitude_03mednegra.txt
#   - magnitude_04mednegra.txt
#   - magnitude_05mednegra.txt
# Generated files for Lab_Gamma, Matutino shift Experimental:
#   - magnitude_01medamarilla.txt
#   - magnitude_02medroja.txt
#   - magnitude_03medroja.txt
#   - magnitude_04medroja.txt

# %% [markdown]
# ## 4
#
# $$
#
#     \Huge \text{General Velocity File Generator}
#
# $$

# %%
#Código requsito previo para correr el código de las 12 triadas de velocidad-------------- Velocidad.txt (no triadas)
import numpy as np
import os
from datetime import datetime, timedelta
import re

def read_sensor_data(filepath):
    data = []
    timestamps = []
    try:
        with open(filepath, 'r') as file:
            for line in file:
                parts = line.strip().split(' -> ')
                if len(parts) > 1:
                    timestamps.append(parts[0])  # Guardar marca de tiempo
                    numbers = parts[1].strip('()').split(', ')
                    data.append([float(num) for num in numbers])
        return timestamps, np.array(data)
    except Exception as e:
        print(f"Error reading file {filepath}: {e}")
        return [], np.array([])

def calculate_velocities(data, delta_t):
    # Calcular velocidades usando diferencias hacia adelante
    velocities = (data[1:] - data[:-1]) / delta_t
    return velocities

def adjust_timestamps(base_time, timestamps):
    try:
        base_datetime = datetime.strptime(base_time, '%H:%M:%S.%f')
        adjusted_timestamps = []
        for ts in timestamps[:-1]:  # Excluir la última marca de tiempo
            current_time = datetime.strptime(ts, '%H:%M:%S.%f')
            adjusted_time = base_datetime + (current_time - datetime.strptime(timestamps[0], '%H:%M:%S.%f'))
            adjusted_timestamps.append(adjusted_time.strftime('%H:%M:%S.%f')[:-3])
        return adjusted_timestamps
    except Exception as e:
        print(f"Error adjusting timestamps: {e}")
        return []

def find_experiment_folder(root_folder, lab, shift):
    date_regex = re.compile(r'\d{2}[A-Za-z]{3}\d{2}')
    for folder in os.listdir(root_folder):
        if date_regex.search(folder) and lab in folder:
            for subfolder in os.listdir(os.path.join(root_folder, folder)):
                if date_regex.search(subfolder) and shift in subfolder:
                    return os.path.join(root_folder, folder, subfolder), date_regex.search(folder).group(0)
    return None, None

def process_files(input_folder, output_folder, delta_t, base_times, file_suffixes=None):
    os.makedirs(output_folder, exist_ok=True)  # Asegurar que el directorio de salida exista
    generated_files = []  # Lista para almacenar los nombres de los archivos generados

    for root, dirs, files in os.walk(input_folder):
        dirs[:] = [d for d in dirs if "Data Analysis" not in os.path.join(root, d)]  # Excluir directorios que contienen 'Data Analysis'
        for filename in files:
            if "00" in filename:  # Omitir archivos con "00" en el nombre
                continue
            if file_suffixes:
                if not any(filename.endswith(suffix) for suffix in file_suffixes):
                    continue
            else:
                if not filename.endswith('mednegra.txt'):
                    continue
                
            file_path = os.path.join(root, filename)
            try:
                timestamps, data = read_sensor_data(file_path)
                if data.size == 0:
                    continue
                velocities = calculate_velocities(data, delta_t)
            except Exception as e:
                print(f"Error processing file {file_path}: {e}")
                continue
            
            file_number = filename.split('mednegra.txt')[0][-2:] if not file_suffixes else filename[:2]
            adjusted_timestamps = adjust_timestamps(base_times.get(file_number, "00:00:00.000"), timestamps)

            output_filename = f"velocity_{filename}"
            output_file_path = os.path.join(output_folder, output_filename)
            try:
                with open(output_file_path, "w") as f:
                    for i, velocity in enumerate(velocities):
                        f.write(f"{adjusted_timestamps[i]} -> ({velocity[0]:.10f}, {velocity[1]:.10f}, {velocity[2]:.10f}, {velocity[3]:.10f}, {velocity[4]:.10f}, {velocity[5]:.10f})\n")
                generated_files.append(output_filename)  # Agregar el nombre del archivo generado a la lista
            except Exception as e:
                print(f"Error writing file {output_file_path}: {e}")

    return generated_files  # Devolver la lista de archivos generados

def process_lab(root_folder, lab_name, base_times, intervention_times, delta_t):
    for shift in ['V', 'M']:
        shift_name = "Vespertino" if shift == 'V' else "Matutino"
        experiment_folder, date_str = find_experiment_folder(root_folder, lab_name, shift)
        if not experiment_folder:
            print(f"No se encontró ningún directorio para {lab_name}, {shift}.")
            continue
        
        # Procesar la línea base
        output_folder = os.path.join(experiment_folder, "Data Analysis", "Processing Data", "Velocity_Baseline")
        os.makedirs(output_folder, exist_ok=True)
        generated_files = process_files(experiment_folder, output_folder, delta_t, base_times)
        
        print(f"Generated files for {lab_name}, {shift_name} shift Baseline:")
        for file in generated_files:
            print(f"  - {file}")

        # Procesar las intervenciones
        output_folder = os.path.join(experiment_folder, "Data Analysis", "Processing Data", "Velocity_Experimental_Color")
        os.makedirs(output_folder, exist_ok=True)
        file_suffixes = ["medroja.txt", "medmorada.txt", "medazul.txt", "medverde.txt", "medamarilla.txt"]
        generated_files = process_files(experiment_folder, output_folder, delta_t, intervention_times, file_suffixes)
        
        print(f"Generated files for {lab_name}, {shift_name} shift Experimental:")
        for file in generated_files:
            print(f"  - {file}")



# Procesar todos los laboratorios y turnos
labs = {
    "Lab_Betta": {
        "base_times": lab_a_matutino_base_times,
        "intervention_times": lab_a_matutino_intervention_times,
    }  
,
    "Lab_Gamma": {
        "base_times": lab_b_matutino_base_times,
        "intervention_times": lab_b_matutino_intervention_times,
    }

}
delta_t = 0.01  # Paso de tiempo para el cálculo de velocidades

for lab_name, times in labs.items():
    process_lab(root_folder, lab_name, times["base_times"], times["intervention_times"], delta_t)
# Out:
# No se encontró ningún directorio para Lab_Betta, V.
# No se encontró ningún directorio para Lab_Betta, M.
# No se encontró ningún directorio para Lab_Gamma, V.
# Generated files for Lab_Gamma, Matutino shift Baseline:
#   - velocity_01mednegra.txt
#   - velocity_02mednegra.txt
#   - velocity_03mednegra.txt
#   - velocity_04mednegra.txt
#   - velocity_05mednegra.txt
# Generated files for Lab_Gamma, Matutino shift Experimental:
#   - velocity_01medamarilla.txt
#   - velocity_02medroja.txt
#   - velocity_03medroja.txt
#   - velocity_04medroja.txt

# %% [markdown]
# ## 5
#
# $$
#
#     \Huge \text{Velocity Generator by Triad}
#
# $$

# %%
#Calculo de velocidades por triada .txt
import os

def extract_velocity_components(root_folder):
    generated_files = []  # Lista para almacenar los nombres de los archivos generados
    
    triad_codes = {
        (0, 2, 4): "FRT",  
        (1, 3, 5): "PLB",  
        (0, 3, 4): "FLT",  
        (1, 2, 5): "PRB",  
        (0, 2, 5): "FRB",  
        (1, 3, 4): "PLT",  
        (0, 3, 5): "FLB",  
        (1, 2, 4): "PRT",  
        (2, 4, 5): "RTB",  
        (0, 1, 3): "FLP",  
        (3, 4, 5): "LTB",  
        (0, 1, 2): "FRP"
    }
    
    for root, dirs, files in os.walk(root_folder):
        if "Velocity_Baseline" in root or "Velocity_Experimental_Color" in root:
            # Usar la carpeta actual, sin agregar '_Component'
            new_folder = root
            
            # Iterar sobre cada archivo en la carpeta original
            for filename in files:
                if filename.startswith("v") and filename.endswith(".txt"):
                    path = os.path.join(root, filename)
                    
                    with open(path, 'r') as file:
                        file_content = file.readlines()  # Leer todo el contenido una vez
                        
                        # Generar archivos por cada triada y usando su código del diccionario
                        for triad, code in triad_codes.items():
                            triad_folder = os.path.join(new_folder, code)
                            os.makedirs(triad_folder, exist_ok=True)  # Crear la carpeta de la triada si no existe
                            new_path = os.path.join(triad_folder, f"Velocity_{code}_" + filename)
                            
                            with open(new_path, 'w') as triad_file:
                                for line in file_content:
                                    time_stamp, velocities = line.strip().split(' -> ')
                                    v = eval(velocities)
                                    selected_components = tuple(v[j] for j in triad)
                                    triad_file.write(f"{time_stamp} -> {selected_components}\n")
                            
                            # Almacenar solo el nombre de la carpeta de cabecera y los nombres de los archivos generados
                            header_folder = os.path.basename(triad_folder)
                            file_name = os.path.basename(new_path)
                            generated_files.append(f"{header_folder}/{file_name}")

    return generated_files  # Devolver la lista de archivos generados

# La ruta base donde están las carpetas de origen
generated_files = extract_velocity_components(root_folder)

# Imprimir los nombres de los archivos generados
print("Generated files:")
for file in generated_files:
    print(f"  - {file}")
# Out:
# Generated files:
#   - FRT/Velocity_FRT_velocity_01mednegra.txt
#   - PLB/Velocity_PLB_velocity_01mednegra.txt
#   - FLT/Velocity_FLT_velocity_01mednegra.txt
#   - PRB/Velocity_PRB_velocity_01mednegra.txt
#   - FRB/Velocity_FRB_velocity_01mednegra.txt
#   - PLT/Velocity_PLT_velocity_01mednegra.txt
#   - FLB/Velocity_FLB_velocity_01mednegra.txt
#   - PRT/Velocity_PRT_velocity_01mednegra.txt
#   - RTB/Velocity_RTB_velocity_01mednegra.txt
#   - FLP/Velocity_FLP_velocity_01mednegra.txt
#   - LTB/Velocity_LTB_velocity_01mednegra.txt
#   - FRP/Velocity_FRP_velocity_01mednegra.txt
#   - FRT/Velocity_FRT_velocity_02mednegra.txt
#   - PLB/Velocity_PLB_velocity_02mednegra.txt
#   - FLT/Velocity_FLT_velocity_02mednegra.txt
#   - PRB/Velocity_PRB_velocity_02mednegra.txt
#   - FRB/Velocity_FRB_velocity_02mednegra.txt
#   - PLT/Velocity_PLT_velocity_02mednegra.txt
#   - FLB/Velocity_FLB_velocity_02mednegra.txt
#   - PRT/Velocity_PRT_velocity_02mednegra.txt
#   - RTB/Velocity_RTB_velocity_02mednegra.txt
#   - FLP/Velocity_FLP_velocity_02mednegra.txt
#   - LTB/Velocity_LTB_velocity_02mednegra.txt
#   - FRP/Velocity_FRP_velocity_02mednegra.txt
#   - FRT/Velocity_FRT_velocity_03mednegra.txt
#   - PLB/Velocity_PLB_velocity_03mednegra.txt
#   - FLT/Velocity_FLT_velocity_03mednegra.txt
#   - PRB/Velocity_PRB_velocity_03mednegra.txt
#   - FRB/Velocity_FRB_velocity_03mednegra.txt
#   - PLT/Velocity_PLT_velocity_03mednegra.txt
#   - FLB/Velocity_FLB_velocity_03mednegra.txt
#   - PRT/Velocity_PRT_velocity_03mednegra.txt
#   - RTB/Velocity_RTB_velocity_03mednegra.txt
#   - FLP/Velocity_FLP_velocity_03mednegra.txt
#   - LTB/Velocity_LTB_velocity_03mednegra.txt
#   - FRP/Velocity_FRP_velocity_03mednegra.txt
#   - FRT/Velocity_FRT_velocity_04mednegra.txt
#   - PLB/Velocity_PLB_velocity_04mednegra.txt
#   - FLT/Velocity_FLT_velocity_04mednegra.txt
#   - PRB/Velocity_PRB_velocity_04mednegra.txt
#   - FRB/Velocity_FRB_velocity_04mednegra.txt
#   - PLT/Velocity_PLT_velocity_04mednegra.txt
#   - FLB/Velocity_FLB_velocity_04mednegra.txt
#   - PRT/Velocity_PRT_velocity_04mednegra.txt
#   - RTB/Velocity_RTB_velocity_04mednegra.txt
#   - FLP/Velocity_FLP_velocity_04mednegra.txt
#   - LTB/Velocity_LTB_velocity_04mednegra.txt
#   - FRP/Velocity_FRP_velocity_04mednegra.txt
#   - FRT/Velocity_FRT_velocity_05mednegra.txt
#   - PLB/Velocity_PLB_velocity_05mednegra.txt
#   - FLT/Velocity_FLT_velocity_05mednegra.txt
#   - PRB/Velocity_PRB_velocity_05mednegra.txt
#   - FRB/Velocity_FRB_velocity_05mednegra.txt
#   - PLT/Velocity_PLT_velocity_05mednegra.txt
#   - FLB/Velocity_FLB_velocity_05mednegra.txt
#   - PRT/Velocity_PRT_velocity_05mednegra.txt
#   - RTB/Velocity_RTB_velocity_05mednegra.txt
#   - FLP/Velocity_FLP_velocity_05mednegra.txt
#   - LTB/Velocity_LTB_velocity_05mednegra.txt
#   - FRP/Velocity_FRP_velocity_05mednegra.txt
#   - FRT/Velocity_FRT_velocity_01medamarilla.txt
#   - PLB/Velocity_PLB_velocity_01medamarilla.txt
#   - FLT/Velocity_FLT_velocity_01medamarilla.txt
#   - PRB/Velocity_PRB_velocity_01medamarilla.txt
#   - FRB/Velocity_FRB_velocity_01medamarilla.txt
#   - PLT/Velocity_PLT_velocity_01medamarilla.txt
#   - FLB/Velocity_FLB_velocity_01medamarilla.txt
#   - PRT/Velocity_PRT_velocity_01medamarilla.txt
#   - RTB/Velocity_RTB_velocity_01medamarilla.txt
#   - FLP/Velocity_FLP_velocity_01medamarilla.txt
#   - LTB/Velocity_LTB_velocity_01medamarilla.txt
#   - FRP/Velocity_FRP_velocity_01medamarilla.txt
#   - FRT/Velocity_FRT_velocity_02medroja.txt
#   - PLB/Velocity_PLB_velocity_02medroja.txt
#   - FLT/Velocity_FLT_velocity_02medroja.txt
#   - PRB/Velocity_PRB_velocity_02medroja.txt
#   - FRB/Velocity_FRB_velocity_02medroja.txt
#   - PLT/Velocity_PLT_velocity_02medroja.txt
#   - FLB/Velocity_FLB_velocity_02medroja.txt
#   - PRT/Velocity_PRT_velocity_02medroja.txt
#   - RTB/Velocity_RTB_velocity_02medroja.txt
#   - FLP/Velocity_FLP_velocity_02medroja.txt
#   - LTB/Velocity_LTB_velocity_02medroja.txt
#   - FRP/Velocity_FRP_velocity_02medroja.txt
#   - FRT/Velocity_FRT_velocity_03medroja.txt
#   - PLB/Velocity_PLB_velocity_03medroja.txt
#   - FLT/Velocity_FLT_velocity_03medroja.txt
#   - PRB/Velocity_PRB_velocity_03medroja.txt
#   - FRB/Velocity_FRB_velocity_03medroja.txt
#   - PLT/Velocity_PLT_velocity_03medroja.txt
#   - FLB/Velocity_FLB_velocity_03medroja.txt
#   - PRT/Velocity_PRT_velocity_03medroja.txt
#   - RTB/Velocity_RTB_velocity_03medroja.txt
#   - FLP/Velocity_FLP_velocity_03medroja.txt
#   - LTB/Velocity_LTB_velocity_03medroja.txt
#   - FRP/Velocity_FRP_velocity_03medroja.txt
#   - FRT/Velocity_FRT_velocity_04medroja.txt
#   - PLB/Velocity_PLB_velocity_04medroja.txt
#   - FLT/Velocity_FLT_velocity_04medroja.txt
#   - PRB/Velocity_PRB_velocity_04medroja.txt
#   - FRB/Velocity_FRB_velocity_04medroja.txt
#   - PLT/Velocity_PLT_velocity_04medroja.txt
#   - FLB/Velocity_FLB_velocity_04medroja.txt
#   - PRT/Velocity_PRT_velocity_04medroja.txt
#   - RTB/Velocity_RTB_velocity_04medroja.txt
#   - FLP/Velocity_FLP_velocity_04medroja.txt
#   - LTB/Velocity_LTB_velocity_04medroja.txt
#   - FRP/Velocity_FRP_velocity_04medroja.txt

# %% [markdown]
# ## 6
#
# $$
#
#     \Huge \text{Vorticity File Generator}
#
# $$

# %%
#Vorticidad .txt
import os
import numpy as np
import re

def read_velocity_data(filepath):
    data = []
    timestamps = []
    try:
        with open(filepath, 'r') as file:
            for line in file:
                parts = line.strip().split(' -> ')
                if len(parts) > 1:
                    timestamps.append(parts[0])  # Guardar timestamps directamente del archivo
                    velocity_components = parts[1].strip('()').split(', ')
                    if len(velocity_components) == 6:  # Asegurarse de que haya 6 componentes
                        data.append([float(v) for v in velocity_components])
        return timestamps, np.array(data)
    except Exception as e:
        print(f"Error reading file {filepath}: {e}")
        return [], np.array([])

def calculate_vorticity(velocities, indices):
    if velocities.ndim != 2 or velocities.shape[1] != 3:
        print(f"velocities.ndim: {velocities.ndim}, velocities.shape: {velocities.shape}")
        raise ValueError("El array de velocidades debe ser bidimensional con tres columnas.")
    
    Vx, Vy, Vz = indices
    dvz_dy = np.gradient(velocities[:, Vz], axis=0)
    dvy_dz = np.gradient(velocities[:, Vy], axis=0)
    dvx_dz = np.gradient(velocities[:, Vx], axis=0)
    dvz_dx = np.gradient(velocities[:, Vz], axis=0)
    dvy_dx = np.gradient(velocities[:, Vy], axis=0)
    dvx_dy = np.gradient(velocities[:, Vx], axis=0)

    omega_x = dvz_dy - dvy_dz
    omega_y = dvx_dz - dvz_dx
    omega_z = dvy_dx - dvx_dy

    return np.array([omega_x, omega_y, omega_z]).T

def save_vorticity_with_timestamps(timestamps, vorticities, filename):
    os.makedirs(os.path.dirname(filename), exist_ok=True)  # Crear el directorio si no existe
    print(f"Saving vorticity data to: {filename}")
    
    try:
        with open(filename, 'w') as f:
            for ts, vort in zip(timestamps, vorticities):
                formatted_output = f"{ts} -> ({vort[0]:.10f}, {vort[1]:.10f}, {vort[2]:.10f})\n"
                f.write(formatted_output)
    except Exception as e:
        print(f"Error writing file {filename}: {e}")

def process_files(input_folder, output_folder, file_suffixes, triads):
    if not os.path.exists(input_folder):
        print(f"Input folder does not exist: {input_folder}")
        return []
    
    generated_files = []  # Lista para almacenar los nombres de los archivos generados
    
    for filename in os.listdir(input_folder):
        if any(filename.endswith(suffix) for suffix in file_suffixes):
            filepath = os.path.join(input_folder, filename)
            print(f"Processing file: {filepath}")
            timestamps, velocities = read_velocity_data(filepath)
            
            if velocities.ndim != 2 or velocities.shape[1] != 6:
                print(f"El archivo {filename} no contiene datos de velocidad válidos. Dimensiones: {velocities.shape}")
                continue
            
            for triad in triads:
                if triad in triad_codes:
                    code = triad_codes[triad]
                    triad_folder = os.path.join(output_folder, code)
                    os.makedirs(triad_folder, exist_ok=True)  # Crear carpeta para la triada si no existe
                    velocities_triad = velocities[:, triad]
                    
                    print(f"Calculating vorticity for triad {code}: {filename}")
                    vorticity = calculate_vorticity(velocities_triad, [0, 1, 2])
                    
                    output_file = f"vorticity_{code}_{filename}"
                    save_vorticity_with_timestamps(timestamps, vorticity, os.path.join(triad_folder, output_file))
                    
                    generated_files.append(f"{os.path.basename(triad_folder)}/{output_file}")

    return generated_files  # Devolver la lista de archivos generados

def find_experiment_folder(root_folder, lab, shift):
    date_regex = re.compile(r'\d{2}[A-Za-z]{3}\d{2}')
    for folder in os.listdir(root_folder):
        if date_regex.search(folder) and lab in folder:
            for subfolder in os.listdir(os.path.join(root_folder, folder)):
                if date_regex.search(subfolder) and shift in subfolder:
                    return os.path.join(root_folder, folder, subfolder), date_regex.search(folder).group(0)
    return None, None

def process_lab(root_folder, lab_name, file_suffixes, triads):
    for shift in ['V', 'M']:
        shift_name = "Vespertino" if shift == 'V' else "Matutino"
        experiment_folder, date_str = find_experiment_folder(root_folder, lab_name, shift)
        if not experiment_folder:
            print(f"No se encontró ningún directorio para {lab_name}, {shift}.")
            continue

        input_folder_base = os.path.join(experiment_folder, "Data Analysis", "Processing Data")
        
        # Procesar la línea base
        input_folder = os.path.join(input_folder_base, "Velocity_Baseline")
        output_folder = os.path.join(input_folder_base, "Vorticity_Baseline")
        generated_files = process_files(input_folder, output_folder, file_suffixes, triads)
        print(f"Generated vorticity files for {lab_name}, {shift_name} shift Baseline:")
        for file in generated_files:
            print(f"  - {file}")

        # Procesar las intervenciones
        input_folder = os.path.join(input_folder_base, "Velocity_Experimental_Color")
        output_folder = os.path.join(input_folder_base, "Vorticity_Experimental_Color")
        generated_files = process_files(input_folder, output_folder, file_suffixes, triads)
        print(f"Generated vorticity files for {lab_name}, {shift_name} shift Experimental Color:")
        for file in generated_files:
            print(f"  - {file}")

# Define the root folder and suffixes
file_suffixes = ["medroja.txt", "medmorada.txt", "medazul.txt", "medverde.txt", "medamarilla.txt", "mednegra.txt"]

# Define the triads
triads = [
    (0, 2, 4),  # T1 (FRONTAL, DERECHA, SUPERIOR)
    (1, 3, 5),  # T2 (TRASERO, IZQUIERDA, INFERIOR)
    (0, 3, 4),  # T3 (FRONTAL, IZQUIERDA, SUPERIOR)
    (1, 2, 5),  # T4 (TRASERO, DERECHA, INFERIOR)
    (0, 2, 5),  # T5 (FRONTAL, DERECHA, INFERIOR)
    (1, 3, 4),  # T6 (TRASERO, IZQUIERDA, SUPERIOR)
    (0, 3, 5),  # T7 (FRONTAL, IZQUIERDA, INFERIOR)
    (1, 2, 4),  # T8 (TRASERO, DERECHA, SUPERIOR)
    (2, 4, 5),  # T9 (DERECHA, SUPERIOR, INFERIOR)
    (0, 1, 3),  # T10 (IZQUIERDA, FRONTAL, TRASERO)
    (3, 4, 5),  # T11 (IZQUIERDA, SUPERIOR, INFERIOR)
    (0, 1, 2)   # T12 (DERECHA, FRONTAL, TRASERO)
]

triad_codes = {
        (0, 2, 4): "FRT",  
        (1, 3, 5): "PLB",  
        (0, 3, 4): "FLT",  
        (1, 2, 5): "PRB",  
        (0, 2, 5): "FRB",  
        (1, 3, 4): "PLT",  
        (0, 3, 5): "FLB",  
        (1, 2, 4): "PRT",  
        (2, 4, 5): "RTB",  
        (0, 1, 3): "FLP",  
        (3, 4, 5): "LTB",  
        (0, 1, 2): "FRP"
    }

# Procesar todos los laboratorios y turnos
labs = ["Lab_Betta", "Lab_Gamma"]

for lab_name in labs:
    process_lab(root_folder, lab_name, file_suffixes, triads)
# Out:
# No se encontró ningún directorio para Lab_Betta, V.
# No se encontró ningún directorio para Lab_Betta, M.
# No se encontró ningún directorio para Lab_Gamma, V.
# Processing file: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Velocity_Baseline\velocity_01mednegra.txt
# Calculating vorticity for triad FRT: velocity_01mednegra.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Baseline\FRT\vorticity_FRT_velocity_01mednegra.txt
# Calculating vorticity for triad PLB: velocity_01mednegra.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Baseline\PLB\vorticity_PLB_velocity_01mednegra.txt
# Calculating vorticity for triad FLT: velocity_01mednegra.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Baseline\FLT\vorticity_FLT_velocity_01mednegra.txt
# Calculating vorticity for triad PRB: velocity_01mednegra.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Baseline\PRB\vorticity_PRB_velocity_01mednegra.txt
# Calculating vorticity for triad FRB: velocity_01mednegra.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Baseline\FRB\vorticity_FRB_velocity_01mednegra.txt
# Calculating vorticity for triad PLT: velocity_01mednegra.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Baseline\PLT\vorticity_PLT_velocity_01mednegra.txt
# Calculating vorticity for triad FLB: velocity_01mednegra.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Baseline\FLB\vorticity_FLB_velocity_01mednegra.txt
# Calculating vorticity for triad PRT: velocity_01mednegra.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Baseline\PRT\vorticity_PRT_velocity_01mednegra.txt
# Calculating vorticity for triad RTB: velocity_01mednegra.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Baseline\RTB\vorticity_RTB_velocity_01mednegra.txt
# Calculating vorticity for triad FLP: velocity_01mednegra.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Baseline\FLP\vorticity_FLP_velocity_01mednegra.txt
# Calculating vorticity for triad LTB: velocity_01mednegra.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Baseline\LTB\vorticity_LTB_velocity_01mednegra.txt
# Calculating vorticity for triad FRP: velocity_01mednegra.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Baseline\FRP\vorticity_FRP_velocity_01mednegra.txt
# Processing file: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Velocity_Baseline\velocity_02mednegra.txt
# Calculating vorticity for triad FRT: velocity_02mednegra.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Baseline\FRT\vorticity_FRT_velocity_02mednegra.txt
# Calculating vorticity for triad PLB: velocity_02mednegra.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Baseline\PLB\vorticity_PLB_velocity_02mednegra.txt
# Calculating vorticity for triad FLT: velocity_02mednegra.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Baseline\FLT\vorticity_FLT_velocity_02mednegra.txt
# Calculating vorticity for triad PRB: velocity_02mednegra.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Baseline\PRB\vorticity_PRB_velocity_02mednegra.txt
# Calculating vorticity for triad FRB: velocity_02mednegra.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Baseline\FRB\vorticity_FRB_velocity_02mednegra.txt
# Calculating vorticity for triad PLT: velocity_02mednegra.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Baseline\PLT\vorticity_PLT_velocity_02mednegra.txt
# Calculating vorticity for triad FLB: velocity_02mednegra.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Baseline\FLB\vorticity_FLB_velocity_02mednegra.txt
# Calculating vorticity for triad PRT: velocity_02mednegra.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Baseline\PRT\vorticity_PRT_velocity_02mednegra.txt
# Calculating vorticity for triad RTB: velocity_02mednegra.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Baseline\RTB\vorticity_RTB_velocity_02mednegra.txt
# Calculating vorticity for triad FLP: velocity_02mednegra.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Baseline\FLP\vorticity_FLP_velocity_02mednegra.txt
# Calculating vorticity for triad LTB: velocity_02mednegra.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Baseline\LTB\vorticity_LTB_velocity_02mednegra.txt
# Calculating vorticity for triad FRP: velocity_02mednegra.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Baseline\FRP\vorticity_FRP_velocity_02mednegra.txt
# Processing file: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Velocity_Baseline\velocity_03mednegra.txt
# Calculating vorticity for triad FRT: velocity_03mednegra.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Baseline\FRT\vorticity_FRT_velocity_03mednegra.txt
# Calculating vorticity for triad PLB: velocity_03mednegra.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Baseline\PLB\vorticity_PLB_velocity_03mednegra.txt
# Calculating vorticity for triad FLT: velocity_03mednegra.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Baseline\FLT\vorticity_FLT_velocity_03mednegra.txt
# Calculating vorticity for triad PRB: velocity_03mednegra.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Baseline\PRB\vorticity_PRB_velocity_03mednegra.txt
# Calculating vorticity for triad FRB: velocity_03mednegra.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Baseline\FRB\vorticity_FRB_velocity_03mednegra.txt
# Calculating vorticity for triad PLT: velocity_03mednegra.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Baseline\PLT\vorticity_PLT_velocity_03mednegra.txt
# Calculating vorticity for triad FLB: velocity_03mednegra.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Baseline\FLB\vorticity_FLB_velocity_03mednegra.txt
# Calculating vorticity for triad PRT: velocity_03mednegra.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Baseline\PRT\vorticity_PRT_velocity_03mednegra.txt
# Calculating vorticity for triad RTB: velocity_03mednegra.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Baseline\RTB\vorticity_RTB_velocity_03mednegra.txt
# Calculating vorticity for triad FLP: velocity_03mednegra.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Baseline\FLP\vorticity_FLP_velocity_03mednegra.txt
# Calculating vorticity for triad LTB: velocity_03mednegra.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Baseline\LTB\vorticity_LTB_velocity_03mednegra.txt
# Calculating vorticity for triad FRP: velocity_03mednegra.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Baseline\FRP\vorticity_FRP_velocity_03mednegra.txt
# Processing file: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Velocity_Baseline\velocity_04mednegra.txt
# Calculating vorticity for triad FRT: velocity_04mednegra.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Baseline\FRT\vorticity_FRT_velocity_04mednegra.txt
# Calculating vorticity for triad PLB: velocity_04mednegra.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Baseline\PLB\vorticity_PLB_velocity_04mednegra.txt
# Calculating vorticity for triad FLT: velocity_04mednegra.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Baseline\FLT\vorticity_FLT_velocity_04mednegra.txt
# Calculating vorticity for triad PRB: velocity_04mednegra.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Baseline\PRB\vorticity_PRB_velocity_04mednegra.txt
# Calculating vorticity for triad FRB: velocity_04mednegra.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Baseline\FRB\vorticity_FRB_velocity_04mednegra.txt
# Calculating vorticity for triad PLT: velocity_04mednegra.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Baseline\PLT\vorticity_PLT_velocity_04mednegra.txt
# Calculating vorticity for triad FLB: velocity_04mednegra.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Baseline\FLB\vorticity_FLB_velocity_04mednegra.txt
# Calculating vorticity for triad PRT: velocity_04mednegra.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Baseline\PRT\vorticity_PRT_velocity_04mednegra.txt
# Calculating vorticity for triad RTB: velocity_04mednegra.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Baseline\RTB\vorticity_RTB_velocity_04mednegra.txt
# Calculating vorticity for triad FLP: velocity_04mednegra.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Baseline\FLP\vorticity_FLP_velocity_04mednegra.txt
# Calculating vorticity for triad LTB: velocity_04mednegra.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Baseline\LTB\vorticity_LTB_velocity_04mednegra.txt
# Calculating vorticity for triad FRP: velocity_04mednegra.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Baseline\FRP\vorticity_FRP_velocity_04mednegra.txt
# Processing file: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Velocity_Baseline\velocity_05mednegra.txt
# Calculating vorticity for triad FRT: velocity_05mednegra.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Baseline\FRT\vorticity_FRT_velocity_05mednegra.txt
# Calculating vorticity for triad PLB: velocity_05mednegra.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Baseline\PLB\vorticity_PLB_velocity_05mednegra.txt
# Calculating vorticity for triad FLT: velocity_05mednegra.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Baseline\FLT\vorticity_FLT_velocity_05mednegra.txt
# Calculating vorticity for triad PRB: velocity_05mednegra.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Baseline\PRB\vorticity_PRB_velocity_05mednegra.txt
# Calculating vorticity for triad FRB: velocity_05mednegra.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Baseline\FRB\vorticity_FRB_velocity_05mednegra.txt
# Calculating vorticity for triad PLT: velocity_05mednegra.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Baseline\PLT\vorticity_PLT_velocity_05mednegra.txt
# Calculating vorticity for triad FLB: velocity_05mednegra.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Baseline\FLB\vorticity_FLB_velocity_05mednegra.txt
# Calculating vorticity for triad PRT: velocity_05mednegra.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Baseline\PRT\vorticity_PRT_velocity_05mednegra.txt
# Calculating vorticity for triad RTB: velocity_05mednegra.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Baseline\RTB\vorticity_RTB_velocity_05mednegra.txt
# Calculating vorticity for triad FLP: velocity_05mednegra.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Baseline\FLP\vorticity_FLP_velocity_05mednegra.txt
# Calculating vorticity for triad LTB: velocity_05mednegra.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Baseline\LTB\vorticity_LTB_velocity_05mednegra.txt
# Calculating vorticity for triad FRP: velocity_05mednegra.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Baseline\FRP\vorticity_FRP_velocity_05mednegra.txt
# Generated vorticity files for Lab_Gamma, Matutino shift Baseline:
#   - FRT/vorticity_FRT_velocity_01mednegra.txt
#   - PLB/vorticity_PLB_velocity_01mednegra.txt
#   - FLT/vorticity_FLT_velocity_01mednegra.txt
#   - PRB/vorticity_PRB_velocity_01mednegra.txt
#   - FRB/vorticity_FRB_velocity_01mednegra.txt
#   - PLT/vorticity_PLT_velocity_01mednegra.txt
#   - FLB/vorticity_FLB_velocity_01mednegra.txt
#   - PRT/vorticity_PRT_velocity_01mednegra.txt
#   - RTB/vorticity_RTB_velocity_01mednegra.txt
#   - FLP/vorticity_FLP_velocity_01mednegra.txt
#   - LTB/vorticity_LTB_velocity_01mednegra.txt
#   - FRP/vorticity_FRP_velocity_01mednegra.txt
#   - FRT/vorticity_FRT_velocity_02mednegra.txt
#   - PLB/vorticity_PLB_velocity_02mednegra.txt
#   - FLT/vorticity_FLT_velocity_02mednegra.txt
#   - PRB/vorticity_PRB_velocity_02mednegra.txt
#   - FRB/vorticity_FRB_velocity_02mednegra.txt
#   - PLT/vorticity_PLT_velocity_02mednegra.txt
#   - FLB/vorticity_FLB_velocity_02mednegra.txt
#   - PRT/vorticity_PRT_velocity_02mednegra.txt
#   - RTB/vorticity_RTB_velocity_02mednegra.txt
#   - FLP/vorticity_FLP_velocity_02mednegra.txt
#   - LTB/vorticity_LTB_velocity_02mednegra.txt
#   - FRP/vorticity_FRP_velocity_02mednegra.txt
#   - FRT/vorticity_FRT_velocity_03mednegra.txt
#   - PLB/vorticity_PLB_velocity_03mednegra.txt
#   - FLT/vorticity_FLT_velocity_03mednegra.txt
#   - PRB/vorticity_PRB_velocity_03mednegra.txt
#   - FRB/vorticity_FRB_velocity_03mednegra.txt
#   - PLT/vorticity_PLT_velocity_03mednegra.txt
#   - FLB/vorticity_FLB_velocity_03mednegra.txt
#   - PRT/vorticity_PRT_velocity_03mednegra.txt
#   - RTB/vorticity_RTB_velocity_03mednegra.txt
#   - FLP/vorticity_FLP_velocity_03mednegra.txt
#   - LTB/vorticity_LTB_velocity_03mednegra.txt
#   - FRP/vorticity_FRP_velocity_03mednegra.txt
#   - FRT/vorticity_FRT_velocity_04mednegra.txt
#   - PLB/vorticity_PLB_velocity_04mednegra.txt
#   - FLT/vorticity_FLT_velocity_04mednegra.txt
#   - PRB/vorticity_PRB_velocity_04mednegra.txt
#   - FRB/vorticity_FRB_velocity_04mednegra.txt
#   - PLT/vorticity_PLT_velocity_04mednegra.txt
#   - FLB/vorticity_FLB_velocity_04mednegra.txt
#   - PRT/vorticity_PRT_velocity_04mednegra.txt
#   - RTB/vorticity_RTB_velocity_04mednegra.txt
#   - FLP/vorticity_FLP_velocity_04mednegra.txt
#   - LTB/vorticity_LTB_velocity_04mednegra.txt
#   - FRP/vorticity_FRP_velocity_04mednegra.txt
#   - FRT/vorticity_FRT_velocity_05mednegra.txt
#   - PLB/vorticity_PLB_velocity_05mednegra.txt
#   - FLT/vorticity_FLT_velocity_05mednegra.txt
#   - PRB/vorticity_PRB_velocity_05mednegra.txt
#   - FRB/vorticity_FRB_velocity_05mednegra.txt
#   - PLT/vorticity_PLT_velocity_05mednegra.txt
#   - FLB/vorticity_FLB_velocity_05mednegra.txt
#   - PRT/vorticity_PRT_velocity_05mednegra.txt
#   - RTB/vorticity_RTB_velocity_05mednegra.txt
#   - FLP/vorticity_FLP_velocity_05mednegra.txt
#   - LTB/vorticity_LTB_velocity_05mednegra.txt
#   - FRP/vorticity_FRP_velocity_05mednegra.txt
# Processing file: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Velocity_Experimental_Color\velocity_01medamarilla.txt
# Calculating vorticity for triad FRT: velocity_01medamarilla.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Experimental_Color\FRT\vorticity_FRT_velocity_01medamarilla.txt
# Calculating vorticity for triad PLB: velocity_01medamarilla.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Experimental_Color\PLB\vorticity_PLB_velocity_01medamarilla.txt
# Calculating vorticity for triad FLT: velocity_01medamarilla.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Experimental_Color\FLT\vorticity_FLT_velocity_01medamarilla.txt
# Calculating vorticity for triad PRB: velocity_01medamarilla.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Experimental_Color\PRB\vorticity_PRB_velocity_01medamarilla.txt
# Calculating vorticity for triad FRB: velocity_01medamarilla.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Experimental_Color\FRB\vorticity_FRB_velocity_01medamarilla.txt
# Calculating vorticity for triad PLT: velocity_01medamarilla.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Experimental_Color\PLT\vorticity_PLT_velocity_01medamarilla.txt
# Calculating vorticity for triad FLB: velocity_01medamarilla.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Experimental_Color\FLB\vorticity_FLB_velocity_01medamarilla.txt
# Calculating vorticity for triad PRT: velocity_01medamarilla.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Experimental_Color\PRT\vorticity_PRT_velocity_01medamarilla.txt
# Calculating vorticity for triad RTB: velocity_01medamarilla.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Experimental_Color\RTB\vorticity_RTB_velocity_01medamarilla.txt
# Calculating vorticity for triad FLP: velocity_01medamarilla.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Experimental_Color\FLP\vorticity_FLP_velocity_01medamarilla.txt
# Calculating vorticity for triad LTB: velocity_01medamarilla.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Experimental_Color\LTB\vorticity_LTB_velocity_01medamarilla.txt
# Calculating vorticity for triad FRP: velocity_01medamarilla.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Experimental_Color\FRP\vorticity_FRP_velocity_01medamarilla.txt
# Processing file: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Velocity_Experimental_Color\velocity_02medroja.txt
# Calculating vorticity for triad FRT: velocity_02medroja.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Experimental_Color\FRT\vorticity_FRT_velocity_02medroja.txt
# Calculating vorticity for triad PLB: velocity_02medroja.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Experimental_Color\PLB\vorticity_PLB_velocity_02medroja.txt
# Calculating vorticity for triad FLT: velocity_02medroja.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Experimental_Color\FLT\vorticity_FLT_velocity_02medroja.txt
# Calculating vorticity for triad PRB: velocity_02medroja.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Experimental_Color\PRB\vorticity_PRB_velocity_02medroja.txt
# Calculating vorticity for triad FRB: velocity_02medroja.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Experimental_Color\FRB\vorticity_FRB_velocity_02medroja.txt
# Calculating vorticity for triad PLT: velocity_02medroja.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Experimental_Color\PLT\vorticity_PLT_velocity_02medroja.txt
# Calculating vorticity for triad FLB: velocity_02medroja.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Experimental_Color\FLB\vorticity_FLB_velocity_02medroja.txt
# Calculating vorticity for triad PRT: velocity_02medroja.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Experimental_Color\PRT\vorticity_PRT_velocity_02medroja.txt
# Calculating vorticity for triad RTB: velocity_02medroja.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Experimental_Color\RTB\vorticity_RTB_velocity_02medroja.txt
# Calculating vorticity for triad FLP: velocity_02medroja.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Experimental_Color\FLP\vorticity_FLP_velocity_02medroja.txt
# Calculating vorticity for triad LTB: velocity_02medroja.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Experimental_Color\LTB\vorticity_LTB_velocity_02medroja.txt
# Calculating vorticity for triad FRP: velocity_02medroja.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Experimental_Color\FRP\vorticity_FRP_velocity_02medroja.txt
# Processing file: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Velocity_Experimental_Color\velocity_03medroja.txt
# Calculating vorticity for triad FRT: velocity_03medroja.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Experimental_Color\FRT\vorticity_FRT_velocity_03medroja.txt
# Calculating vorticity for triad PLB: velocity_03medroja.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Experimental_Color\PLB\vorticity_PLB_velocity_03medroja.txt
# Calculating vorticity for triad FLT: velocity_03medroja.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Experimental_Color\FLT\vorticity_FLT_velocity_03medroja.txt
# Calculating vorticity for triad PRB: velocity_03medroja.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Experimental_Color\PRB\vorticity_PRB_velocity_03medroja.txt
# Calculating vorticity for triad FRB: velocity_03medroja.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Experimental_Color\FRB\vorticity_FRB_velocity_03medroja.txt
# Calculating vorticity for triad PLT: velocity_03medroja.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Experimental_Color\PLT\vorticity_PLT_velocity_03medroja.txt
# Calculating vorticity for triad FLB: velocity_03medroja.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Experimental_Color\FLB\vorticity_FLB_velocity_03medroja.txt
# Calculating vorticity for triad PRT: velocity_03medroja.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Experimental_Color\PRT\vorticity_PRT_velocity_03medroja.txt
# Calculating vorticity for triad RTB: velocity_03medroja.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Experimental_Color\RTB\vorticity_RTB_velocity_03medroja.txt
# Calculating vorticity for triad FLP: velocity_03medroja.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Experimental_Color\FLP\vorticity_FLP_velocity_03medroja.txt
# Calculating vorticity for triad LTB: velocity_03medroja.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Experimental_Color\LTB\vorticity_LTB_velocity_03medroja.txt
# Calculating vorticity for triad FRP: velocity_03medroja.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Experimental_Color\FRP\vorticity_FRP_velocity_03medroja.txt
# Processing file: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Velocity_Experimental_Color\velocity_04medroja.txt
# Calculating vorticity for triad FRT: velocity_04medroja.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Experimental_Color\FRT\vorticity_FRT_velocity_04medroja.txt
# Calculating vorticity for triad PLB: velocity_04medroja.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Experimental_Color\PLB\vorticity_PLB_velocity_04medroja.txt
# Calculating vorticity for triad FLT: velocity_04medroja.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Experimental_Color\FLT\vorticity_FLT_velocity_04medroja.txt
# Calculating vorticity for triad PRB: velocity_04medroja.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Experimental_Color\PRB\vorticity_PRB_velocity_04medroja.txt
# Calculating vorticity for triad FRB: velocity_04medroja.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Experimental_Color\FRB\vorticity_FRB_velocity_04medroja.txt
# Calculating vorticity for triad PLT: velocity_04medroja.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Experimental_Color\PLT\vorticity_PLT_velocity_04medroja.txt
# Calculating vorticity for triad FLB: velocity_04medroja.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Experimental_Color\FLB\vorticity_FLB_velocity_04medroja.txt
# Calculating vorticity for triad PRT: velocity_04medroja.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Experimental_Color\PRT\vorticity_PRT_velocity_04medroja.txt
# Calculating vorticity for triad RTB: velocity_04medroja.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Experimental_Color\RTB\vorticity_RTB_velocity_04medroja.txt
# Calculating vorticity for triad FLP: velocity_04medroja.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Experimental_Color\FLP\vorticity_FLP_velocity_04medroja.txt
# Calculating vorticity for triad LTB: velocity_04medroja.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Experimental_Color\LTB\vorticity_LTB_velocity_04medroja.txt
# Calculating vorticity for triad FRP: velocity_04medroja.txt
# Saving vorticity data to: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Data Analysis\Processing Data\Vorticity_Experimental_Color\FRP\vorticity_FRP_velocity_04medroja.txt
# Generated vorticity files for Lab_Gamma, Matutino shift Experimental Color:
#   - FRT/vorticity_FRT_velocity_01medamarilla.txt
#   - PLB/vorticity_PLB_velocity_01medamarilla.txt
#   - FLT/vorticity_FLT_velocity_01medamarilla.txt
#   - PRB/vorticity_PRB_velocity_01medamarilla.txt
#   - FRB/vorticity_FRB_velocity_01medamarilla.txt
#   - PLT/vorticity_PLT_velocity_01medamarilla.txt
#   - FLB/vorticity_FLB_velocity_01medamarilla.txt
#   - PRT/vorticity_PRT_velocity_01medamarilla.txt
#   - RTB/vorticity_RTB_velocity_01medamarilla.txt
#   - FLP/vorticity_FLP_velocity_01medamarilla.txt
#   - LTB/vorticity_LTB_velocity_01medamarilla.txt
#   - FRP/vorticity_FRP_velocity_01medamarilla.txt
#   - FRT/vorticity_FRT_velocity_02medroja.txt
#   - PLB/vorticity_PLB_velocity_02medroja.txt
#   - FLT/vorticity_FLT_velocity_02medroja.txt
#   - PRB/vorticity_PRB_velocity_02medroja.txt
#   - FRB/vorticity_FRB_velocity_02medroja.txt
#   - PLT/vorticity_PLT_velocity_02medroja.txt
#   - FLB/vorticity_FLB_velocity_02medroja.txt
#   - PRT/vorticity_PRT_velocity_02medroja.txt
#   - RTB/vorticity_RTB_velocity_02medroja.txt
#   - FLP/vorticity_FLP_velocity_02medroja.txt
#   - LTB/vorticity_LTB_velocity_02medroja.txt
#   - FRP/vorticity_FRP_velocity_02medroja.txt
#   - FRT/vorticity_FRT_velocity_03medroja.txt
#   - PLB/vorticity_PLB_velocity_03medroja.txt
#   - FLT/vorticity_FLT_velocity_03medroja.txt
#   - PRB/vorticity_PRB_velocity_03medroja.txt
#   - FRB/vorticity_FRB_velocity_03medroja.txt
#   - PLT/vorticity_PLT_velocity_03medroja.txt
#   - FLB/vorticity_FLB_velocity_03medroja.txt
#   - PRT/vorticity_PRT_velocity_03medroja.txt
#   - RTB/vorticity_RTB_velocity_03medroja.txt
#   - FLP/vorticity_FLP_velocity_03medroja.txt
#   - LTB/vorticity_LTB_velocity_03medroja.txt
#   - FRP/vorticity_FRP_velocity_03medroja.txt
#   - FRT/vorticity_FRT_velocity_04medroja.txt
#   - PLB/vorticity_PLB_velocity_04medroja.txt
#   - FLT/vorticity_FLT_velocity_04medroja.txt
#   - PRB/vorticity_PRB_velocity_04medroja.txt
#   - FRB/vorticity_FRB_velocity_04medroja.txt
#   - PLT/vorticity_PLT_velocity_04medroja.txt
#   - FLB/vorticity_FLB_velocity_04medroja.txt
#   - PRT/vorticity_PRT_velocity_04medroja.txt
#   - RTB/vorticity_RTB_velocity_04medroja.txt
#   - FLP/vorticity_FLP_velocity_04medroja.txt
#   - LTB/vorticity_LTB_velocity_04medroja.txt
#   - FRP/vorticity_FRP_velocity_04medroja.txt

# %% [markdown]
# ## 7
#
# $$
#
#     \Huge \text{Helicity Generator by Triads}
#
# $$

# %%
#Helicidad general .txt
import os
import numpy as np
import re

def read_velocity_data(filepath):
    data = []
    timestamps = []
    try:
        with open(filepath, 'r') as file:
            for line in file:
                parts = line.strip().split(' -> ')
                if len(parts) > 1:
                    timestamps.append(parts[0])
                    velocity_components = parts[1].strip('()').split(', ')
                    data.append([float(v) for v in velocity_components])
        return timestamps, np.array(data)
    except Exception as e:
        print(f"Error reading file {filepath}: {e}")
        return [], np.array([])

def calculate_helicity(velocities, vorticities, indices, volume):
    selected_velocities = velocities[:, indices]
    helicity = np.einsum('ij,ij->i', selected_velocities, vorticities) * volume
    return helicity

def format_and_save_helicities(timestamps, helicities, filename):
    os.makedirs(os.path.dirname(filename), exist_ok=True)
    try:
        with open(filename, "w") as file:
            for timestamp, helicity in zip(timestamps, helicities):
                formatted_output = f"{timestamp} -> {helicity:.10f}\n"
                file.write(formatted_output)
    except Exception as e:
        print(f"Error writing file {filename}: {e}")

def process_files(input_folder_velocity, input_folder_vorticity, output_folder, file_suffixes, volume, triads):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    
    generated_files = []
    
    for suffix in file_suffixes:
        for filename in os.listdir(input_folder_velocity):
            if filename.endswith(suffix):
                base_filename = filename.split('.')[0]
                filepath_velocity = os.path.join(input_folder_velocity, filename)
                
                for triad in triads:
                    if triad in triad_codes:
                        code = triad_codes[triad]
                        triad_folder = os.path.join(input_folder_vorticity, code)
                        filepath_vorticity = os.path.join(triad_folder, f"vorticity_{code}_{base_filename}.txt")
                        
                        timestamps, velocities = read_velocity_data(filepath_velocity)
                        if velocities.size == 0:
                            continue
                        
                        _, vorticity = read_velocity_data(filepath_vorticity)

                        if vorticity.size == 0:
                            print(f"Skipping file {filename} due to missing vorticity data for triad {code}.")
                            continue
                        
                        helicity = calculate_helicity(velocities, vorticity, triad, volume)
                        
                        output_filename = f"helicity_{code}_{base_filename}.txt"
                        output_path = os.path.join(output_folder, code, output_filename)
                        
                        format_and_save_helicities(timestamps, helicity, output_path)
                        
                        generated_files.append(f"{os.path.basename(output_folder)}/{code}/{output_filename}")

    return generated_files

def find_experiment_folder(root_folder, lab, shift):
    date_regex = re.compile(r'\d{2}[A-Za-z]{3}\d{2}')
    for folder in os.listdir(root_folder):
        if date_regex.search(folder) and lab in folder:
            for subfolder in os.listdir(os.path.join(root_folder, folder)):
                if date_regex.search(subfolder) and shift in subfolder:
                    return os.path.join(root_folder, folder, subfolder), date_regex.search(folder).group(0)
    return None, None

def process_lab(root_folder, lab_name, file_suffixes, volume, triads):
    for shift in ['V', 'M']:
        shift_name = "Vespertino" if shift == 'V' else "Matutino"
        experiment_folder, date_str = find_experiment_folder(root_folder, lab_name, shift)
        if not experiment_folder:
            print(f"No se encontró ningún directorio para {lab_name}, {shift}.")
            continue

        input_folder_base = os.path.join(experiment_folder, "Data Analysis", "Processing Data")
        
        if not os.path.exists(input_folder_base):
            print(f"Cannot access directory: {input_folder_base}")
            continue

        # Procesar la línea base
        input_folder_velocity = os.path.join(input_folder_base, "Velocity_Baseline")
        input_folder_vorticity = os.path.join(input_folder_base, "Vorticity_Baseline")
        output_folder = os.path.join(input_folder_base, "Helicity_Baseline")
        generated_files = process_files(input_folder_velocity, input_folder_vorticity, output_folder, file_suffixes, volume, triads)
        print(f"Generated helicity files for {lab_name}, {shift_name} shift Baseline:")
        for file in generated_files:
            print(f"  - {file}")

        # Procesar las intervenciones
        input_folder_velocity = os.path.join(input_folder_base, "Velocity_Experimental_Color")
        input_folder_vorticity = os.path.join(input_folder_base, "Vorticity_Experimental_Color")
        output_folder = os.path.join(input_folder_base, "Helicity_Experimental_Color")
        generated_files = process_files(input_folder_velocity, input_folder_vorticity, output_folder, file_suffixes, volume, triads)
        print(f"Generated helicity files for {lab_name}, {shift_name} shift Experimental Color:")
        for file in generated_files:
            print(f"  - {file}")

# Define the root folder and suffixes
file_suffixes = ["medroja.txt", "medmorada.txt", "medazul.txt", "medverde.txt", "medamarilla.txt", "mednegra.txt"]

# Volumes for each lab
volumes = {
    "Lab_Betta": 7.3195, # Volume for Lab A
    "Lab_Gamma": 6.8342  # Volume for Lab B (example)
}

# Triads
triads = [
    (0, 2, 4),  # T1 (FRONTAL, DERECHA, SUPERIOR)
    (1, 3, 5),  # T2 (TRASERO, IZQUIERDA, INFERIOR)
    (0, 3, 4),  # T3 (FRONTAL, IZQUIERDA, SUPERIOR)
    (1, 2, 5),  # T4 (TRASERO, DERECHA, INFERIOR)
    (0, 2, 5),  # T5 (FRONTAL, DERECHA, INFERIOR)
    (1, 3, 4),  # T6 (TRASERO, IZQUIERDA, SUPERIOR)
    (0, 3, 5),  # T7 (FRONTAL, IZQUIERDA, INFERIOR)
    (1, 2, 4),  # T8 (TRASERO, DERECHA, SUPERIOR)
    (2, 4, 5),  # T9 (DERECHA, SUPERIOR, INFERIOR)
    (0, 1, 3),  # T10 (IZQUIERDA, FRONTAL, TRASERO)
    (3, 4, 5),  # T11 (IZQUIERDA, SUPERIOR, INFERIOR)
    (0, 1, 2)   # T12 (DERECHA, FRONTAL, TRASERO)
]

# Triad codes
triad_codes = {
    (0, 2, 4): "FRT",  
    (1, 3, 5): "PLB",  
    (0, 3, 4): "FLT",  
    (1, 2, 5): "PRB",  
    (0, 2, 5): "FRB",  
    (1, 3, 4): "PLT",  
    (0, 3, 5): "FLB",  
    (1, 2, 4): "PRT",  
    (2, 4, 5): "RTB",  
    (0, 1, 3): "FLP",  
    (3, 4, 5): "LTB",  
    (0, 1, 2): "FRP"
}

# Procesar todos los laboratorios y turnos
labs = ["Lab_Betta", "Lab_Gamma"]

for lab_name in labs:
    process_lab(root_folder, lab_name, file_suffixes, volumes[lab_name], triads)
# Out:
# No se encontró ningún directorio para Lab_Betta, V.
# No se encontró ningún directorio para Lab_Betta, M.
# No se encontró ningún directorio para Lab_Gamma, V.
# Generated helicity files for Lab_Gamma, Matutino shift Baseline:
#   - Helicity_Baseline/FRT/helicity_FRT_velocity_01mednegra.txt
#   - Helicity_Baseline/PLB/helicity_PLB_velocity_01mednegra.txt
#   - Helicity_Baseline/FLT/helicity_FLT_velocity_01mednegra.txt
#   - Helicity_Baseline/PRB/helicity_PRB_velocity_01mednegra.txt
#   - Helicity_Baseline/FRB/helicity_FRB_velocity_01mednegra.txt
#   - Helicity_Baseline/PLT/helicity_PLT_velocity_01mednegra.txt
#   - Helicity_Baseline/FLB/helicity_FLB_velocity_01mednegra.txt
#   - Helicity_Baseline/PRT/helicity_PRT_velocity_01mednegra.txt
#   - Helicity_Baseline/RTB/helicity_RTB_velocity_01mednegra.txt
#   - Helicity_Baseline/FLP/helicity_FLP_velocity_01mednegra.txt
#   - Helicity_Baseline/LTB/helicity_LTB_velocity_01mednegra.txt
#   - Helicity_Baseline/FRP/helicity_FRP_velocity_01mednegra.txt
#   - Helicity_Baseline/FRT/helicity_FRT_velocity_02mednegra.txt
#   - Helicity_Baseline/PLB/helicity_PLB_velocity_02mednegra.txt
#   - Helicity_Baseline/FLT/helicity_FLT_velocity_02mednegra.txt
#   - Helicity_Baseline/PRB/helicity_PRB_velocity_02mednegra.txt
#   - Helicity_Baseline/FRB/helicity_FRB_velocity_02mednegra.txt
#   - Helicity_Baseline/PLT/helicity_PLT_velocity_02mednegra.txt
#   - Helicity_Baseline/FLB/helicity_FLB_velocity_02mednegra.txt
#   - Helicity_Baseline/PRT/helicity_PRT_velocity_02mednegra.txt
#   - Helicity_Baseline/RTB/helicity_RTB_velocity_02mednegra.txt
#   - Helicity_Baseline/FLP/helicity_FLP_velocity_02mednegra.txt
#   - Helicity_Baseline/LTB/helicity_LTB_velocity_02mednegra.txt
#   - Helicity_Baseline/FRP/helicity_FRP_velocity_02mednegra.txt
#   - Helicity_Baseline/FRT/helicity_FRT_velocity_03mednegra.txt
#   - Helicity_Baseline/PLB/helicity_PLB_velocity_03mednegra.txt
#   - Helicity_Baseline/FLT/helicity_FLT_velocity_03mednegra.txt
#   - Helicity_Baseline/PRB/helicity_PRB_velocity_03mednegra.txt
#   - Helicity_Baseline/FRB/helicity_FRB_velocity_03mednegra.txt
#   - Helicity_Baseline/PLT/helicity_PLT_velocity_03mednegra.txt
#   - Helicity_Baseline/FLB/helicity_FLB_velocity_03mednegra.txt
#   - Helicity_Baseline/PRT/helicity_PRT_velocity_03mednegra.txt
#   - Helicity_Baseline/RTB/helicity_RTB_velocity_03mednegra.txt
#   - Helicity_Baseline/FLP/helicity_FLP_velocity_03mednegra.txt
#   - Helicity_Baseline/LTB/helicity_LTB_velocity_03mednegra.txt
#   - Helicity_Baseline/FRP/helicity_FRP_velocity_03mednegra.txt
#   - Helicity_Baseline/FRT/helicity_FRT_velocity_04mednegra.txt
#   - Helicity_Baseline/PLB/helicity_PLB_velocity_04mednegra.txt
#   - Helicity_Baseline/FLT/helicity_FLT_velocity_04mednegra.txt
#   - Helicity_Baseline/PRB/helicity_PRB_velocity_04mednegra.txt
#   - Helicity_Baseline/FRB/helicity_FRB_velocity_04mednegra.txt
#   - Helicity_Baseline/PLT/helicity_PLT_velocity_04mednegra.txt
#   - Helicity_Baseline/FLB/helicity_FLB_velocity_04mednegra.txt
#   - Helicity_Baseline/PRT/helicity_PRT_velocity_04mednegra.txt
#   - Helicity_Baseline/RTB/helicity_RTB_velocity_04mednegra.txt
#   - Helicity_Baseline/FLP/helicity_FLP_velocity_04mednegra.txt
#   - Helicity_Baseline/LTB/helicity_LTB_velocity_04mednegra.txt
#   - Helicity_Baseline/FRP/helicity_FRP_velocity_04mednegra.txt
#   - Helicity_Baseline/FRT/helicity_FRT_velocity_05mednegra.txt
#   - Helicity_Baseline/PLB/helicity_PLB_velocity_05mednegra.txt
#   - Helicity_Baseline/FLT/helicity_FLT_velocity_05mednegra.txt
#   - Helicity_Baseline/PRB/helicity_PRB_velocity_05mednegra.txt
#   - Helicity_Baseline/FRB/helicity_FRB_velocity_05mednegra.txt
#   - Helicity_Baseline/PLT/helicity_PLT_velocity_05mednegra.txt
#   - Helicity_Baseline/FLB/helicity_FLB_velocity_05mednegra.txt
#   - Helicity_Baseline/PRT/helicity_PRT_velocity_05mednegra.txt
#   - Helicity_Baseline/RTB/helicity_RTB_velocity_05mednegra.txt
#   - Helicity_Baseline/FLP/helicity_FLP_velocity_05mednegra.txt
#   - Helicity_Baseline/LTB/helicity_LTB_velocity_05mednegra.txt
#   - Helicity_Baseline/FRP/helicity_FRP_velocity_05mednegra.txt
# Generated helicity files for Lab_Gamma, Matutino shift Experimental Color:
#   - Helicity_Experimental_Color/FRT/helicity_FRT_velocity_02medroja.txt
#   - Helicity_Experimental_Color/PLB/helicity_PLB_velocity_02medroja.txt
#   - Helicity_Experimental_Color/FLT/helicity_FLT_velocity_02medroja.txt
#   - Helicity_Experimental_Color/PRB/helicity_PRB_velocity_02medroja.txt
#   - Helicity_Experimental_Color/FRB/helicity_FRB_velocity_02medroja.txt
#   - Helicity_Experimental_Color/PLT/helicity_PLT_velocity_02medroja.txt
#   - Helicity_Experimental_Color/FLB/helicity_FLB_velocity_02medroja.txt
#   - Helicity_Experimental_Color/PRT/helicity_PRT_velocity_02medroja.txt
#   - Helicity_Experimental_Color/RTB/helicity_RTB_velocity_02medroja.txt
#   - Helicity_Experimental_Color/FLP/helicity_FLP_velocity_02medroja.txt
#   - Helicity_Experimental_Color/LTB/helicity_LTB_velocity_02medroja.txt
#   - Helicity_Experimental_Color/FRP/helicity_FRP_velocity_02medroja.txt
#   - Helicity_Experimental_Color/FRT/helicity_FRT_velocity_03medroja.txt
#   - Helicity_Experimental_Color/PLB/helicity_PLB_velocity_03medroja.txt
#   - Helicity_Experimental_Color/FLT/helicity_FLT_velocity_03medroja.txt
#   - Helicity_Experimental_Color/PRB/helicity_PRB_velocity_03medroja.txt
#   - Helicity_Experimental_Color/FRB/helicity_FRB_velocity_03medroja.txt
#   - Helicity_Experimental_Color/PLT/helicity_PLT_velocity_03medroja.txt
#   - Helicity_Experimental_Color/FLB/helicity_FLB_velocity_03medroja.txt
#   - Helicity_Experimental_Color/PRT/helicity_PRT_velocity_03medroja.txt
#   - Helicity_Experimental_Color/RTB/helicity_RTB_velocity_03medroja.txt
#   - Helicity_Experimental_Color/FLP/helicity_FLP_velocity_03medroja.txt
#   - Helicity_Experimental_Color/LTB/helicity_LTB_velocity_03medroja.txt
#   - Helicity_Experimental_Color/FRP/helicity_FRP_velocity_03medroja.txt
#   - Helicity_Experimental_Color/FRT/helicity_FRT_velocity_04medroja.txt
#   - Helicity_Experimental_Color/PLB/helicity_PLB_velocity_04medroja.txt
#   - Helicity_Experimental_Color/FLT/helicity_FLT_velocity_04medroja.txt
#   - Helicity_Experimental_Color/PRB/helicity_PRB_velocity_04medroja.txt
#   - Helicity_Experimental_Color/FRB/helicity_FRB_velocity_04medroja.txt
#   - Helicity_Experimental_Color/PLT/helicity_PLT_velocity_04medroja.txt
#   - Helicity_Experimental_Color/FLB/helicity_FLB_velocity_04medroja.txt
#   - Helicity_Experimental_Color/PRT/helicity_PRT_velocity_04medroja.txt
#   - Helicity_Experimental_Color/RTB/helicity_RTB_velocity_04medroja.txt
#   - Helicity_Experimental_Color/FLP/helicity_FLP_velocity_04medroja.txt
#   - Helicity_Experimental_Color/LTB/helicity_LTB_velocity_04medroja.txt
#   - Helicity_Experimental_Color/FRP/helicity_FRP_velocity_04medroja.txt
#   - Helicity_Experimental_Color/FRT/helicity_FRT_velocity_01medamarilla.txt
#   - Helicity_Experimental_Color/PLB/helicity_PLB_velocity_01medamarilla.txt
#   - Helicity_Experimental_Color/FLT/helicity_FLT_velocity_01medamarilla.txt
#   - Helicity_Experimental_Color/PRB/helicity_PRB_velocity_01medamarilla.txt
#   - Helicity_Experimental_Color/FRB/helicity_FRB_velocity_01medamarilla.txt
#   - Helicity_Experimental_Color/PLT/helicity_PLT_velocity_01medamarilla.txt
#   - Helicity_Experimental_Color/FLB/helicity_FLB_velocity_01medamarilla.txt
#   - Helicity_Experimental_Color/PRT/helicity_PRT_velocity_01medamarilla.txt
#   - Helicity_Experimental_Color/RTB/helicity_RTB_velocity_01medamarilla.txt
#   - Helicity_Experimental_Color/FLP/helicity_FLP_velocity_01medamarilla.txt
#   - Helicity_Experimental_Color/LTB/helicity_LTB_velocity_01medamarilla.txt
#   - Helicity_Experimental_Color/FRP/helicity_FRP_velocity_01medamarilla.txt

# %% [markdown]
# ## 8
#
# $$
#
#     \Huge \text{First Integral of Helicity Generator}
#
# $$

# %%
#Integral Helicidad .txt
import os
import re

def process_file(file_path, output_file_path):
    with open(file_path, 'r') as file:
        lines = file.readlines()
    
    accumulated_helicity = 0
    results = []
    for line in lines:
        time_stamp, value = line.split('->')
        value = float(value.strip())
        accumulated_helicity += value
        results.append(f"{time_stamp.strip()} -> {accumulated_helicity:.10f}\n")

    with open(output_file_path, 'w') as output_file:
        output_file.writelines(results)

def generate_accumulated_helicity(input_directory, output_directory):
    if not os.path.exists(output_directory):
        os.makedirs(output_directory)

    for root, dirs, files in os.walk(input_directory):
        for filename in files:
            if filename.endswith(".txt"):
                file_path = os.path.join(root, filename)
                output_filename = f"sum_{filename}"
                output_file_path = os.path.join(output_directory, output_filename)
                process_file(file_path, output_file_path)
                print(f"Generated file: {output_filename}")

def find_experiment_folder(root_folder, lab, shift):
    date_regex = re.compile(r'\d{2}[A-Za-z]{3}\d{2}')
    for folder in os.listdir(root_folder):
        if date_regex.search(folder) and lab in folder:
            for subfolder in os.listdir(os.path.join(root_folder, folder)):
                if date_regex.search(subfolder) and shift in subfolder:
                    return os.path.join(root_folder, folder, subfolder), date_regex.search(folder).group(0)
    return None, None

def process_lab_helicity(root_folder, lab_name, shift, file_suffixes, triad_codes):
    shift_name = "Vespertino" if shift == 'V' else "Matutino"
    experiment_folder, date_str = find_experiment_folder(root_folder, lab_name, shift)
    if not experiment_folder:
        print(f"No se encontró ningún directorio para {lab_name}, {shift}.")
        return

    input_folder_base = os.path.join(experiment_folder, "Data Analysis", "Processing Data")
    
    if not os.path.exists(input_folder_base):
        print(f"Skipping {shift_name} shift for {lab_name} as directory does not exist: {input_folder_base}")
        return

    # Procesar los acumulados de Baseline para cada triada
    for triad, triad_code in triad_codes.items():
        input_directory = os.path.join(input_folder_base, "Helicity_Baseline", triad_code)
        output_directory = os.path.join(input_folder_base, "Sum_Helicity_Baseline", triad_code)
        if os.path.exists(input_directory):
            generate_accumulated_helicity(input_directory, output_directory)
            print(f"Generated accumulated helicity files for {lab_name}, {shift_name} shift Baseline, Triad {triad_code}.")
        else:
            print(f"Skipping {shift_name} shift for {lab_name} Baseline Triad {triad_code} as directory does not exist: {input_directory}")

    # Procesar los acumulados de Experimental Color para cada triada
    for triad, triad_code in triad_codes.items():
        input_directory = os.path.join(input_folder_base, "Helicity_Experimental_Color", triad_code)
        output_directory = os.path.join(input_folder_base, "Sum_Helicity_Experimental_Color", triad_code)
        if os.path.exists(input_directory):
            generate_accumulated_helicity(input_directory, output_directory)
            print(f"Generated accumulated helicity files for {lab_name}, {shift_name} shift Experimental Color, Triad {triad_code}.")
        else:
            print(f"Skipping {shift_name} shift for {lab_name} Experimental Color Triad {triad_code} as directory does not exist: {input_directory}")

# Define the root folder, suffixes, and triad codes
file_suffixes = ["medroja.txt", "medmorada.txt", "medazul.txt", "medverde.txt", "medamarilla.txt", "mednegra.txt"]
triad_codes = {
    (0, 2, 4): "FRT",  
    (1, 3, 5): "PLB",  
    (0, 3, 4): "FLT",  
    (1, 2, 5): "PRB",  
    (0, 2, 5): "FRB",  
    (1, 3, 4): "PLT",  
    (0, 3, 5): "FLB",  
    (1, 2, 4): "PRT",  
    (2, 4, 5): "RTB",  
    (0, 1, 3): "FLP",  
    (3, 4, 5): "LTB",  
    (0, 1, 2): "FRP"
}

# Procesar todos los laboratorios y turnos
labs = ["Lab_Betta", "Lab_Gamma"]

for lab_name in labs:
    for shift in ['V', 'M']:
        process_lab_helicity(root_folder, lab_name, shift, file_suffixes, triad_codes)

print("Processing complete. All accumulated helicity results are saved in their respective directories.")
# Out:
# No se encontró ningún directorio para Lab_Betta, V.
# No se encontró ningún directorio para Lab_Betta, M.
# No se encontró ningún directorio para Lab_Gamma, V.
# Generated file: sum_helicity_FRT_velocity_01mednegra.txt
# Generated file: sum_helicity_FRT_velocity_02mednegra.txt
# Generated file: sum_helicity_FRT_velocity_03mednegra.txt
# Generated file: sum_helicity_FRT_velocity_04mednegra.txt
# Generated file: sum_helicity_FRT_velocity_05mednegra.txt
# Generated accumulated helicity files for Lab_Gamma, Matutino shift Baseline, Triad FRT.
# Generated file: sum_helicity_PLB_velocity_01mednegra.txt
# Generated file: sum_helicity_PLB_velocity_02mednegra.txt
# Generated file: sum_helicity_PLB_velocity_03mednegra.txt
# Generated file: sum_helicity_PLB_velocity_04mednegra.txt
# Generated file: sum_helicity_PLB_velocity_05mednegra.txt
# Generated accumulated helicity files for Lab_Gamma, Matutino shift Baseline, Triad PLB.
# Generated file: sum_helicity_FLT_velocity_01mednegra.txt
# Generated file: sum_helicity_FLT_velocity_02mednegra.txt
# Generated file: sum_helicity_FLT_velocity_03mednegra.txt
# Generated file: sum_helicity_FLT_velocity_04mednegra.txt
# Generated file: sum_helicity_FLT_velocity_05mednegra.txt
# Generated accumulated helicity files for Lab_Gamma, Matutino shift Baseline, Triad FLT.
# Generated file: sum_helicity_PRB_velocity_01mednegra.txt
# Generated file: sum_helicity_PRB_velocity_02mednegra.txt
# Generated file: sum_helicity_PRB_velocity_03mednegra.txt
# Generated file: sum_helicity_PRB_velocity_04mednegra.txt
# Generated file: sum_helicity_PRB_velocity_05mednegra.txt
# Generated accumulated helicity files for Lab_Gamma, Matutino shift Baseline, Triad PRB.
# Generated file: sum_helicity_FRB_velocity_01mednegra.txt
# Generated file: sum_helicity_FRB_velocity_02mednegra.txt
# Generated file: sum_helicity_FRB_velocity_03mednegra.txt
# Generated file: sum_helicity_FRB_velocity_04mednegra.txt
# Generated file: sum_helicity_FRB_velocity_05mednegra.txt
# Generated accumulated helicity files for Lab_Gamma, Matutino shift Baseline, Triad FRB.
# Generated file: sum_helicity_PLT_velocity_01mednegra.txt
# Generated file: sum_helicity_PLT_velocity_02mednegra.txt
# Generated file: sum_helicity_PLT_velocity_03mednegra.txt
# Generated file: sum_helicity_PLT_velocity_04mednegra.txt
# Generated file: sum_helicity_PLT_velocity_05mednegra.txt
# Generated accumulated helicity files for Lab_Gamma, Matutino shift Baseline, Triad PLT.
# Generated file: sum_helicity_FLB_velocity_01mednegra.txt
# Generated file: sum_helicity_FLB_velocity_02mednegra.txt
# Generated file: sum_helicity_FLB_velocity_03mednegra.txt
# Generated file: sum_helicity_FLB_velocity_04mednegra.txt
# Generated file: sum_helicity_FLB_velocity_05mednegra.txt
# Generated accumulated helicity files for Lab_Gamma, Matutino shift Baseline, Triad FLB.
# Generated file: sum_helicity_PRT_velocity_01mednegra.txt
# Generated file: sum_helicity_PRT_velocity_02mednegra.txt
# Generated file: sum_helicity_PRT_velocity_03mednegra.txt
# Generated file: sum_helicity_PRT_velocity_04mednegra.txt
# Generated file: sum_helicity_PRT_velocity_05mednegra.txt
# Generated accumulated helicity files for Lab_Gamma, Matutino shift Baseline, Triad PRT.
# Generated file: sum_helicity_RTB_velocity_01mednegra.txt
# Generated file: sum_helicity_RTB_velocity_02mednegra.txt
# Generated file: sum_helicity_RTB_velocity_03mednegra.txt
# Generated file: sum_helicity_RTB_velocity_04mednegra.txt
# Generated file: sum_helicity_RTB_velocity_05mednegra.txt
# Generated accumulated helicity files for Lab_Gamma, Matutino shift Baseline, Triad RTB.
# Generated file: sum_helicity_FLP_velocity_01mednegra.txt
# Generated file: sum_helicity_FLP_velocity_02mednegra.txt
# Generated file: sum_helicity_FLP_velocity_03mednegra.txt
# Generated file: sum_helicity_FLP_velocity_04mednegra.txt
# Generated file: sum_helicity_FLP_velocity_05mednegra.txt
# Generated accumulated helicity files for Lab_Gamma, Matutino shift Baseline, Triad FLP.
# Generated file: sum_helicity_LTB_velocity_01mednegra.txt
# Generated file: sum_helicity_LTB_velocity_02mednegra.txt
# Generated file: sum_helicity_LTB_velocity_03mednegra.txt
# Generated file: sum_helicity_LTB_velocity_04mednegra.txt
# Generated file: sum_helicity_LTB_velocity_05mednegra.txt
# Generated accumulated helicity files for Lab_Gamma, Matutino shift Baseline, Triad LTB.
# Generated file: sum_helicity_FRP_velocity_01mednegra.txt
# Generated file: sum_helicity_FRP_velocity_02mednegra.txt
# Generated file: sum_helicity_FRP_velocity_03mednegra.txt
# Generated file: sum_helicity_FRP_velocity_04mednegra.txt
# Generated file: sum_helicity_FRP_velocity_05mednegra.txt
# Generated accumulated helicity files for Lab_Gamma, Matutino shift Baseline, Triad FRP.
# Generated file: sum_helicity_FRT_velocity_01medamarilla.txt
# Generated file: sum_helicity_FRT_velocity_02medroja.txt
# Generated file: sum_helicity_FRT_velocity_03medroja.txt
# Generated file: sum_helicity_FRT_velocity_04medroja.txt
# Generated accumulated helicity files for Lab_Gamma, Matutino shift Experimental Color, Triad FRT.
# Generated file: sum_helicity_PLB_velocity_01medamarilla.txt
# Generated file: sum_helicity_PLB_velocity_02medroja.txt
# Generated file: sum_helicity_PLB_velocity_03medroja.txt
# Generated file: sum_helicity_PLB_velocity_04medroja.txt
# Generated accumulated helicity files for Lab_Gamma, Matutino shift Experimental Color, Triad PLB.
# Generated file: sum_helicity_FLT_velocity_01medamarilla.txt
# Generated file: sum_helicity_FLT_velocity_02medroja.txt
# Generated file: sum_helicity_FLT_velocity_03medroja.txt
# Generated file: sum_helicity_FLT_velocity_04medroja.txt
# Generated accumulated helicity files for Lab_Gamma, Matutino shift Experimental Color, Triad FLT.
# Generated file: sum_helicity_PRB_velocity_01medamarilla.txt
# Generated file: sum_helicity_PRB_velocity_02medroja.txt
# Generated file: sum_helicity_PRB_velocity_03medroja.txt
# Generated file: sum_helicity_PRB_velocity_04medroja.txt
# Generated accumulated helicity files for Lab_Gamma, Matutino shift Experimental Color, Triad PRB.
# Generated file: sum_helicity_FRB_velocity_01medamarilla.txt
# Generated file: sum_helicity_FRB_velocity_02medroja.txt
# Generated file: sum_helicity_FRB_velocity_03medroja.txt
# Generated file: sum_helicity_FRB_velocity_04medroja.txt
# Generated accumulated helicity files for Lab_Gamma, Matutino shift Experimental Color, Triad FRB.
# Generated file: sum_helicity_PLT_velocity_01medamarilla.txt
# Generated file: sum_helicity_PLT_velocity_02medroja.txt
# Generated file: sum_helicity_PLT_velocity_03medroja.txt
# Generated file: sum_helicity_PLT_velocity_04medroja.txt
# Generated accumulated helicity files for Lab_Gamma, Matutino shift Experimental Color, Triad PLT.
# Generated file: sum_helicity_FLB_velocity_01medamarilla.txt
# Generated file: sum_helicity_FLB_velocity_02medroja.txt
# Generated file: sum_helicity_FLB_velocity_03medroja.txt
# Generated file: sum_helicity_FLB_velocity_04medroja.txt
# Generated accumulated helicity files for Lab_Gamma, Matutino shift Experimental Color, Triad FLB.
# Generated file: sum_helicity_PRT_velocity_01medamarilla.txt
# Generated file: sum_helicity_PRT_velocity_02medroja.txt
# Generated file: sum_helicity_PRT_velocity_03medroja.txt
# Generated file: sum_helicity_PRT_velocity_04medroja.txt
# Generated accumulated helicity files for Lab_Gamma, Matutino shift Experimental Color, Triad PRT.
# Generated file: sum_helicity_RTB_velocity_01medamarilla.txt
# Generated file: sum_helicity_RTB_velocity_02medroja.txt
# Generated file: sum_helicity_RTB_velocity_03medroja.txt
# Generated file: sum_helicity_RTB_velocity_04medroja.txt
# Generated accumulated helicity files for Lab_Gamma, Matutino shift Experimental Color, Triad RTB.
# Generated file: sum_helicity_FLP_velocity_01medamarilla.txt
# Generated file: sum_helicity_FLP_velocity_02medroja.txt
# Generated file: sum_helicity_FLP_velocity_03medroja.txt
# Generated file: sum_helicity_FLP_velocity_04medroja.txt
# Generated accumulated helicity files for Lab_Gamma, Matutino shift Experimental Color, Triad FLP.
# Generated file: sum_helicity_LTB_velocity_01medamarilla.txt
# Generated file: sum_helicity_LTB_velocity_02medroja.txt
# Generated file: sum_helicity_LTB_velocity_03medroja.txt
# Generated file: sum_helicity_LTB_velocity_04medroja.txt
# Generated accumulated helicity files for Lab_Gamma, Matutino shift Experimental Color, Triad LTB.
# Generated file: sum_helicity_FRP_velocity_01medamarilla.txt
# Generated file: sum_helicity_FRP_velocity_02medroja.txt
# Generated file: sum_helicity_FRP_velocity_03medroja.txt
# Generated file: sum_helicity_FRP_velocity_04medroja.txt
# Generated accumulated helicity files for Lab_Gamma, Matutino shift Experimental Color, Triad FRP.
# Processing complete. All accumulated helicity results are saved in their respective directories.

# %% [markdown]
# ## 9
#
# $$
#
#     \Huge \text{First Integral of Absolute Values of Helicity}
#
# $$

# %%
#Integral absoluta helicidad .txt
import os
import re

def process_file_absolute(file_path, output_file_path):
    # Leer las líneas del archivo
    with open(file_path, 'r') as file:
        lines = file.readlines()
    
    # Extraer los valores de helicidad y calcular la suma de los valores absolutos
    absolute_helicity_sum = 0
    results = []
    for line in lines:
        time_stamp, value = line.split('->')
        value = abs(float(value.strip()))  # Uso de valor absoluto
        absolute_helicity_sum += value
        results.append(f"{time_stamp.strip()} -> {absolute_helicity_sum:.10f}\n")

    # Escribir los resultados de la suma de valores absolutos en un nuevo archivo
    with open(output_file_path, 'w') as output_file:
        output_file.writelines(results)

def generate_absolute_helicity_sum(input_directory, output_directory):
    # Crear el directorio de salida si no existe
    if not os.path.exists(output_directory):
        os.makedirs(output_directory)

    # Leer todos los archivos en el directorio especificado
    for root, dirs, files in os.walk(input_directory):
        for filename in files:
            if filename.endswith(".txt"):
                file_path = os.path.join(root, filename)
                output_filename = f"sum_absolute_{filename}"  # Cambio en el nombre del archivo de salida para reflejar los valores absolutos
                output_file_path = os.path.join(output_directory, output_filename)
                # Procesar el archivo
                process_file_absolute(file_path, output_file_path)
                # Imprimir en consola el nombre del archivo generado
                print(f"Generated file: {output_filename}")

def find_experiment_folder(root_folder, lab, shift):
    date_regex = re.compile(r'\d{2}[A-Za-z]{3}\d{2}')
    for folder in os.listdir(root_folder):
        if date_regex.search(folder) and lab in folder:
            for subfolder in os.listdir(os.path.join(root_folder, folder)):
                if date_regex.search(subfolder) and shift in subfolder:
                    return os.path.join(root_folder, folder, subfolder), date_regex.search(folder).group(0)
    return None, None

def process_lab_absolute_helicity(root_folder, lab_name, shift, file_suffixes, triad_codes):
    shift_name = "Vespertino" if shift == 'V' else "Matutino"
    experiment_folder, date_str = find_experiment_folder(root_folder, lab_name, shift)
    if not experiment_folder:
        print(f"No se encontró ningún directorio para {lab_name}, {shift}.")
        return

    input_folder_base = os.path.join(experiment_folder, "Data Analysis", "Processing Data")
    
    if not os.path.exists(input_folder_base):
        print(f"Skipping {shift_name} shift for {lab_name} as directory does not exist: {input_folder_base}")
        return

    # Procesar los acumulados absolutos de Baseline para cada triada
    for triad, triad_code in triad_codes.items():
        input_directory = os.path.join(input_folder_base, "Helicity_Baseline", triad_code)
        output_directory = os.path.join(input_folder_base, "Sum_Absolute_Helicity_Baseline", triad_code)
        if os.path.exists(input_directory):
            generate_absolute_helicity_sum(input_directory, output_directory)
            print(f"Generated absolute helicity sum files for {lab_name}, {shift_name} shift Baseline, Triad {triad_code}.")
        else:
            print(f"Skipping {shift_name} shift for {lab_name} Baseline Triad {triad_code} as directory does not exist: {input_directory}")

    # Procesar los acumulados absolutos de Experimental Color para cada triada
    for triad, triad_code in triad_codes.items():
        input_directory = os.path.join(input_folder_base, "Helicity_Experimental_Color", triad_code)
        output_directory = os.path.join(input_folder_base, "Sum_Absolute_Helicity_Experimental_Color", triad_code)
        if os.path.exists(input_directory):
            generate_absolute_helicity_sum(input_directory, output_directory)
            print(f"Generated absolute helicity sum files for {lab_name}, {shift_name} shift Experimental Color, Triad {triad_code}.")
        else:
            print(f"Skipping {shift_name} shift for {lab_name} Experimental Color Triad {triad_code} as directory does not exist: {input_directory}")

# Define the root folder, suffixes, and triad codes
file_suffixes = ["medroja.txt", "medmorada.txt", "medazul.txt", "medverde.txt", "medamarilla.txt", "mednegra.txt"]
triad_codes = {
    (0, 2, 4): "FRT",  
    (1, 3, 5): "PLB",  
    (0, 3, 4): "FLT",  
    (1, 2, 5): "PRB",  
    (0, 2, 5): "FRB",  
    (1, 3, 4): "PLT",  
    (0, 3, 5): "FLB",  
    (1, 2, 4): "PRT",  
    (2, 4, 5): "RTB",  
    (0, 1, 3): "FLP",  
    (3, 4, 5): "LTB",  
    (0, 1, 2): "FRP"
}

# Procesar todos los laboratorios y turnos
labs = ["Lab_Betta", "Lab_Gamma"]

for lab_name in labs:
    for shift in ['V', 'M']:
        process_lab_absolute_helicity(root_folder, lab_name, shift, file_suffixes, triad_codes)

print("Processing complete. All absolute helicity sum results are saved in their respective directories.")
# Out:
# No se encontró ningún directorio para Lab_Betta, V.
# No se encontró ningún directorio para Lab_Betta, M.
# No se encontró ningún directorio para Lab_Gamma, V.
# Generated file: sum_absolute_helicity_FRT_velocity_01mednegra.txt
# Generated file: sum_absolute_helicity_FRT_velocity_02mednegra.txt
# Generated file: sum_absolute_helicity_FRT_velocity_03mednegra.txt
# Generated file: sum_absolute_helicity_FRT_velocity_04mednegra.txt
# Generated file: sum_absolute_helicity_FRT_velocity_05mednegra.txt
# Generated absolute helicity sum files for Lab_Gamma, Matutino shift Baseline, Triad FRT.
# Generated file: sum_absolute_helicity_PLB_velocity_01mednegra.txt
# Generated file: sum_absolute_helicity_PLB_velocity_02mednegra.txt
# Generated file: sum_absolute_helicity_PLB_velocity_03mednegra.txt
# Generated file: sum_absolute_helicity_PLB_velocity_04mednegra.txt
# Generated file: sum_absolute_helicity_PLB_velocity_05mednegra.txt
# Generated absolute helicity sum files for Lab_Gamma, Matutino shift Baseline, Triad PLB.
# Generated file: sum_absolute_helicity_FLT_velocity_01mednegra.txt
# Generated file: sum_absolute_helicity_FLT_velocity_02mednegra.txt
# Generated file: sum_absolute_helicity_FLT_velocity_03mednegra.txt
# Generated file: sum_absolute_helicity_FLT_velocity_04mednegra.txt
# Generated file: sum_absolute_helicity_FLT_velocity_05mednegra.txt
# Generated absolute helicity sum files for Lab_Gamma, Matutino shift Baseline, Triad FLT.
# Generated file: sum_absolute_helicity_PRB_velocity_01mednegra.txt
# Generated file: sum_absolute_helicity_PRB_velocity_02mednegra.txt
# Generated file: sum_absolute_helicity_PRB_velocity_03mednegra.txt
# Generated file: sum_absolute_helicity_PRB_velocity_04mednegra.txt
# Generated file: sum_absolute_helicity_PRB_velocity_05mednegra.txt
# Generated absolute helicity sum files for Lab_Gamma, Matutino shift Baseline, Triad PRB.
# Generated file: sum_absolute_helicity_FRB_velocity_01mednegra.txt
# Generated file: sum_absolute_helicity_FRB_velocity_02mednegra.txt
# Generated file: sum_absolute_helicity_FRB_velocity_03mednegra.txt
# Generated file: sum_absolute_helicity_FRB_velocity_04mednegra.txt
# Generated file: sum_absolute_helicity_FRB_velocity_05mednegra.txt
# Generated absolute helicity sum files for Lab_Gamma, Matutino shift Baseline, Triad FRB.
# Generated file: sum_absolute_helicity_PLT_velocity_01mednegra.txt
# Generated file: sum_absolute_helicity_PLT_velocity_02mednegra.txt
# Generated file: sum_absolute_helicity_PLT_velocity_03mednegra.txt
# Generated file: sum_absolute_helicity_PLT_velocity_04mednegra.txt
# Generated file: sum_absolute_helicity_PLT_velocity_05mednegra.txt
# Generated absolute helicity sum files for Lab_Gamma, Matutino shift Baseline, Triad PLT.
# Generated file: sum_absolute_helicity_FLB_velocity_01mednegra.txt
# Generated file: sum_absolute_helicity_FLB_velocity_02mednegra.txt
# Generated file: sum_absolute_helicity_FLB_velocity_03mednegra.txt
# Generated file: sum_absolute_helicity_FLB_velocity_04mednegra.txt
# Generated file: sum_absolute_helicity_FLB_velocity_05mednegra.txt
# Generated absolute helicity sum files for Lab_Gamma, Matutino shift Baseline, Triad FLB.
# Generated file: sum_absolute_helicity_PRT_velocity_01mednegra.txt
# Generated file: sum_absolute_helicity_PRT_velocity_02mednegra.txt
# Generated file: sum_absolute_helicity_PRT_velocity_03mednegra.txt
# Generated file: sum_absolute_helicity_PRT_velocity_04mednegra.txt
# Generated file: sum_absolute_helicity_PRT_velocity_05mednegra.txt
# Generated absolute helicity sum files for Lab_Gamma, Matutino shift Baseline, Triad PRT.
# Generated file: sum_absolute_helicity_RTB_velocity_01mednegra.txt
# Generated file: sum_absolute_helicity_RTB_velocity_02mednegra.txt
# Generated file: sum_absolute_helicity_RTB_velocity_03mednegra.txt
# Generated file: sum_absolute_helicity_RTB_velocity_04mednegra.txt
# Generated file: sum_absolute_helicity_RTB_velocity_05mednegra.txt
# Generated absolute helicity sum files for Lab_Gamma, Matutino shift Baseline, Triad RTB.
# Generated file: sum_absolute_helicity_FLP_velocity_01mednegra.txt
# Generated file: sum_absolute_helicity_FLP_velocity_02mednegra.txt
# Generated file: sum_absolute_helicity_FLP_velocity_03mednegra.txt
# Generated file: sum_absolute_helicity_FLP_velocity_04mednegra.txt
# Generated file: sum_absolute_helicity_FLP_velocity_05mednegra.txt
# Generated absolute helicity sum files for Lab_Gamma, Matutino shift Baseline, Triad FLP.
# Generated file: sum_absolute_helicity_LTB_velocity_01mednegra.txt
# Generated file: sum_absolute_helicity_LTB_velocity_02mednegra.txt
# Generated file: sum_absolute_helicity_LTB_velocity_03mednegra.txt
# Generated file: sum_absolute_helicity_LTB_velocity_04mednegra.txt
# Generated file: sum_absolute_helicity_LTB_velocity_05mednegra.txt
# Generated absolute helicity sum files for Lab_Gamma, Matutino shift Baseline, Triad LTB.
# Generated file: sum_absolute_helicity_FRP_velocity_01mednegra.txt
# Generated file: sum_absolute_helicity_FRP_velocity_02mednegra.txt
# Generated file: sum_absolute_helicity_FRP_velocity_03mednegra.txt
# Generated file: sum_absolute_helicity_FRP_velocity_04mednegra.txt
# Generated file: sum_absolute_helicity_FRP_velocity_05mednegra.txt
# Generated absolute helicity sum files for Lab_Gamma, Matutino shift Baseline, Triad FRP.
# Generated file: sum_absolute_helicity_FRT_velocity_01medamarilla.txt
# Generated file: sum_absolute_helicity_FRT_velocity_02medroja.txt
# Generated file: sum_absolute_helicity_FRT_velocity_03medroja.txt
# Generated file: sum_absolute_helicity_FRT_velocity_04medroja.txt
# Generated absolute helicity sum files for Lab_Gamma, Matutino shift Experimental Color, Triad FRT.
# Generated file: sum_absolute_helicity_PLB_velocity_01medamarilla.txt
# Generated file: sum_absolute_helicity_PLB_velocity_02medroja.txt
# Generated file: sum_absolute_helicity_PLB_velocity_03medroja.txt
# Generated file: sum_absolute_helicity_PLB_velocity_04medroja.txt
# Generated absolute helicity sum files for Lab_Gamma, Matutino shift Experimental Color, Triad PLB.
# Generated file: sum_absolute_helicity_FLT_velocity_01medamarilla.txt
# Generated file: sum_absolute_helicity_FLT_velocity_02medroja.txt
# Generated file: sum_absolute_helicity_FLT_velocity_03medroja.txt
# Generated file: sum_absolute_helicity_FLT_velocity_04medroja.txt
# Generated absolute helicity sum files for Lab_Gamma, Matutino shift Experimental Color, Triad FLT.
# Generated file: sum_absolute_helicity_PRB_velocity_01medamarilla.txt
# Generated file: sum_absolute_helicity_PRB_velocity_02medroja.txt
# Generated file: sum_absolute_helicity_PRB_velocity_03medroja.txt
# Generated file: sum_absolute_helicity_PRB_velocity_04medroja.txt
# Generated absolute helicity sum files for Lab_Gamma, Matutino shift Experimental Color, Triad PRB.
# Generated file: sum_absolute_helicity_FRB_velocity_01medamarilla.txt
# Generated file: sum_absolute_helicity_FRB_velocity_02medroja.txt
# Generated file: sum_absolute_helicity_FRB_velocity_03medroja.txt
# Generated file: sum_absolute_helicity_FRB_velocity_04medroja.txt
# Generated absolute helicity sum files for Lab_Gamma, Matutino shift Experimental Color, Triad FRB.
# Generated file: sum_absolute_helicity_PLT_velocity_01medamarilla.txt
# Generated file: sum_absolute_helicity_PLT_velocity_02medroja.txt
# Generated file: sum_absolute_helicity_PLT_velocity_03medroja.txt
# Generated file: sum_absolute_helicity_PLT_velocity_04medroja.txt
# Generated absolute helicity sum files for Lab_Gamma, Matutino shift Experimental Color, Triad PLT.
# Generated file: sum_absolute_helicity_FLB_velocity_01medamarilla.txt
# Generated file: sum_absolute_helicity_FLB_velocity_02medroja.txt
# Generated file: sum_absolute_helicity_FLB_velocity_03medroja.txt
# Generated file: sum_absolute_helicity_FLB_velocity_04medroja.txt
# Generated absolute helicity sum files for Lab_Gamma, Matutino shift Experimental Color, Triad FLB.
# Generated file: sum_absolute_helicity_PRT_velocity_01medamarilla.txt
# Generated file: sum_absolute_helicity_PRT_velocity_02medroja.txt
# Generated file: sum_absolute_helicity_PRT_velocity_03medroja.txt
# Generated file: sum_absolute_helicity_PRT_velocity_04medroja.txt
# Generated absolute helicity sum files for Lab_Gamma, Matutino shift Experimental Color, Triad PRT.
# Generated file: sum_absolute_helicity_RTB_velocity_01medamarilla.txt
# Generated file: sum_absolute_helicity_RTB_velocity_02medroja.txt
# Generated file: sum_absolute_helicity_RTB_velocity_03medroja.txt
# Generated file: sum_absolute_helicity_RTB_velocity_04medroja.txt
# Generated absolute helicity sum files for Lab_Gamma, Matutino shift Experimental Color, Triad RTB.
# Generated file: sum_absolute_helicity_FLP_velocity_01medamarilla.txt
# Generated file: sum_absolute_helicity_FLP_velocity_02medroja.txt
# Generated file: sum_absolute_helicity_FLP_velocity_03medroja.txt
# Generated file: sum_absolute_helicity_FLP_velocity_04medroja.txt
# Generated absolute helicity sum files for Lab_Gamma, Matutino shift Experimental Color, Triad FLP.
# Generated file: sum_absolute_helicity_LTB_velocity_01medamarilla.txt
# Generated file: sum_absolute_helicity_LTB_velocity_02medroja.txt
# Generated file: sum_absolute_helicity_LTB_velocity_03medroja.txt
# Generated file: sum_absolute_helicity_LTB_velocity_04medroja.txt
# Generated absolute helicity sum files for Lab_Gamma, Matutino shift Experimental Color, Triad LTB.
# Generated file: sum_absolute_helicity_FRP_velocity_01medamarilla.txt
# Generated file: sum_absolute_helicity_FRP_velocity_02medroja.txt
# Generated file: sum_absolute_helicity_FRP_velocity_03medroja.txt
# Generated file: sum_absolute_helicity_FRP_velocity_04medroja.txt
# Generated absolute helicity sum files for Lab_Gamma, Matutino shift Experimental Color, Triad FRP.
# Processing complete. All absolute helicity sum results are saved in their respective directories.

# %% [markdown]
# ## 10
#
# $$
#
#     \Huge \text{General Enstrophy File Generator}
#
# $$

# %%
#Enstrofía general .txt
import numpy as np
import os
import re

def read_vorticity_data(filepath):
    data = []
    timestamps = []
    try:
        with open(filepath, 'r') as file:
            for line in file:
                parts = line.strip().split(' -> ')
                if len(parts) > 1:
                    timestamps.append(parts[0])
                    vorticity_components = parts[1].strip('()').split(', ')
                    data.append([float(v) for v in vorticity_components])
        return timestamps, np.array(data)
    except Exception as e:
        print(f"Error reading file {filepath}: {e}")
        return [], np.array([])

def calculate_enstrophy(vorticities, volume):
    # Enstrophy calculation: sum of the squares of vorticity components, multiplied by volume
    enstrophy = np.sum(vorticities**2, axis=1) * volume
    return enstrophy

def format_and_save_enstrophies(timestamps, enstrophies, filename):
    try:
        with open(filename, "w") as file:
            for timestamp, enstrophy in zip(timestamps, enstrophies):
                formatted_output = f"{timestamp} -> {enstrophy:.10f}\n"
                file.write(formatted_output)
    except Exception as e:
        print(f"Error writing file {filename}: {e}")

def process_files_enstrophy(input_folder, output_folder, file_suffixes, volume):
    os.makedirs(output_folder, exist_ok=True)
    generated_files = []  # Lista para almacenar los nombres de los archivos generados

    for root, dirs, files in os.walk(input_folder):
        for filename in files:
            for file_suffix in file_suffixes:
                if filename.endswith(file_suffix):
                    base_filename = filename[:-len(file_suffix)]  # Correctly removing the suffix
                    
                    filepath_vorticity = os.path.join(root, filename)
                    
                    timestamps, vorticity = read_vorticity_data(filepath_vorticity)
                    if vorticity.size == 0:
                        continue
                    
                    enstrophy = calculate_enstrophy(vorticity, volume)
                    
                    output_filename = f"enstrophy_{base_filename}{file_suffix}"
                    output_filepath = os.path.join(output_folder, output_filename)
                    
                    format_and_save_enstrophies(timestamps, enstrophy, output_filepath)
                    generated_files.append(f"{os.path.basename(output_folder)}/{output_filename}")

    return generated_files  # Devolver la lista de archivos generados

def find_experiment_folder(root_folder, lab, shift):
    date_regex = re.compile(r'\d{2}[A-Za-z]{3}\d{2}')
    for folder in os.listdir(root_folder):
        if date_regex.search(folder) and lab in folder:
            for subfolder in os.listdir(os.path.join(root_folder, folder)):
                if date_regex.search(subfolder) and shift in subfolder:
                    return os.path.join(root_folder, folder, subfolder), date_regex.search(folder).group(0)
    return None, None

def process_lab_enstrophy(root_folder, lab_name, shift, file_suffixes, volume, triad_codes):
    shift_name = "Vespertino" if shift == 'V' else "Matutino"
    experiment_folder, date_str = find_experiment_folder(root_folder, lab_name, shift)
    if not experiment_folder:
        print(f"No se encontró ningún directorio para {lab_name}, {shift}.")
        return

    input_folder_base = os.path.join(experiment_folder, "Data Analysis", "Processing Data")
    
    if not os.path.exists(input_folder_base):
        print(f"Skipping {shift_name} shift for {lab_name} as directory does not exist: {input_folder_base}")
        return

    # Procesar enstrofia de Baseline para cada triada
    for triad, triad_code in triad_codes.items():
        input_directory = os.path.join(input_folder_base, "Vorticity_Baseline", triad_code)
        output_directory = os.path.join(input_folder_base, "Enstrophy_Baseline", triad_code)
        if os.path.exists(input_directory):
            generated_files = process_files_enstrophy(input_directory, output_directory, file_suffixes, volume)
            print(f"Generated enstrophy files for {lab_name}, {shift_name} shift Baseline, Triad {triad_code}:")
            for file in generated_files:
                print(f"  - {file}")
        else:
            print(f"Skipping {shift_name} shift for {lab_name} Baseline Triad {triad_code} as directory does not exist: {input_directory}")

    # Procesar enstrofia de Experimental Color para cada triada
    for triad, triad_code in triad_codes.items():
        input_directory = os.path.join(input_folder_base, "Vorticity_Experimental_Color", triad_code)
        output_directory = os.path.join(input_folder_base, "Enstrophy_Experimental_Color", triad_code)
        if os.path.exists(input_directory):
            generated_files = process_files_enstrophy(input_directory, output_directory, file_suffixes, volume)
            print(f"Generated enstrophy files for {lab_name}, {shift_name} shift Experimental Color, Triad {triad_code}:")
            for file in generated_files:
                print(f"  - {file}")
        else:
            print(f"Skipping {shift_name} shift for {lab_name} Experimental Color Triad {triad_code} as directory does not exist: {input_directory}")

# Define the root folder, suffixes, and triad codes
file_suffixes = ["medroja.txt", "medmorada.txt", "medazul.txt", "medverde.txt", "medamarilla.txt", "mednegra.txt"]
triad_codes = {
    (0, 2, 4): "FRT",  
    (1, 3, 5): "PLB",  
    (0, 3, 4): "FLT",  
    (1, 2, 5): "PRB",  
    (0, 2, 5): "FRB",  
    (1, 3, 4): "PLT",  
    (0, 3, 5): "FLB",  
    (1, 2, 4): "PRT",  
    (2, 4, 5): "RTB",  
    (0, 1, 3): "FLP",  
    (3, 4, 5): "LTB",  
    (0, 1, 2): "FRP"
}

# Volumes for each lab
volumes = {
    "Lab_Betta": 7.3195 , # Volume for Lab A
    "Lab_Gamma": 6.8342   # Volume for Lab B (example)
}

# Procesar todos los laboratorios y turnos
labs = ["Lab_Betta", "Lab_Gamma"]

for lab_name in labs:
    for shift in ['V', 'M']:
        process_lab_enstrophy(root_folder, lab_name, shift, file_suffixes, volumes[lab_name], triad_codes)

print("Processing complete. All enstrophy results are saved in their respective directories.")
# Out:
# No se encontró ningún directorio para Lab_Betta, V.
# No se encontró ningún directorio para Lab_Betta, M.
# No se encontró ningún directorio para Lab_Gamma, V.
# Generated enstrophy files for Lab_Gamma, Matutino shift Baseline, Triad FRT:
#   - FRT/enstrophy_vorticity_FRT_velocity_01mednegra.txt
#   - FRT/enstrophy_vorticity_FRT_velocity_02mednegra.txt
#   - FRT/enstrophy_vorticity_FRT_velocity_03mednegra.txt
#   - FRT/enstrophy_vorticity_FRT_velocity_04mednegra.txt
#   - FRT/enstrophy_vorticity_FRT_velocity_05mednegra.txt
# Generated enstrophy files for Lab_Gamma, Matutino shift Baseline, Triad PLB:
#   - PLB/enstrophy_vorticity_PLB_velocity_01mednegra.txt
#   - PLB/enstrophy_vorticity_PLB_velocity_02mednegra.txt
#   - PLB/enstrophy_vorticity_PLB_velocity_03mednegra.txt
#   - PLB/enstrophy_vorticity_PLB_velocity_04mednegra.txt
#   - PLB/enstrophy_vorticity_PLB_velocity_05mednegra.txt
# Generated enstrophy files for Lab_Gamma, Matutino shift Baseline, Triad FLT:
#   - FLT/enstrophy_vorticity_FLT_velocity_01mednegra.txt
#   - FLT/enstrophy_vorticity_FLT_velocity_02mednegra.txt
#   - FLT/enstrophy_vorticity_FLT_velocity_03mednegra.txt
#   - FLT/enstrophy_vorticity_FLT_velocity_04mednegra.txt
#   - FLT/enstrophy_vorticity_FLT_velocity_05mednegra.txt
# Generated enstrophy files for Lab_Gamma, Matutino shift Baseline, Triad PRB:
#   - PRB/enstrophy_vorticity_PRB_velocity_01mednegra.txt
#   - PRB/enstrophy_vorticity_PRB_velocity_02mednegra.txt
#   - PRB/enstrophy_vorticity_PRB_velocity_03mednegra.txt
#   - PRB/enstrophy_vorticity_PRB_velocity_04mednegra.txt
#   - PRB/enstrophy_vorticity_PRB_velocity_05mednegra.txt
# Generated enstrophy files for Lab_Gamma, Matutino shift Baseline, Triad FRB:
#   - FRB/enstrophy_vorticity_FRB_velocity_01mednegra.txt
#   - FRB/enstrophy_vorticity_FRB_velocity_02mednegra.txt
#   - FRB/enstrophy_vorticity_FRB_velocity_03mednegra.txt
#   - FRB/enstrophy_vorticity_FRB_velocity_04mednegra.txt
#   - FRB/enstrophy_vorticity_FRB_velocity_05mednegra.txt
# Generated enstrophy files for Lab_Gamma, Matutino shift Baseline, Triad PLT:
#   - PLT/enstrophy_vorticity_PLT_velocity_01mednegra.txt
#   - PLT/enstrophy_vorticity_PLT_velocity_02mednegra.txt
#   - PLT/enstrophy_vorticity_PLT_velocity_03mednegra.txt
#   - PLT/enstrophy_vorticity_PLT_velocity_04mednegra.txt
#   - PLT/enstrophy_vorticity_PLT_velocity_05mednegra.txt
# Generated enstrophy files for Lab_Gamma, Matutino shift Baseline, Triad FLB:
#   - FLB/enstrophy_vorticity_FLB_velocity_01mednegra.txt
#   - FLB/enstrophy_vorticity_FLB_velocity_02mednegra.txt
#   - FLB/enstrophy_vorticity_FLB_velocity_03mednegra.txt
#   - FLB/enstrophy_vorticity_FLB_velocity_04mednegra.txt
#   - FLB/enstrophy_vorticity_FLB_velocity_05mednegra.txt
# Generated enstrophy files for Lab_Gamma, Matutino shift Baseline, Triad PRT:
#   - PRT/enstrophy_vorticity_PRT_velocity_01mednegra.txt
#   - PRT/enstrophy_vorticity_PRT_velocity_02mednegra.txt
#   - PRT/enstrophy_vorticity_PRT_velocity_03mednegra.txt
#   - PRT/enstrophy_vorticity_PRT_velocity_04mednegra.txt
#   - PRT/enstrophy_vorticity_PRT_velocity_05mednegra.txt
# Generated enstrophy files for Lab_Gamma, Matutino shift Baseline, Triad RTB:
#   - RTB/enstrophy_vorticity_RTB_velocity_01mednegra.txt
#   - RTB/enstrophy_vorticity_RTB_velocity_02mednegra.txt
#   - RTB/enstrophy_vorticity_RTB_velocity_03mednegra.txt
#   - RTB/enstrophy_vorticity_RTB_velocity_04mednegra.txt
#   - RTB/enstrophy_vorticity_RTB_velocity_05mednegra.txt
# Generated enstrophy files for Lab_Gamma, Matutino shift Baseline, Triad FLP:
#   - FLP/enstrophy_vorticity_FLP_velocity_01mednegra.txt
#   - FLP/enstrophy_vorticity_FLP_velocity_02mednegra.txt
#   - FLP/enstrophy_vorticity_FLP_velocity_03mednegra.txt
#   - FLP/enstrophy_vorticity_FLP_velocity_04mednegra.txt
#   - FLP/enstrophy_vorticity_FLP_velocity_05mednegra.txt
# Generated enstrophy files for Lab_Gamma, Matutino shift Baseline, Triad LTB:
#   - LTB/enstrophy_vorticity_LTB_velocity_01mednegra.txt
#   - LTB/enstrophy_vorticity_LTB_velocity_02mednegra.txt
#   - LTB/enstrophy_vorticity_LTB_velocity_03mednegra.txt
#   - LTB/enstrophy_vorticity_LTB_velocity_04mednegra.txt
#   - LTB/enstrophy_vorticity_LTB_velocity_05mednegra.txt
# Generated enstrophy files for Lab_Gamma, Matutino shift Baseline, Triad FRP:
#   - FRP/enstrophy_vorticity_FRP_velocity_01mednegra.txt
#   - FRP/enstrophy_vorticity_FRP_velocity_02mednegra.txt
#   - FRP/enstrophy_vorticity_FRP_velocity_03mednegra.txt
#   - FRP/enstrophy_vorticity_FRP_velocity_04mednegra.txt
#   - FRP/enstrophy_vorticity_FRP_velocity_05mednegra.txt
# Generated enstrophy files for Lab_Gamma, Matutino shift Experimental Color, Triad FRT:
#   - FRT/enstrophy_vorticity_FRT_velocity_01medamarilla.txt
#   - FRT/enstrophy_vorticity_FRT_velocity_02medroja.txt
#   - FRT/enstrophy_vorticity_FRT_velocity_03medroja.txt
#   - FRT/enstrophy_vorticity_FRT_velocity_04medroja.txt
# Generated enstrophy files for Lab_Gamma, Matutino shift Experimental Color, Triad PLB:
#   - PLB/enstrophy_vorticity_PLB_velocity_01medamarilla.txt
#   - PLB/enstrophy_vorticity_PLB_velocity_02medroja.txt
#   - PLB/enstrophy_vorticity_PLB_velocity_03medroja.txt
#   - PLB/enstrophy_vorticity_PLB_velocity_04medroja.txt
# Generated enstrophy files for Lab_Gamma, Matutino shift Experimental Color, Triad FLT:
#   - FLT/enstrophy_vorticity_FLT_velocity_01medamarilla.txt
#   - FLT/enstrophy_vorticity_FLT_velocity_02medroja.txt
#   - FLT/enstrophy_vorticity_FLT_velocity_03medroja.txt
#   - FLT/enstrophy_vorticity_FLT_velocity_04medroja.txt
# Generated enstrophy files for Lab_Gamma, Matutino shift Experimental Color, Triad PRB:
#   - PRB/enstrophy_vorticity_PRB_velocity_01medamarilla.txt
#   - PRB/enstrophy_vorticity_PRB_velocity_02medroja.txt
#   - PRB/enstrophy_vorticity_PRB_velocity_03medroja.txt
#   - PRB/enstrophy_vorticity_PRB_velocity_04medroja.txt
# Generated enstrophy files for Lab_Gamma, Matutino shift Experimental Color, Triad FRB:
#   - FRB/enstrophy_vorticity_FRB_velocity_01medamarilla.txt
#   - FRB/enstrophy_vorticity_FRB_velocity_02medroja.txt
#   - FRB/enstrophy_vorticity_FRB_velocity_03medroja.txt
#   - FRB/enstrophy_vorticity_FRB_velocity_04medroja.txt
# Generated enstrophy files for Lab_Gamma, Matutino shift Experimental Color, Triad PLT:
#   - PLT/enstrophy_vorticity_PLT_velocity_01medamarilla.txt
#   - PLT/enstrophy_vorticity_PLT_velocity_02medroja.txt
#   - PLT/enstrophy_vorticity_PLT_velocity_03medroja.txt
#   - PLT/enstrophy_vorticity_PLT_velocity_04medroja.txt
# Generated enstrophy files for Lab_Gamma, Matutino shift Experimental Color, Triad FLB:
#   - FLB/enstrophy_vorticity_FLB_velocity_01medamarilla.txt
#   - FLB/enstrophy_vorticity_FLB_velocity_02medroja.txt
#   - FLB/enstrophy_vorticity_FLB_velocity_03medroja.txt
#   - FLB/enstrophy_vorticity_FLB_velocity_04medroja.txt
# Generated enstrophy files for Lab_Gamma, Matutino shift Experimental Color, Triad PRT:
#   - PRT/enstrophy_vorticity_PRT_velocity_01medamarilla.txt
#   - PRT/enstrophy_vorticity_PRT_velocity_02medroja.txt
#   - PRT/enstrophy_vorticity_PRT_velocity_03medroja.txt
#   - PRT/enstrophy_vorticity_PRT_velocity_04medroja.txt
# Generated enstrophy files for Lab_Gamma, Matutino shift Experimental Color, Triad RTB:
#   - RTB/enstrophy_vorticity_RTB_velocity_01medamarilla.txt
#   - RTB/enstrophy_vorticity_RTB_velocity_02medroja.txt
#   - RTB/enstrophy_vorticity_RTB_velocity_03medroja.txt
#   - RTB/enstrophy_vorticity_RTB_velocity_04medroja.txt
# Generated enstrophy files for Lab_Gamma, Matutino shift Experimental Color, Triad FLP:
#   - FLP/enstrophy_vorticity_FLP_velocity_01medamarilla.txt
#   - FLP/enstrophy_vorticity_FLP_velocity_02medroja.txt
#   - FLP/enstrophy_vorticity_FLP_velocity_03medroja.txt
#   - FLP/enstrophy_vorticity_FLP_velocity_04medroja.txt
# Generated enstrophy files for Lab_Gamma, Matutino shift Experimental Color, Triad LTB:
#   - LTB/enstrophy_vorticity_LTB_velocity_01medamarilla.txt
#   - LTB/enstrophy_vorticity_LTB_velocity_02medroja.txt
#   - LTB/enstrophy_vorticity_LTB_velocity_03medroja.txt
#   - LTB/enstrophy_vorticity_LTB_velocity_04medroja.txt
# Generated enstrophy files for Lab_Gamma, Matutino shift Experimental Color, Triad FRP:
#   - FRP/enstrophy_vorticity_FRP_velocity_01medamarilla.txt
#   - FRP/enstrophy_vorticity_FRP_velocity_02medroja.txt
#   - FRP/enstrophy_vorticity_FRP_velocity_03medroja.txt
#   - FRP/enstrophy_vorticity_FRP_velocity_04medroja.txt
# Processing complete. All enstrophy results are saved in their respective directories.

# %% [markdown]
# ## 11
#
# $$
#
#     \Huge \text{First Integral of Enstrophy}
#
# $$

# %%
#Integral Enstrofía
import os
import numpy as np
import re

def read_vorticity_data(filepath):
    data = []
    timestamps = []
    try:
        with open(filepath, 'r') as file:
            for line in file:
                parts = line.strip().split(' -> ')
                if len(parts) > 1:
                    timestamps.append(parts[0])
                    vorticity_components = parts[1].strip('()').split(', ')
                    data.append([float(v) for v in vorticity_components])
        return timestamps, np.array(data)
    except Exception as e:
        print(f"Error reading file {filepath}: {e}")
        return [], np.array([])

def calculate_enstrophy(vorticities, volume):
    # Enstrophy calculation: sum of the squares of vorticity components, multiplied by volume
    enstrophy = np.sum(vorticities**2, axis=1) * volume
    return enstrophy

def format_and_save_enstrophies(timestamps, enstrophies, filename):
    try:
        with open(filename, "w") as file:
            for timestamp, enstrophy in zip(timestamps, enstrophies):
                formatted_output = f"{timestamp} -> {enstrophy:.10f}\n"
                file.write(formatted_output)
    except Exception as e:
        print(f"Error writing file {filename}: {e}")

def process_files_enstrophy(input_folder, output_folder, file_suffixes, volume):
    os.makedirs(output_folder, exist_ok=True)
    generated_files = []  # Lista para almacenar los nombres de los archivos generados

    for filename in os.listdir(input_folder):
        for file_suffix in file_suffixes:
            if filename.endswith(file_suffix):
                base_filename = filename[:-len(file_suffix)]  # Correctly removing the suffix
                
                filepath_vorticity = os.path.join(input_folder, filename)
                
                timestamps, vorticity = read_vorticity_data(filepath_vorticity)
                if vorticity.size == 0:
                    continue
                
                enstrophy = calculate_enstrophy(vorticity, volume)
                
                output_filename = f"enstrophy_{base_filename}{file_suffix}"
                output_filepath = os.path.join(output_folder, output_filename)
                
                format_and_save_enstrophies(timestamps, enstrophy, output_filepath)
                generated_files.append(f"{os.path.basename(output_folder)}/{output_filename}")

    return generated_files  # Devolver la lista de archivos generados

def accumulate_enstrophy(file_path, output_file_path):
    try:
        with open(file_path, 'r') as file:
            lines = file.readlines()
        
        accumulated_enstrophy = 0
        results = []
        for line in lines:
            time_stamp, value = line.split('->')
            value = float(value.strip())
            accumulated_enstrophy += value
            results.append(f"{time_stamp.strip()} -> {accumulated_enstrophy:.10f}\n")

        with open(output_file_path, 'w') as output_file:
            output_file.writelines(results)
    except Exception as e:
        print(f"Error processing file {file_path}: {e}")

def generate_accumulated_enstrophy(input_directory, output_directory):
    if not os.path.exists(output_directory):
        os.makedirs(output_directory)

    for root, dirs, files in os.walk(input_directory):
        for filename in files:
            if filename.endswith(".txt"):
                file_path = os.path.join(root, filename)
                output_filename = f"sum_{filename}"
                output_file_path = os.path.join(output_directory, output_filename)
                accumulate_enstrophy(file_path, output_file_path)
                print(f"Generated file: {output_filename}")

def find_experiment_folder(root_folder, lab, shift):
    date_regex = re.compile(r'\d{2}[A-Za-z]{3}\d{2}')
    for folder in os.listdir(root_folder):
        if date_regex.search(folder) and lab in folder:
            for subfolder in os.listdir(os.path.join(root_folder, folder)):
                if date_regex.search(subfolder) and shift in subfolder:
                    return os.path.join(root_folder, folder, subfolder), date_regex.search(folder).group(0)
    return None, None

def process_lab_accumulated_enstrophy(root_folder, lab_name, shift, file_suffixes, volume, triad_codes):
    shift_name = "Vespertino" if shift == 'V' else "Matutino"
    experiment_folder, date_str = find_experiment_folder(root_folder, lab_name, shift)
    if not experiment_folder:
        print(f"No se encontró ningún directorio para {lab_name}, {shift}.")
        return

    input_folder_base = os.path.join(experiment_folder, "Data Analysis", "Processing Data")
    
    if not os.path.exists(input_folder_base):
        print(f"Skipping {shift_name} shift for {lab_name} as directory does not exist: {input_folder_base}")
        return

    # Procesar enstrofia acumulada de Baseline para cada triada
    for triad, triad_code in triad_codes.items():
        input_directory = os.path.join(input_folder_base, "Enstrophy_Baseline", triad_code)
        output_directory = os.path.join(input_folder_base, "Sum_Enstrophy_Baseline", triad_code)
        if os.path.exists(input_directory):
            generate_accumulated_enstrophy(input_directory, output_directory)
            print(f"Generated accumulated enstrophy files for {lab_name}, {shift_name} shift Baseline, Triad {triad_code}.")
        else:
            print(f"Skipping {shift_name} shift for {lab_name} Baseline Triad {triad_code} as directory does not exist: {input_directory}")

    # Procesar enstrofia acumulada de Experimental Color para cada triada
    for triad, triad_code in triad_codes.items():
        input_directory = os.path.join(input_folder_base, "Enstrophy_Experimental_Color", triad_code)
        output_directory = os.path.join(input_folder_base, "Sum_Enstrophy_Experimental_Color", triad_code)
        if os.path.exists(input_directory):
            generate_accumulated_enstrophy(input_directory, output_directory)
            print(f"Generated accumulated enstrophy files for {lab_name}, {shift_name} shift Experimental Color, Triad {triad_code}.")
        else:
            print(f"Skipping {shift_name} shift for {lab_name} Experimental Color Triad {triad_code} as directory does not exist: {input_directory}")

# Define the root folder, suffixes, and triad codes
file_suffixes = ["medroja.txt", "medmorada.txt", "medazul.txt", "medverde.txt", "medamarilla.txt", "mednegra.txt"]
triad_codes = {
    (0, 2, 4): "FRT",  
    (1, 3, 5): "PLB",  
    (0, 3, 4): "FLT",  
    (1, 2, 5): "PRB",  
    (0, 2, 5): "FRB",  
    (1, 3, 4): "PLT",  
    (0, 3, 5): "FLB",  
    (1, 2, 4): "PRT",  
    (2, 4, 5): "RTB",  
    (0, 1, 3): "FLP",  
    (3, 4, 5): "LTB",  
    (0, 1, 2): "FRP"
}

# Volumes for each lab
volumes = {
    "Lab_Betta": 7.3195 , # Volume for Lab A
    "Lab_Gamma": 6.8342   # Volume for Lab B (example)
}

# Procesar todos los laboratorios y turnos
labs = ["Lab_Betta", "Lab_Gamma"]

for lab_name in labs:
    for shift in ['V', 'M']:
        process_lab_accumulated_enstrophy(root_folder, lab_name, shift, file_suffixes, volumes[lab_name], triad_codes)

print("Processing complete. All accumulated enstrophy results are saved in their respective directories.")
# Out:
# No se encontró ningún directorio para Lab_Betta, V.
# No se encontró ningún directorio para Lab_Betta, M.
# No se encontró ningún directorio para Lab_Gamma, V.
# Generated file: sum_enstrophy_vorticity_FRT_velocity_01mednegra.txt
# Generated file: sum_enstrophy_vorticity_FRT_velocity_02mednegra.txt
# Generated file: sum_enstrophy_vorticity_FRT_velocity_03mednegra.txt
# Generated file: sum_enstrophy_vorticity_FRT_velocity_04mednegra.txt
# Generated file: sum_enstrophy_vorticity_FRT_velocity_05mednegra.txt
# Generated accumulated enstrophy files for Lab_Gamma, Matutino shift Baseline, Triad FRT.
# Generated file: sum_enstrophy_vorticity_PLB_velocity_01mednegra.txt
# Generated file: sum_enstrophy_vorticity_PLB_velocity_02mednegra.txt
# Generated file: sum_enstrophy_vorticity_PLB_velocity_03mednegra.txt
# Generated file: sum_enstrophy_vorticity_PLB_velocity_04mednegra.txt
# Generated file: sum_enstrophy_vorticity_PLB_velocity_05mednegra.txt
# Generated accumulated enstrophy files for Lab_Gamma, Matutino shift Baseline, Triad PLB.
# Generated file: sum_enstrophy_vorticity_FLT_velocity_01mednegra.txt
# Generated file: sum_enstrophy_vorticity_FLT_velocity_02mednegra.txt
# Generated file: sum_enstrophy_vorticity_FLT_velocity_03mednegra.txt
# Generated file: sum_enstrophy_vorticity_FLT_velocity_04mednegra.txt
# Generated file: sum_enstrophy_vorticity_FLT_velocity_05mednegra.txt
# Generated accumulated enstrophy files for Lab_Gamma, Matutino shift Baseline, Triad FLT.
# Generated file: sum_enstrophy_vorticity_PRB_velocity_01mednegra.txt
# Generated file: sum_enstrophy_vorticity_PRB_velocity_02mednegra.txt
# Generated file: sum_enstrophy_vorticity_PRB_velocity_03mednegra.txt
# Generated file: sum_enstrophy_vorticity_PRB_velocity_04mednegra.txt
# Generated file: sum_enstrophy_vorticity_PRB_velocity_05mednegra.txt
# Generated accumulated enstrophy files for Lab_Gamma, Matutino shift Baseline, Triad PRB.
# Generated file: sum_enstrophy_vorticity_FRB_velocity_01mednegra.txt
# Generated file: sum_enstrophy_vorticity_FRB_velocity_02mednegra.txt
# Generated file: sum_enstrophy_vorticity_FRB_velocity_03mednegra.txt
# Generated file: sum_enstrophy_vorticity_FRB_velocity_04mednegra.txt
# Generated file: sum_enstrophy_vorticity_FRB_velocity_05mednegra.txt
# Generated accumulated enstrophy files for Lab_Gamma, Matutino shift Baseline, Triad FRB.
# Generated file: sum_enstrophy_vorticity_PLT_velocity_01mednegra.txt
# Generated file: sum_enstrophy_vorticity_PLT_velocity_02mednegra.txt
# Generated file: sum_enstrophy_vorticity_PLT_velocity_03mednegra.txt
# Generated file: sum_enstrophy_vorticity_PLT_velocity_04mednegra.txt
# Generated file: sum_enstrophy_vorticity_PLT_velocity_05mednegra.txt
# Generated accumulated enstrophy files for Lab_Gamma, Matutino shift Baseline, Triad PLT.
# Generated file: sum_enstrophy_vorticity_FLB_velocity_01mednegra.txt
# Generated file: sum_enstrophy_vorticity_FLB_velocity_02mednegra.txt
# Generated file: sum_enstrophy_vorticity_FLB_velocity_03mednegra.txt
# Generated file: sum_enstrophy_vorticity_FLB_velocity_04mednegra.txt
# Generated file: sum_enstrophy_vorticity_FLB_velocity_05mednegra.txt
# Generated accumulated enstrophy files for Lab_Gamma, Matutino shift Baseline, Triad FLB.
# Generated file: sum_enstrophy_vorticity_PRT_velocity_01mednegra.txt
# Generated file: sum_enstrophy_vorticity_PRT_velocity_02mednegra.txt
# Generated file: sum_enstrophy_vorticity_PRT_velocity_03mednegra.txt
# Generated file: sum_enstrophy_vorticity_PRT_velocity_04mednegra.txt
# Generated file: sum_enstrophy_vorticity_PRT_velocity_05mednegra.txt
# Generated accumulated enstrophy files for Lab_Gamma, Matutino shift Baseline, Triad PRT.
# Generated file: sum_enstrophy_vorticity_RTB_velocity_01mednegra.txt
# Generated file: sum_enstrophy_vorticity_RTB_velocity_02mednegra.txt
# Generated file: sum_enstrophy_vorticity_RTB_velocity_03mednegra.txt
# Generated file: sum_enstrophy_vorticity_RTB_velocity_04mednegra.txt
# Generated file: sum_enstrophy_vorticity_RTB_velocity_05mednegra.txt
# Generated accumulated enstrophy files for Lab_Gamma, Matutino shift Baseline, Triad RTB.
# Generated file: sum_enstrophy_vorticity_FLP_velocity_01mednegra.txt
# Generated file: sum_enstrophy_vorticity_FLP_velocity_02mednegra.txt
# Generated file: sum_enstrophy_vorticity_FLP_velocity_03mednegra.txt
# Generated file: sum_enstrophy_vorticity_FLP_velocity_04mednegra.txt
# Generated file: sum_enstrophy_vorticity_FLP_velocity_05mednegra.txt
# Generated accumulated enstrophy files for Lab_Gamma, Matutino shift Baseline, Triad FLP.
# Generated file: sum_enstrophy_vorticity_LTB_velocity_01mednegra.txt
# Generated file: sum_enstrophy_vorticity_LTB_velocity_02mednegra.txt
# Generated file: sum_enstrophy_vorticity_LTB_velocity_03mednegra.txt
# Generated file: sum_enstrophy_vorticity_LTB_velocity_04mednegra.txt
# Generated file: sum_enstrophy_vorticity_LTB_velocity_05mednegra.txt
# Generated accumulated enstrophy files for Lab_Gamma, Matutino shift Baseline, Triad LTB.
# Generated file: sum_enstrophy_vorticity_FRP_velocity_01mednegra.txt
# Generated file: sum_enstrophy_vorticity_FRP_velocity_02mednegra.txt
# Generated file: sum_enstrophy_vorticity_FRP_velocity_03mednegra.txt
# Generated file: sum_enstrophy_vorticity_FRP_velocity_04mednegra.txt
# Generated file: sum_enstrophy_vorticity_FRP_velocity_05mednegra.txt
# Generated accumulated enstrophy files for Lab_Gamma, Matutino shift Baseline, Triad FRP.
# Generated file: sum_enstrophy_vorticity_FRT_velocity_01medamarilla.txt
# Generated file: sum_enstrophy_vorticity_FRT_velocity_02medroja.txt
# Generated file: sum_enstrophy_vorticity_FRT_velocity_03medroja.txt
# Generated file: sum_enstrophy_vorticity_FRT_velocity_04medroja.txt
# Generated accumulated enstrophy files for Lab_Gamma, Matutino shift Experimental Color, Triad FRT.
# Generated file: sum_enstrophy_vorticity_PLB_velocity_01medamarilla.txt
# Generated file: sum_enstrophy_vorticity_PLB_velocity_02medroja.txt
# Generated file: sum_enstrophy_vorticity_PLB_velocity_03medroja.txt
# Generated file: sum_enstrophy_vorticity_PLB_velocity_04medroja.txt
# Generated accumulated enstrophy files for Lab_Gamma, Matutino shift Experimental Color, Triad PLB.
# Generated file: sum_enstrophy_vorticity_FLT_velocity_01medamarilla.txt
# Generated file: sum_enstrophy_vorticity_FLT_velocity_02medroja.txt
# Generated file: sum_enstrophy_vorticity_FLT_velocity_03medroja.txt
# Generated file: sum_enstrophy_vorticity_FLT_velocity_04medroja.txt
# Generated accumulated enstrophy files for Lab_Gamma, Matutino shift Experimental Color, Triad FLT.
# Generated file: sum_enstrophy_vorticity_PRB_velocity_01medamarilla.txt
# Generated file: sum_enstrophy_vorticity_PRB_velocity_02medroja.txt
# Generated file: sum_enstrophy_vorticity_PRB_velocity_03medroja.txt
# Generated file: sum_enstrophy_vorticity_PRB_velocity_04medroja.txt
# Generated accumulated enstrophy files for Lab_Gamma, Matutino shift Experimental Color, Triad PRB.
# Generated file: sum_enstrophy_vorticity_FRB_velocity_01medamarilla.txt
# Generated file: sum_enstrophy_vorticity_FRB_velocity_02medroja.txt
# Generated file: sum_enstrophy_vorticity_FRB_velocity_03medroja.txt
# Generated file: sum_enstrophy_vorticity_FRB_velocity_04medroja.txt
# Generated accumulated enstrophy files for Lab_Gamma, Matutino shift Experimental Color, Triad FRB.
# Generated file: sum_enstrophy_vorticity_PLT_velocity_01medamarilla.txt
# Generated file: sum_enstrophy_vorticity_PLT_velocity_02medroja.txt
# Generated file: sum_enstrophy_vorticity_PLT_velocity_03medroja.txt
# Generated file: sum_enstrophy_vorticity_PLT_velocity_04medroja.txt
# Generated accumulated enstrophy files for Lab_Gamma, Matutino shift Experimental Color, Triad PLT.
# Generated file: sum_enstrophy_vorticity_FLB_velocity_01medamarilla.txt
# Generated file: sum_enstrophy_vorticity_FLB_velocity_02medroja.txt
# Generated file: sum_enstrophy_vorticity_FLB_velocity_03medroja.txt
# Generated file: sum_enstrophy_vorticity_FLB_velocity_04medroja.txt
# Generated accumulated enstrophy files for Lab_Gamma, Matutino shift Experimental Color, Triad FLB.
# Generated file: sum_enstrophy_vorticity_PRT_velocity_01medamarilla.txt
# Generated file: sum_enstrophy_vorticity_PRT_velocity_02medroja.txt
# Generated file: sum_enstrophy_vorticity_PRT_velocity_03medroja.txt
# Generated file: sum_enstrophy_vorticity_PRT_velocity_04medroja.txt
# Generated accumulated enstrophy files for Lab_Gamma, Matutino shift Experimental Color, Triad PRT.
# Generated file: sum_enstrophy_vorticity_RTB_velocity_01medamarilla.txt
# Generated file: sum_enstrophy_vorticity_RTB_velocity_02medroja.txt
# Generated file: sum_enstrophy_vorticity_RTB_velocity_03medroja.txt
# Generated file: sum_enstrophy_vorticity_RTB_velocity_04medroja.txt
# Generated accumulated enstrophy files for Lab_Gamma, Matutino shift Experimental Color, Triad RTB.
# Generated file: sum_enstrophy_vorticity_FLP_velocity_01medamarilla.txt
# Generated file: sum_enstrophy_vorticity_FLP_velocity_02medroja.txt
# Generated file: sum_enstrophy_vorticity_FLP_velocity_03medroja.txt
# Generated file: sum_enstrophy_vorticity_FLP_velocity_04medroja.txt
# Generated accumulated enstrophy files for Lab_Gamma, Matutino shift Experimental Color, Triad FLP.
# Generated file: sum_enstrophy_vorticity_LTB_velocity_01medamarilla.txt
# Generated file: sum_enstrophy_vorticity_LTB_velocity_02medroja.txt
# Generated file: sum_enstrophy_vorticity_LTB_velocity_03medroja.txt
# Generated file: sum_enstrophy_vorticity_LTB_velocity_04medroja.txt
# Generated accumulated enstrophy files for Lab_Gamma, Matutino shift Experimental Color, Triad LTB.
# Generated file: sum_enstrophy_vorticity_FRP_velocity_01medamarilla.txt
# Generated file: sum_enstrophy_vorticity_FRP_velocity_02medroja.txt
# Generated file: sum_enstrophy_vorticity_FRP_velocity_03medroja.txt
# Generated file: sum_enstrophy_vorticity_FRP_velocity_04medroja.txt
# Generated accumulated enstrophy files for Lab_Gamma, Matutino shift Experimental Color, Triad FRP.
# Processing complete. All accumulated enstrophy results are saved in their respective directories.

# %% [markdown]
# ## 12
#
# $$
#
#     \Huge \text{First Integral Moduli Baseline vs Experimental Color}
#
# $$

# %%
import numpy as np
import os
import glob
import datetime

def read_data(filepath):
    timestamps = []
    values = []
    with open(filepath, 'r') as file:
        for line in file:
            parts = line.strip().split(' -> ')
            if len(parts) > 1:
                try:
                    timestamp = datetime.datetime.strptime(parts[0], "%H:%M:%S.%f")
                    timestamps.append(timestamp)
                    values.append([float(num) for num in parts[1].strip('()').split(',')])
                except ValueError as e:
                    print(f"Error processing line in file {filepath}: {line}\n{e}")
    return timestamps, np.array(values)

def generate_combinations(baseline_files, experimental_files):
    combinations = []
    for base_file in baseline_files:
        base_num = int(base_file.split('med')[0][-2:])
        for exp_file in experimental_files:
            exp_num = int(exp_file.split('med')[0][-2:])
            if exp_num == base_num or exp_num == base_num - 1:
                combinations.append((base_file, exp_file))
            elif exp_num == base_num + 1 and (base_num + 1) <= len(baseline_files):
                combinations.append((baseline_files[base_num], exp_file))
    return combinations

def read_curl_file(file_path):
    """Reads a file containing curl components and returns a list of tuples (i, j, k)."""
    curl_components = []
    with open(file_path, 'r') as file:
        for line in file:
            parts = line.strip().split(' -> ')
            if len(parts) > 1:
                try:
                    components = tuple(map(float, parts[1].strip('()').split(',')))
                    if len(components) == 3:
                        curl_components.append(components)
                except ValueError:
                    continue  # Ignore lines that cannot be converted to floats
    return curl_components

def calculate_modulus(curl_components):
    """Calculates the modulus of the curl components."""
    moduli = [np.sqrt(i**2 + j**2 + k**2) for i, j, k in curl_components]
    return moduli

def integrate_moduli(moduli):
    """Calculates the sum (integral) of the moduli."""
    return np.sum(moduli)

def compare_integrals(baseline_integral, intervention_integral):
    """Compares the integrals and reports the result."""
    difference = abs(intervention_integral - baseline_integral)
    percentage_difference = (difference / baseline_integral) * 100

    if percentage_difference > 34:
        return "There is intervention"
    elif 10 <= percentage_difference <= 33.9:
        return "Inconclusive"
    else:
        return "No evidence"

def print_result(lab, shift, baseline_file, experimental_file, baseline_integral, intervention_integral, result):
    shift_name = "Matutino" if shift == "M" else "Vespertino"
    print(f"Lab: {lab}, Shift: {shift_name}")
    print(f"Comparison Result")
    print(f"{'-'*50}")
    print(f"Baseline File: {os.path.basename(baseline_file)}")
    print(f"Experimental File: {os.path.basename(experimental_file)}")
    print(f"Baseline Integral: {baseline_integral:.2f}")
    print(f"Intervention Integral: {intervention_integral:.2f}")
    print(f"Difference: {abs(intervention_integral - baseline_integral):.2f}")
    print(f"Percentage Difference: {(abs(intervention_integral - baseline_integral) / baseline_integral) * 100:.2f}%")
    print(f"Result: {result}")
    print(f"{'='*50}\n")



def save_intervention_result(results_file, lab, shift, baseline_file, experimental_file, baseline_integral, intervention_integral, result):
    shift_name = "Matutino" if shift == "M" else "Vespertino"
    with open(results_file, 'a') as f:
        f.write(f"Lab: {lab}, Shift: {shift_name}\n")
        f.write(f"Comparison Result\n")
        f.write(f"{'-'*50}\n")
        f.write(f"Baseline File: {os.path.basename(baseline_file)}\n")
        f.write(f"Experimental File: {os.path.basename(experimental_file)}\n")
        f.write(f"Baseline Integral: {baseline_integral:.2f}\n")
        f.write(f"Intervention Integral: {intervention_integral:.2f}\n")
        f.write(f"Difference: {abs(intervention_integral - baseline_integral):.2f}\n")
        f.write(f"Percentage Difference: {(abs(intervention_integral - baseline_integral) / baseline_integral) * 100:.2f}%\n")
        f.write(f"Result: {result}\n")
        f.write(f"{'='*50}\n\n")

def main():
    results_file = os.path.join(root_folder, "intervention_results.txt")
    
    if os.path.exists(results_file):
        os.remove(results_file)  # Remove the file if it already exists

    labs = ["Lab_Betta", "Lab_Gamma"]
    shifts = ["V", "M"]

    color_map = {
        "medroja.txt": "red",
        "medmorada.txt": "purple",
        "medazul.txt": "blue",
        "medverde.txt": "green",
        "medamarilla.txt": "yellow"
    }

    for lab in labs:
        for shift in shifts:
            lab_dir = glob.glob(os.path.join(root_folder, f"*{lab}"))[0]
            date_str = os.path.basename(lab_dir).split(' ')[0]

            baseline_dir = os.path.join(lab_dir, f"{date_str}.{shift} - {lab}", "Data Analysis", "Processing Data", "Curl_Baseline")
            exp_dir = os.path.join(lab_dir, f"{date_str}.{shift} - {lab}", "Data Analysis", "Processing Data", "Curl_Experimental_Color")
            
            if not os.path.exists(baseline_dir) or not os.path.exists(exp_dir):
                print(f"Error: Directory not found for {lab} {shift}")
                continue

            baseline_files = [f for f in os.listdir(baseline_dir) if f.endswith('mednegra.txt') and "00" not in f]
            experimental_files = [f for f in os.listdir(exp_dir) if any(f.endswith(suffix) for suffix in color_map.keys()) and "00" not in f]

            combinations = generate_combinations(baseline_files, experimental_files)

            for base_file, exp_file in combinations:
                baseline_file = os.path.join(baseline_dir, base_file)
                experimental_file = os.path.join(exp_dir, exp_file)
                if os.path.exists(baseline_file) and os.path.exists(experimental_file):
                    # Reading and processing baseline file
                    baseline_curl = read_curl_file(baseline_file)
                    baseline_moduli = calculate_modulus(baseline_curl)
                    baseline_integral = integrate_moduli(baseline_moduli)

                    # Reading and processing intervention file
                    intervention_curl = read_curl_file(experimental_file)
                    intervention_moduli = calculate_modulus(intervention_curl)
                    intervention_integral = integrate_moduli(intervention_moduli)

                    # Comparing integrals
                    result = compare_integrals(baseline_integral, intervention_integral)
                    print_result(lab, shift, baseline_file, experimental_file, baseline_integral, intervention_integral, result)
                    
                    if result == "There is intervention":
                        save_intervention_result(results_file, lab, shift, baseline_file, experimental_file, baseline_integral, intervention_integral, result)

if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[13], line 156
#     153                         save_intervention_result(results_file, lab, shift, baseline_file, experimental_file, baseline_integral, intervention_integral, result)
#     155 if __name__ == "__main__":
# --> 156     main()
#
# Cell In[13], line 119, in main()
#     117 for lab in labs:
#     118     for shift in shifts:
# --> 119         lab_dir = glob.glob(os.path.join(root_folder, f"*{lab}"))[0]
#     120         date_str = os.path.basename(lab_dir).split(' ')[0]
#     122         baseline_dir = os.path.join(lab_dir, f"{date_str}.{shift} - {lab}", "Data Analysis", "Processing Data", "Curl_Baseline")
#
# IndexError: list index out of range

# %% [markdown]
# ## 13
#
# $$
#
#     \Huge \text{Second Integral of Absolute Helicity Baseline vs Experimental Color}
#
# $$

# %%
import numpy as np
import os
import glob

def read_data(filepath):
    values = []
    with open(filepath, 'r') as file:
        for line in file:
            parts = line.strip().split(' -> ')
            if len(parts) > 1:
                values.append(float(parts[1]))
    return np.array(values)

def get_sum_helicity(files, dir_path):
    sum_helicities = {"sum_absolute_helicity_1": {}, "sum_absolute_helicity_2": {}}
    for file in files:
        file_path = os.path.join(dir_path, file)
        values = read_data(file_path)
        sum_helicity = np.sum(values)
        if "sum_absolute_helicity_1" in file:
            sum_helicities["sum_absolute_helicity_1"][file] = sum_helicity
        elif "sum_absolute_helicity_2" in file:
            sum_helicities["sum_absolute_helicity_2"][file] = sum_helicity
    return sum_helicities

def generate_combinations(baseline_files, experimental_files):
    combinations = []
    for base_file in baseline_files:
        base_num = int(base_file.split('velocity_')[1].split('med')[0])
        for exp_file in experimental_files:
            exp_num = int(exp_file.split('velocity_')[1].split('med')[0])
            if exp_num == base_num or exp_num == base_num - 1:
                combinations.append((base_file, exp_file))
            elif exp_num == base_num + 1 and (base_num + 1) <= len(baseline_files):
                combinations.append((baseline_files[base_num], exp_file))
    return combinations

def calculate_percentage_difference(baseline_value, experimental_value):
    return 100 * (experimental_value - baseline_value) / baseline_value

def format_comparison_results(combinations, baseline_sums, experimental_sums, comparison_type):
    comparison_lines = [f"*** Comparison - {comparison_type} ***\n"]
    for base_file, exp_file in combinations:
        if base_file in baseline_sums[comparison_type] and exp_file in experimental_sums[comparison_type]:
            baseline_value = baseline_sums[comparison_type][base_file]
            experimental_value = experimental_sums[comparison_type][exp_file]
            percentage_diff = calculate_percentage_difference(baseline_value, experimental_value)
            comparison_lines.append(f"Baseline: {base_file} - {baseline_value:.2f}\n")
            comparison_lines.append(f"Experimental: {exp_file} - {experimental_value:.2f}\n")
            comparison_lines.append(f"*** Percentage Difference: {percentage_diff:.2f}% ***\n\n")
    return comparison_lines

def format_statistical_summary(baseline_sums, experimental_sums):
    summary_lines = ["*** Statistical Summary ***\n"]
    for helicity_type in baseline_sums:
        baseline_values = list(baseline_sums[helicity_type].values())
        experimental_values = list(experimental_sums[helicity_type].values())

        # Verifica si las listas están vacías
        if not baseline_values:
            summary_lines.append(f"{helicity_type} Baseline: No data\n")
        else:
            max_baseline_value = max(baseline_values)
            min_baseline_value = min(baseline_values)
            max_baseline_file = [k for k, v in baseline_sums[helicity_type].items() if v == max_baseline_value][0]
            min_baseline_file = [k for k, v in baseline_sums[helicity_type].items() if v == min_baseline_value][0]
            summary_lines.append(f"{helicity_type}:\n")
            summary_lines.append(f"  Baseline - Mean: {np.mean(baseline_values):.2f}, Std Dev: {np.std(baseline_values):.2f}\n")
            summary_lines.append(f"    Max: {max_baseline_value:.2f} ({max_baseline_file})\n")
            summary_lines.append(f"    Min: {min_baseline_value:.2f} ({min_baseline_file})\n")

        # Verifica si las listas están vacías para datos experimentales
        if not experimental_values:
            summary_lines.append(f"{helicity_type} Experimental: No data\n")
        else:
            max_experimental_value = max(experimental_values)
            min_experimental_value = min(experimental_values)
            max_experimental_file = [k for k, v in experimental_sums[helicity_type].items() if v == max_experimental_value][0]
            min_experimental_file = [k for k, v in experimental_sums[helicity_type].items() if v == min_experimental_value][0]
            summary_lines.append(f"  Experimental - Mean: {np.mean(experimental_values):.2f}, Std Dev: {np.std(experimental_values):.2f}\n")
            summary_lines.append(f"    Max: {max_experimental_value:.2f} ({max_experimental_file})\n")
            summary_lines.append(f"    Min: {min_experimental_value:.2f} ({min_experimental_file})\n")

        summary_lines.append("\n")

    return summary_lines

def main():
    root_folder = "path/to/root_folder"  # Define la ruta de la carpeta raíz
    labs = ["Lab_Betta", "Lab_Gamma"]
    shifts = ["V", "M"]

    results = []

    for lab in labs:
        for shift in shifts:
            lab_dirs = glob.glob(os.path.join(root_folder, f"*{lab}"))
            if not lab_dirs:
                print(f"No se encontró ningún directorio para {lab}.")
                continue
            lab_dir = lab_dirs[0]
            date_str = os.path.basename(lab_dir).split(' ')[0]
            baseline_dir = os.path.join(lab_dir, f"{date_str}.{shift} - {lab}", "Data Analysis", "Processing Data", "Sum_Absolute_Helicity_Baseline")
            exp_dir = os.path.join(lab_dir, f"{date_str}.{shift} - {lab}", "Data Analysis", "Processing Data", "Sum_Absolute_Helicity_Experimental_Color")

            if not os.path.exists(baseline_dir) or not os.path.exists(exp_dir):
                print(f"Omitiendo cálculo para {lab} {shift} ya que el directorio no existe.")
                continue

            baseline_files = [f for f in os.listdir(baseline_dir) if f.endswith('mednegra.txt') and "00" not in f]
            experimental_files = [f for f in os.listdir(exp_dir) if f.endswith('.txt') and "00" not in f]

            baseline_sums = get_sum_helicity(baseline_files, baseline_dir)
            experimental_sums = get_sum_helicity(experimental_files, exp_dir)

            header = f"\n\n*** Resultados para {lab} - Turno: {'Vespertino' if shift == 'V' else 'Matutino'} - Fecha: {date_str} ***\n"
            results.append(header)
            results.append("=" * len(header) + "\n\n")

            # Generar combinaciones y formatear resultados de comparación
            combinations_1 = generate_combinations(baseline_files, experimental_files)
            results.extend(format_comparison_results(combinations_1, baseline_sums, experimental_sums, "sum_absolute_helicity_1"))
            results.extend(format_comparison_results(combinations_1, baseline_sums, experimental_sums, "sum_absolute_helicity_2"))

            # Añadir resumen estadístico
            results.append("*** Statistical Summary ***\n")
            results.extend(format_statistical_summary(baseline_sums, experimental_sums))
            results.append("=" * len(header) + "\n\n")

    output_filepath = os.path.join(root_folder, "SUM TOTAL OF HELICITY BY TRIAD COMPONENTS.txt")
    with open(output_filepath, 'w') as output_file:
        output_file.writelines(results)

    print(f"Resultados guardados en {output_filepath}")

    # Imprimir resultados en consola
    for line in results:
        print(line, end='')

if __name__ == "__main__":
    main()
# Out:
# No se encontró ningún directorio para Lab_Betta.
# No se encontró ningún directorio para Lab_Betta.
# No se encontró ningún directorio para Lab_Gamma.
# No se encontró ningún directorio para Lab_Gamma.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[14], line 141
#     138         print(line, end='')
#     140 if __name__ == "__main__":
# --> 141     main()
#
# Cell In[14], line 131, in main()
#     128         results.append("=" * len(header) + "\n\n")
#     130 output_filepath = os.path.join(root_folder, "SUM TOTAL OF HELICITY BY TRIAD COMPONENTS.txt")
# --> 131 with open(output_filepath, 'w') as output_file:
#     132     output_file.writelines(results)
#     134 print(f"Resultados guardados en {output_filepath}")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'path/to/root_folder\\SUM TOTAL OF HELICITY BY TRIAD COMPONENTS.txt'

# %%
import os
import re

def extraer_fecha(root_folder):
    nombre_directorio = os.path.basename(root_folder)
    match = re.search(r'(\d{2}[a-z]{3}\d{2})', nombre_directorio)
    
    if match:
        fecha_str = match.group(1)  # Captura la fecha en formato '20sep24'
        return fecha_str
    else:
        raise ValueError(f"No se encontró una fecha válida en el nombre del directorio {root_folder}.")

# Función para decodificar el texto hexadecimal
def decodificar_hex(hex_string):
    try:
        hex_cleaned = hex_string.strip().replace(' ', '')
        decoded_string = bytes.fromhex(hex_cleaned).decode('ascii', errors='ignore').strip()
        return decoded_string
    except Exception as e:
        print(f"Error decodificando: {e}")
        return None

# Función para procesar el archivo y extraer la hora y el valor limpio
def procesar_archivo_para_hora_y_texto(ruta_archivo):
    resultados = []
    
    with open(ruta_archivo, 'r') as archivo:
        for linea in archivo:
            match_hora = re.search(r'(\d{2}-\d{2}-\d{4} \d{2}:\d{2}:\d{2}\.\d{3})', linea)
            if match_hora:
                hora = match_hora.group(1).split(' ')[1]  # Obtener solo la parte de la hora
                partes = linea.strip().split(',')
                if len(partes) > 3:
                    hex_data = partes[-1]
                    decoded_value = decodificar_hex(hex_data)

                    if decoded_value:
                        resultados.append(f"{hora}, {decoded_value}")
                    else:
                        resultados.append(f"{hora}, .")
    
    return resultados

# Función para guardar los resultados en un archivo de salida
def guardar_resultados(ruta_salida, resultados):
    with open(ruta_salida, 'w') as archivo_salida:
        for resultado in resultados:
            archivo_salida.write(resultado + '\n')

# Función para construir la ruta del archivo a procesar
def construir_ruta(root_folder, fecha, lab, turno, color, numero):
    colorin = color.lower()
    ruta_archivo = os.path.join(root_folder, f"{fecha} - Lab_{lab}", f"{fecha}.{turno} - Lab_{lab}", "Pesajes", f"0{numero}med{colorin}.log")
    return ruta_archivo

# Función para filtrar resultados
def filtrar_resultados(resultados):
    # Expresión regular para el formato deseado
    pattern = r'^\d{2}:\d{2}:\d{2}\.\d{3}, \d+\.\d{2}g$'
    return [resultado for resultado in resultados if re.match(pattern, resultado.strip())]

# Si este es el archivo principal
if __name__ == "__main__":
    fecha = extraer_fecha(root_folder)  # Extraer fecha en minúsculas
    labs = ["Betta", "Gamma"]
    turnos = ["M", "V"]
    colores = ["Negra","Amarilla", "Roja", "Azul", "Verde", "Morada"]
    numeros_archivo = range(1, 11)

    for lab in labs:
        for turno in turnos:
            for color in colores:
                for numero in numeros_archivo:
                    ruta_archivo = construir_ruta(root_folder, fecha, lab, turno, color, numero)
                    
                    if os.path.exists(ruta_archivo):
                        colorin = color.lower()
                        ruta_salida = os.path.join(os.path.dirname(ruta_archivo), f"resultados_{colorin}_{numero:02d}.txt")

                        print(f"\nProcesando para Lab: {lab}, Turno: {turno}, Color: {color}, Archivo: {numero:02d}")
                        print(f"Archivo a procesar: {ruta_archivo}")
                        
                        # Procesar el archivo para extraer hora y texto limpio
                        resultados = procesar_archivo_para_hora_y_texto(ruta_archivo)

                        # Filtrar resultados
                        resultados_filtrados = filtrar_resultados(resultados)

                        # Guardar los resultados filtrados en el archivo de salida
                        guardar_resultados(ruta_salida, resultados_filtrados)
                    else:
                        print(f"Archivo no encontrado: {ruta_archivo}")
    print("\nProcesamiento completo.")
# Out:
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\01mednegra.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\02mednegra.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\03mednegra.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\04mednegra.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\05mednegra.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\06mednegra.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\07mednegra.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\08mednegra.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\09mednegra.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\010mednegra.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\01medamarilla.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\02medamarilla.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\03medamarilla.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\04medamarilla.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\05medamarilla.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\06medamarilla.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\07medamarilla.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\08medamarilla.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\09medamarilla.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\010medamarilla.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\01medroja.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\02medroja.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\03medroja.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\04medroja.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\05medroja.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\06medroja.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\07medroja.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\08medroja.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\09medroja.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\010medroja.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\01medazul.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\02medazul.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\03medazul.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\04medazul.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\05medazul.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\06medazul.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\07medazul.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\08medazul.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\09medazul.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\010medazul.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\01medverde.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\02medverde.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\03medverde.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\04medverde.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\05medverde.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\06medverde.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\07medverde.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\08medverde.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\09medverde.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\010medverde.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\01medmorada.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\02medmorada.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\03medmorada.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\04medmorada.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\05medmorada.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\06medmorada.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\07medmorada.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\08medmorada.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\09medmorada.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\010medmorada.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\01mednegra.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\02mednegra.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\03mednegra.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\04mednegra.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\05mednegra.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\06mednegra.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\07mednegra.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\08mednegra.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\09mednegra.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\010mednegra.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\01medamarilla.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\02medamarilla.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\03medamarilla.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\04medamarilla.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\05medamarilla.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\06medamarilla.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\07medamarilla.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\08medamarilla.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\09medamarilla.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\010medamarilla.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\01medroja.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\02medroja.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\03medroja.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\04medroja.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\05medroja.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\06medroja.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\07medroja.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\08medroja.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\09medroja.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\010medroja.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\01medazul.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\02medazul.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\03medazul.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\04medazul.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\05medazul.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\06medazul.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\07medazul.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\08medazul.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\09medazul.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\010medazul.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\01medverde.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\02medverde.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\03medverde.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\04medverde.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\05medverde.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\06medverde.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\07medverde.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\08medverde.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\09medverde.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\010medverde.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\01medmorada.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\02medmorada.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\03medmorada.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\04medmorada.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\05medmorada.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\06medmorada.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\07medmorada.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\08medmorada.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\09medmorada.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\010medmorada.log
#
# Procesando para Lab: Gamma, Turno: M, Color: Negra, Archivo: 01
# Archivo a procesar: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\01mednegra.log
# Error decodificando: non-hexadecimal number found in fromhex() arg at position 0
#
# Procesando para Lab: Gamma, Turno: M, Color: Negra, Archivo: 02
# Archivo a procesar: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\02mednegra.log
# Error decodificando: non-hexadecimal number found in fromhex() arg at position 0
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\03mednegra.log
#
# Procesando para Lab: Gamma, Turno: M, Color: Negra, Archivo: 04
# Archivo a procesar: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\04mednegra.log
# Error decodificando: non-hexadecimal number found in fromhex() arg at position 0
#
# Procesando para Lab: Gamma, Turno: M, Color: Negra, Archivo: 05
# Archivo a procesar: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\05mednegra.log
# Error decodificando: non-hexadecimal number found in fromhex() arg at position 0
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\06mednegra.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\07mednegra.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\08mednegra.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\09mednegra.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\010mednegra.log
#
# Procesando para Lab: Gamma, Turno: M, Color: Amarilla, Archivo: 01
# Archivo a procesar: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\01medamarilla.log
# Error decodificando: non-hexadecimal number found in fromhex() arg at position 0
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\02medamarilla.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\03medamarilla.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\04medamarilla.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\05medamarilla.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\06medamarilla.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\07medamarilla.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\08medamarilla.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\09medamarilla.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\010medamarilla.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\01medroja.log
#
# Procesando para Lab: Gamma, Turno: M, Color: Roja, Archivo: 02
# Archivo a procesar: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\02medroja.log
# Error decodificando: non-hexadecimal number found in fromhex() arg at position 0
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\03medroja.log
#
# Procesando para Lab: Gamma, Turno: M, Color: Roja, Archivo: 04
# Archivo a procesar: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\04medroja.log
# Error decodificando: non-hexadecimal number found in fromhex() arg at position 0
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\05medroja.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\06medroja.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\07medroja.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\08medroja.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\09medroja.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\010medroja.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\01medazul.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\02medazul.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\03medazul.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\04medazul.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\05medazul.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\06medazul.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\07medazul.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\08medazul.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\09medazul.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\010medazul.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\01medverde.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\02medverde.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\03medverde.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\04medverde.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\05medverde.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\06medverde.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\07medverde.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\08medverde.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\09medverde.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\010medverde.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\01medmorada.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\02medmorada.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\03medmorada.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\04medmorada.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\05medmorada.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\06medmorada.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\07medmorada.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\08medmorada.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\09medmorada.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\010medmorada.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\01mednegra.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\02mednegra.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\03mednegra.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\04mednegra.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\05mednegra.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\06mednegra.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\07mednegra.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\08mednegra.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\09mednegra.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\010mednegra.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\01medamarilla.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\02medamarilla.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\03medamarilla.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\04medamarilla.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\05medamarilla.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\06medamarilla.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\07medamarilla.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\08medamarilla.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\09medamarilla.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\010medamarilla.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\01medroja.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\02medroja.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\03medroja.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\04medroja.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\05medroja.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\06medroja.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\07medroja.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\08medroja.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\09medroja.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\010medroja.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\01medazul.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\02medazul.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\03medazul.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\04medazul.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\05medazul.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\06medazul.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\07medazul.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\08medazul.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\09medazul.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\010medazul.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\01medverde.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\02medverde.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\03medverde.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\04medverde.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\05medverde.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\06medverde.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\07medverde.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\08medverde.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\09medverde.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\010medverde.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\01medmorada.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\02medmorada.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\03medmorada.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\04medmorada.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\05medmorada.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\06medmorada.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\07medmorada.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\08medmorada.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\09medmorada.log
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\010medmorada.log
#
# Procesamiento completo.

# %%
import os
import re
import pandas as pd

# Función para extraer la fecha del nombre del directorio raíz
def extraer_fecha(root_folder):
    nombre_directorio = os.path.basename(root_folder)
    match = re.search(r'(\d{2}[A-Za-z]{3}\d{2})', nombre_directorio)
    
    if match:
        fecha_str = match.group(1)  # Captura la fecha en formato '16Sep24'
        return fecha_str
    else:
        raise ValueError(f"No se encontró una fecha válida en el nombre del directorio {root_folder}.")

# Función para cargar y procesar los datos
def cargar_y_procesar_datos(ruta_archivo):
    datos_procesados = []
    
    with open(ruta_archivo, 'r') as archivo:
        for linea in archivo:
            partes = linea.split(',')
            hora = partes[0].strip()  # Extrae la hora
            valor = partes[1].strip()  # Extrae el valor con 'g'
            
            # Elimina la 'g' y convierte a float
            valor_numero = float(valor.replace('g', ''))
            # Aplica el tratamiento Dato * 9.81 / 5.00
            valor_procesado = valor_numero * 9.81 / 5.00
            
            # Guarda la hora y el valor procesado
            datos_procesados.append(f"{hora}, {valor_procesado:.2f}\n")
    
    return datos_procesados

# Función para guardar los datos procesados en un archivo .txt
def guardar_datos_txt(datos_procesados, ruta_salida):
    with open(ruta_salida, 'w') as archivo_salida:
        archivo_salida.writelines(datos_procesados)
    print(f"Datos procesados guardados en: {ruta_salida}")

# Función principal para procesar y guardar archivos
def procesar_archivos(root_folder):
    labs = ["Betta", "Gamma"]
    turnos = ["M", "V"]
    colores = ["Negra", "Amarilla", "Roja", "Azul", "Verde", "Morada"]
    numeros_archivo = range(1, 11)

    fecha = extraer_fecha(root_folder)

    for lab in labs:
        for turno in turnos:
            for color in colores:
                for numero in numeros_archivo:
                    colorin = color.lower()
                    ruta_archivo = os.path.join(root_folder, f"{fecha} - Lab_{lab}", f"{fecha}.{turno} - Lab_{lab}", "Pesajes", f"resultados_{colorin}_0{numero}.txt")
                    
                    if os.path.exists(ruta_archivo):
                        # Cargar y procesar los datos del archivo
                        datos_procesados = cargar_y_procesar_datos(ruta_archivo)

                        # Definir la carpeta y el nombre del archivo de salida
                        output_folder = os.path.join(root_folder, f"{fecha} - Lab_{lab}", f"{fecha}.{turno} - Lab_{lab}", "pesajes", "procesados")
                        os.makedirs(output_folder, exist_ok=True)
                        ruta_salida = os.path.join(output_folder, f"resultados_0{numero}_{colorin}.txt")

                        # Guardar los datos procesados en un archivo .txt
                        guardar_datos_txt(datos_procesados, ruta_salida)
                    else:
                        print(f"Archivo no encontrado: {ruta_archivo}")

# Si este es el archivo principal
if __name__ == "__main__":
    procesar_archivos(root_folder)
    print("\nProcesamiento completo.")
# Out:
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\resultados_negra_01.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\resultados_negra_02.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\resultados_negra_03.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\resultados_negra_04.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\resultados_negra_05.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\resultados_negra_06.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\resultados_negra_07.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\resultados_negra_08.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\resultados_negra_09.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\resultados_negra_010.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\resultados_amarilla_01.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\resultados_amarilla_02.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\resultados_amarilla_03.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\resultados_amarilla_04.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\resultados_amarilla_05.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\resultados_amarilla_06.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\resultados_amarilla_07.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\resultados_amarilla_08.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\resultados_amarilla_09.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\resultados_amarilla_010.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\resultados_roja_01.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\resultados_roja_02.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\resultados_roja_03.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\resultados_roja_04.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\resultados_roja_05.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\resultados_roja_06.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\resultados_roja_07.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\resultados_roja_08.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\resultados_roja_09.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\resultados_roja_010.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\resultados_azul_01.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\resultados_azul_02.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\resultados_azul_03.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\resultados_azul_04.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\resultados_azul_05.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\resultados_azul_06.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\resultados_azul_07.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\resultados_azul_08.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\resultados_azul_09.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\resultados_azul_010.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\resultados_verde_01.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\resultados_verde_02.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\resultados_verde_03.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\resultados_verde_04.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\resultados_verde_05.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\resultados_verde_06.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\resultados_verde_07.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\resultados_verde_08.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\resultados_verde_09.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\resultados_verde_010.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\resultados_morada_01.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\resultados_morada_02.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\resultados_morada_03.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\resultados_morada_04.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\resultados_morada_05.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\resultados_morada_06.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\resultados_morada_07.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\resultados_morada_08.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\resultados_morada_09.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.M - Lab_Betta\Pesajes\resultados_morada_010.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\resultados_negra_01.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\resultados_negra_02.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\resultados_negra_03.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\resultados_negra_04.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\resultados_negra_05.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\resultados_negra_06.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\resultados_negra_07.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\resultados_negra_08.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\resultados_negra_09.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\resultados_negra_010.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\resultados_amarilla_01.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\resultados_amarilla_02.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\resultados_amarilla_03.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\resultados_amarilla_04.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\resultados_amarilla_05.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\resultados_amarilla_06.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\resultados_amarilla_07.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\resultados_amarilla_08.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\resultados_amarilla_09.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\resultados_amarilla_010.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\resultados_roja_01.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\resultados_roja_02.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\resultados_roja_03.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\resultados_roja_04.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\resultados_roja_05.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\resultados_roja_06.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\resultados_roja_07.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\resultados_roja_08.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\resultados_roja_09.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\resultados_roja_010.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\resultados_azul_01.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\resultados_azul_02.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\resultados_azul_03.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\resultados_azul_04.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\resultados_azul_05.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\resultados_azul_06.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\resultados_azul_07.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\resultados_azul_08.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\resultados_azul_09.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\resultados_azul_010.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\resultados_verde_01.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\resultados_verde_02.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\resultados_verde_03.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\resultados_verde_04.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\resultados_verde_05.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\resultados_verde_06.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\resultados_verde_07.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\resultados_verde_08.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\resultados_verde_09.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\resultados_verde_010.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\resultados_morada_01.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\resultados_morada_02.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\resultados_morada_03.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\resultados_morada_04.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\resultados_morada_05.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\resultados_morada_06.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\resultados_morada_07.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\resultados_morada_08.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\resultados_morada_09.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Betta\20sep24.V - Lab_Betta\Pesajes\resultados_morada_010.txt
# Datos procesados guardados en: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\pesajes\procesados\resultados_01_negra.txt
# Datos procesados guardados en: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\pesajes\procesados\resultados_02_negra.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\resultados_negra_03.txt
# Datos procesados guardados en: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\pesajes\procesados\resultados_04_negra.txt
# Datos procesados guardados en: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\pesajes\procesados\resultados_05_negra.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\resultados_negra_06.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\resultados_negra_07.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\resultados_negra_08.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\resultados_negra_09.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\resultados_negra_010.txt
# Datos procesados guardados en: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\pesajes\procesados\resultados_01_amarilla.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\resultados_amarilla_02.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\resultados_amarilla_03.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\resultados_amarilla_04.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\resultados_amarilla_05.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\resultados_amarilla_06.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\resultados_amarilla_07.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\resultados_amarilla_08.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\resultados_amarilla_09.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\resultados_amarilla_010.txt
# Datos procesados guardados en: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\pesajes\procesados\resultados_01_roja.txt
# Datos procesados guardados en: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\pesajes\procesados\resultados_02_roja.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\resultados_roja_03.txt
# Datos procesados guardados en: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\pesajes\procesados\resultados_04_roja.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\resultados_roja_05.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\resultados_roja_06.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\resultados_roja_07.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\resultados_roja_08.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\resultados_roja_09.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\resultados_roja_010.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\resultados_azul_01.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\resultados_azul_02.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\resultados_azul_03.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\resultados_azul_04.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\resultados_azul_05.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\resultados_azul_06.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\resultados_azul_07.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\resultados_azul_08.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\resultados_azul_09.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\resultados_azul_010.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\resultados_verde_01.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\resultados_verde_02.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\resultados_verde_03.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\resultados_verde_04.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\resultados_verde_05.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\resultados_verde_06.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\resultados_verde_07.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\resultados_verde_08.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\resultados_verde_09.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\resultados_verde_010.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\resultados_morada_01.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\resultados_morada_02.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\resultados_morada_03.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\resultados_morada_04.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\resultados_morada_05.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\resultados_morada_06.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\resultados_morada_07.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\resultados_morada_08.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\resultados_morada_09.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\resultados_morada_010.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\resultados_negra_01.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\resultados_negra_02.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\resultados_negra_03.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\resultados_negra_04.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\resultados_negra_05.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\resultados_negra_06.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\resultados_negra_07.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\resultados_negra_08.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\resultados_negra_09.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\resultados_negra_010.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\resultados_amarilla_01.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\resultados_amarilla_02.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\resultados_amarilla_03.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\resultados_amarilla_04.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\resultados_amarilla_05.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\resultados_amarilla_06.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\resultados_amarilla_07.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\resultados_amarilla_08.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\resultados_amarilla_09.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\resultados_amarilla_010.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\resultados_roja_01.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\resultados_roja_02.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\resultados_roja_03.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\resultados_roja_04.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\resultados_roja_05.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\resultados_roja_06.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\resultados_roja_07.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\resultados_roja_08.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\resultados_roja_09.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\resultados_roja_010.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\resultados_azul_01.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\resultados_azul_02.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\resultados_azul_03.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\resultados_azul_04.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\resultados_azul_05.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\resultados_azul_06.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\resultados_azul_07.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\resultados_azul_08.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\resultados_azul_09.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\resultados_azul_010.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\resultados_verde_01.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\resultados_verde_02.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\resultados_verde_03.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\resultados_verde_04.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\resultados_verde_05.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\resultados_verde_06.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\resultados_verde_07.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\resultados_verde_08.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\resultados_verde_09.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\resultados_verde_010.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\resultados_morada_01.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\resultados_morada_02.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\resultados_morada_03.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\resultados_morada_04.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\resultados_morada_05.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\resultados_morada_06.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\resultados_morada_07.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\resultados_morada_08.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\resultados_morada_09.txt
# Archivo no encontrado: F:\Datos\20sep24\20sep24 - Lab_Gamma\20sep24.V - Lab_Gamma\Pesajes\resultados_morada_010.txt
#
# Procesamiento completo.

# %%
def procesar_archivo(ruta_archivo):
    resultados = []
    
    # Abrir y leer el archivo línea por línea
    with open(ruta_archivo, 'r') as archivo:
        for linea in archivo:
            valor = linea.strip()  # Quitar espacios en blanco alrededor
            if 'g' in valor:
                # Eliminar la 'g' y convertir a float
                valor_numero = float(valor.replace('g', '').strip())
                
                # Aplicar el tratamiento: Dato * 9.81 / 5.00
                valor_procesado = valor_numero * 9.81 / 5.00
                
                # Agregar el resultado procesado a la lista
                resultados.append(valor_procesado)
    
    return resultados

# Función para guardar los resultados en un archivo
def guardar_resultados(ruta_salida, resultados):
    with open(ruta_salida, 'w') as archivo_salida:
        for resultado in resultados:
            archivo_salida.write(f"{resultado:.5f}\n")

# Uso de ejemplo
ruta_entrada = r'F:\Datos\20Sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\03medroja_decimal.txt'  # Ruta de tu archivo original
ruta_salida = r'F:\Datos\20Sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\procesados\resultados_03_roja.txt'  # Ruta donde se guardarán los resultados

# Procesar el archivo y guardar los resultados
resultados_procesados = procesar_archivo(ruta_entrada)
guardar_resultados(ruta_salida, resultados_procesados)

print(f"Archivo procesado y guardado en {ruta_salida}")
# Out:
# Archivo procesado y guardado en F:\Datos\20Sep24\20sep24 - Lab_Gamma\20sep24.M - Lab_Gamma\Pesajes\procesados\resultados_03_roja.txt
